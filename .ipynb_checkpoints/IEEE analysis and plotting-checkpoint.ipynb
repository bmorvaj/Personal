# %%
from datetime import datetime
import csv
import xlwt
import os
import collections
import matplotlib.pyplot as plt
import matplotlib.pylab as py
import seaborn as sns
import pprint
from matplotlib import pyplot

import math
import matplotlib as mpl
from matplotlib import cm
from matplotlib import rc
import pandas as pd
import numpy as np
from IPython.display import HTML
import h5py
from tables import *
import gc
import vitables
import warnings
from pandas.tools.plotting import parallel_coordinates

# %%
warnings.filterwarnings('ignore')
from IPython.core.display import HTML
HTML("<style>.container { width:90% !important; }</style>")
# Out:
# <style>.container { width:90% !important; }</style>

# %%
# %matplotlib inline

# %% [markdown]
# # PV

# %% [markdown]
# CF 0.5

# %%
PVop8_05=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL05/8000000/PV')
PVop8_05SUM=PVop8_05.sum(axis=1)

PVop6_05=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL05/6000000/PV')
PVop6_05SUM=PVop6_05.sum(axis=1)

PVpotential05 = pd.concat([PVop8_05SUM, PVop6_05SUM], axis=1)

PVop55_05=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL05/5500000/PV')
PVop55_05SUM=PVop55_05.sum(axis=1)

PVpotential05 = pd.concat([PVpotential05, PVop55_05SUM], axis=1)

PVop5_05=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL05/5000000/PV')
PVop5_05SUM=PVop5_05.sum(axis=1)

PVpotential05 = pd.concat([PVpotential05, PVop5_05SUM], axis=1)

PVop48_05=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL05/4800000/PV')
PVop48_05SUM=PVop48_05.sum(axis=1)

PVpotential05 = pd.concat([PVpotential05, PVop48_05SUM], axis=1)

PVop46_05=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL05/4600000/PV')
PVop46_05SUM=PVop46_05.sum(axis=1)

PVpotential05 = pd.concat([PVpotential05, PVop46_05SUM], axis=1)


PVpotential05.columns=["8000000", "6000000", "5500000", "5000000", "4800000", "4600000"]

PVpotential05
# Out:
#        8000000    6000000     5500000     5000000     4800000     4600000
# 0     0.000000   0.000000    0.000000    0.000000    0.000000    0.000000
# 1     0.000000   0.000000    0.000000    0.000000    0.000000    0.000000
# 2     0.000000   0.000000    0.000000    0.000000    0.000000    0.000000
# 3     0.000000   0.000000    0.000000    0.000000    0.000000    0.000000
# 4     0.000000   0.000000    0.000000    0.000000    0.000000    0.000000
# 5     0.000000   0.000000    0.000000    0.000000    0.000000    0.000000
# 6     0.000000   0.000000    0.000000    0.000000    0.000000    0.000000
# 7     0.000000   0.000000    0.000000    0.000000    0.000000    0.000000
# 8     0.000000   0.000000    0.000000    0.000000    0.000000    0.000000
# 9     7.541404  15.956965   24.148725   39.868218   48.141129   38.495098
# 10   22.624211  47.870896   72.446176  119.604654  144.423387  115.485293
# 11   36.629674  77.505260  117.293809  193.645630  233.828340  186.976189
# ...

# %%
PVpotential05SUM=pd.DataFrame(PVpotential05.transpose().sum(axis=1), columns=['CF 0.5']) # sum all timesteps per carbon case

# %% [markdown]
# CF 0.4

# %%
PVop8_04=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL04/8000000/PV')
PVop8_04SUM=PVop8_04.sum(axis=1)

PVop6_04=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL04/6000000/PV')
PVop6_04SUM=PVop6_04.sum(axis=1)

PVpotential04 = pd.concat([PVop8_04SUM, PVop6_04SUM], axis=1)

PVop55_04=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL04/5500000/PV')
PVop55_04SUM=PVop55_04.sum(axis=1)

PVpotential04 = pd.concat([PVpotential04, PVop55_04SUM], axis=1)

PVop5_04=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL04/5000000/PV')
PVop5_04SUM=PVop5_04.sum(axis=1)

PVpotential04 = pd.concat([PVpotential04, PVop5_04SUM], axis=1)

PVop48_04=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL04/4800000/PV')
PVop48_04SUM=PVop48_04.sum(axis=1)

PVpotential04 = pd.concat([PVpotential04, PVop48_04SUM], axis=1)

PVop46_04=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL04/4600000/PV')
PVop46_04SUM=PVop46_04.sum(axis=1)

PVpotential04 = pd.concat([PVpotential04, PVop46_04SUM], axis=1)

PVop44_04=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL04/4400000/PV')
PVop44_04SUM=PVop44_04.sum(axis=1)

PVpotential04 = pd.concat([PVpotential04, PVop44_04SUM], axis=1)


PVpotential04.columns=["8000000", "6000000", "5500000", "5000000", "4800000", "4600000", "4400000"]

PVpotential04
# Out:
#        8000000    6000000     5500000     5000000     4800000     4600000  \
# 0     0.000000   0.000000    0.000000    0.000000    0.000000    0.000000
# 1     0.000000   0.000000    0.000000    0.000000    0.000000    0.000000
# 2     0.000000   0.000000    0.000000    0.000000    0.000000    0.000000
# 3     0.000000   0.000000    0.000000    0.000000    0.000000    0.000000
# 4     0.000000   0.000000    0.000000    0.000000    0.000000    0.000000
# 5     0.000000   0.000000    0.000000    0.000000    0.000000    0.000000
# 6     0.000000   0.000000    0.000000    0.000000    0.000000    0.000000
# 7     0.000000   0.000000    0.000000    0.000000    0.000000    0.000000
# 8     0.000000   0.000000    0.000000    0.000000    0.000000    0.000000
# 9     7.141689  12.092446   18.117469   27.382028   33.626895   41.713702
# 10   21.425066  36.277338   54.352408   82.146085  100.880686  125.141106
# 11   34.688201  58.734737   87.999137  132.998423  163.330634  202.609410
# ...

# %%
PVpotential04SUM=pd.DataFrame(PVpotential04.transpose().sum(axis=1), columns=['CF 0.4']) # sum all timesteps per carbon case

# %% [markdown]
# CF 0.3

# %%
PVop8_03=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL03/8000000/PV')
PVop8_03SUM=PVop8_03.sum(axis=1)

PVop6_03=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL03/6000000/PV')
PVop6_03SUM=PVop6_03.sum(axis=1)

PVpotential03 = pd.concat([PVop8_03SUM, PVop6_03SUM], axis=1)

PVop55_03=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL03/5500000/PV')
PVop55_03SUM=PVop55_03.sum(axis=1)

PVpotential03 = pd.concat([PVpotential03, PVop55_03SUM], axis=1)

PVop5_03=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL03/5000000/PV')
PVop5_03SUM=PVop5_03.sum(axis=1)

PVpotential03 = pd.concat([PVpotential03, PVop5_03SUM], axis=1)

PVop48_03=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL03/4800000/PV')
PVop48_03SUM=PVop48_03.sum(axis=1)

PVpotential03 = pd.concat([PVpotential03, PVop48_03SUM], axis=1)

PVop46_03=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL03/4600000/PV')
PVop46_03SUM=PVop46_03.sum(axis=1)

PVpotential03 = pd.concat([PVpotential03, PVop46_03SUM], axis=1)

PVop44_03=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL03/4400000/PV')
PVop44_03SUM=PVop44_03.sum(axis=1)

PVpotential03 = pd.concat([PVpotential03, PVop44_03SUM], axis=1)

PVop40_03=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL03/4000000/PV')
PVop40_03SUM=PVop40_03.sum(axis=1)

PVpotential03 = pd.concat([PVpotential03, PVop40_03SUM], axis=1)

PVop35_03=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL03/3500000/PV')
PVop35_03SUM=PVop35_03.sum(axis=1)

PVpotential03 = pd.concat([PVpotential03, PVop35_03SUM], axis=1)

PVop32_03=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL03/3200000/PV')
PVop32_03SUM=PVop32_03.sum(axis=1)

PVpotential03 = pd.concat([PVpotential03, PVop32_03SUM], axis=1)


PVpotential03.columns=["8000000", "6000000", "5500000", "5000000", "4800000", "4600000", "4400000", "4000000", "3500000", "3200000"]

PVpotential03
# Out:
#        8000000    6000000    5500000     5000000     4800000     4600000  \
# 0     0.000000   0.000000   0.000000    0.000000    0.000000    0.000000
# 1     0.000000   0.000000   0.000000    0.000000    0.000000    0.000000
# 2     0.000000   0.000000   0.000000    0.000000    0.000000    0.000000
# 3     0.000000   0.000000   0.000000    0.000000    0.000000    0.000000
# 4     0.000000   0.000000   0.000000    0.000000    0.000000    0.000000
# 5     0.000000   0.000000   0.000000    0.000000    0.000000    0.000000
# 6     0.000000   0.000000   0.000000    0.000000    0.000000    0.000000
# 7     0.000000   0.000000   0.000000    0.000000    0.000000    0.000000
# 8     0.000000   0.000000   0.000000    0.000000    0.000000    0.000000
# 9     7.220408   9.697229  13.638596   20.276505   23.263357   25.927597
# 10   21.661225  29.091688  40.915789   60.829515   69.790072   77.782792
# 11   35.070555  47.100828  66.244610   98.485881  112.993449  125.934045
# ...

# %%
PVpotential03SUM=pd.DataFrame(PVpotential03.transpose().sum(axis=1), columns=['CF 0.3']) # sum all timesteps per carbon case

# %% [markdown]
# CF 0.2

# %%
PVop8_02=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL02/8000000/PV')
PVop8_02SUM=PVop8_02.sum(axis=1)

PVop6_02=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL02/6000000/PV')
PVop6_02SUM=PVop6_02.sum(axis=1)

PVpotential02 = pd.concat([PVop8_02SUM, PVop6_02SUM], axis=1)

PVop55_02=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL02/5500000/PV')
PVop55_02SUM=PVop55_02.sum(axis=1)

PVpotential02 = pd.concat([PVpotential02, PVop55_02SUM], axis=1)

PVop5_02=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL02/5000000/PV')
PVop5_02SUM=PVop5_02.sum(axis=1)

PVpotential02 = pd.concat([PVpotential02, PVop5_02SUM], axis=1)

PVop48_02=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL02/4800000/PV')
PVop48_02SUM=PVop48_02.sum(axis=1)

PVpotential02 = pd.concat([PVpotential02, PVop48_02SUM], axis=1)

PVop46_02=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL02/4600000/PV')
PVop46_02SUM=PVop46_02.sum(axis=1)

PVpotential02 = pd.concat([PVpotential02, PVop46_02SUM], axis=1)

PVop44_02=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL02/4400000/PV')
PVop44_02SUM=PVop44_02.sum(axis=1)

PVpotential02 = pd.concat([PVpotential02, PVop44_02SUM], axis=1)

PVop40_02=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL02/4000000/PV')
PVop40_02SUM=PVop40_02.sum(axis=1)

PVpotential02 = pd.concat([PVpotential02, PVop40_02SUM], axis=1)

PVop35_02=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL02/3500000/PV')
PVop35_02SUM=PVop35_02.sum(axis=1)

PVpotential02 = pd.concat([PVpotential02, PVop35_02SUM], axis=1)

PVop32_02=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL02/3200000/PV')
PVop32_02SUM=PVop32_02.sum(axis=1)

PVpotential02 = pd.concat([PVpotential02, PVop32_02SUM], axis=1)

PVop3_02=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL02/3000000/PV')
PVop3_02SUM=PVop3_02.sum(axis=1)

PVpotential02 = pd.concat([PVpotential02, PVop3_02SUM], axis=1)

PVop25_02=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL02/2500000/PV')
PVop25_02SUM=PVop25_02.sum(axis=1)

PVpotential02 = pd.concat([PVpotential02, PVop25_02SUM], axis=1)


PVpotential02.columns=["8000000", "6000000", "5500000", "5000000", "4800000", "4600000", "4400000", "4000000", "3500000", "3200000", "3000000", "2500000"]

PVpotential02
# Out:
#        8000000    6000000    5500000    5000000    4800000     4600000  \
# 0     0.000000   0.000000   0.000000   0.000000   0.000000    0.000000
# 1     0.000000   0.000000   0.000000   0.000000   0.000000    0.000000
# 2     0.000000   0.000000   0.000000   0.000000   0.000000    0.000000
# 3     0.000000   0.000000   0.000000   0.000000   0.000000    0.000000
# 4     0.000000   0.000000   0.000000   0.000000   0.000000    0.000000
# 5     0.000000   0.000000   0.000000   0.000000   0.000000    0.000000
# 6     0.000000   0.000000   0.000000   0.000000   0.000000    0.000000
# 7     0.000000   0.000000   0.000000   0.000000   0.000000    0.000000
# 8     0.000000   0.000000   0.000000   0.000000   0.000000    0.000000
# 9     7.164901   7.382480  10.417595  15.122369  16.318546   17.654253
# 10   21.494703  22.147439  31.252785  45.367108  48.955638   52.962758
# 11   34.800948  35.857759  50.599747  73.451509  79.261509   85.749227
# ...

# %%
PVpotential02SUM=pd.DataFrame(PVpotential02.transpose().sum(axis=1), columns=['CF 0.2']) # sum all timesteps per carbon case

# %% [markdown]
# CF 0.1

# %%
PVop8_01=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL01/8000000/PV')
PVop8_01SUM=PVop8_01.sum(axis=1)

PVop6_01=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL01/6000000/PV')
PVop6_01SUM=PVop6_01.sum(axis=1)

PVpotential01 = pd.concat([PVop8_01SUM, PVop6_01SUM], axis=1)

PVop55_01=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL01/5500000/PV')
PVop55_01SUM=PVop55_01.sum(axis=1)

PVpotential01 = pd.concat([PVpotential01, PVop55_01SUM], axis=1)

PVop5_01=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL01/5000000/PV')
PVop5_01SUM=PVop5_01.sum(axis=1)

PVpotential01 = pd.concat([PVpotential01, PVop5_01SUM], axis=1)

PVop48_01=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL01/4800000/PV')
PVop48_01SUM=PVop48_01.sum(axis=1)

PVpotential01 = pd.concat([PVpotential01, PVop48_01SUM], axis=1)

PVop46_01=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL01/4600000/PV')
PVop46_01SUM=PVop46_01.sum(axis=1)

PVpotential01 = pd.concat([PVpotential01, PVop46_01SUM], axis=1)

PVop44_01=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL01/4400000/PV')
PVop44_01SUM=PVop44_01.sum(axis=1)

PVpotential01 = pd.concat([PVpotential01, PVop44_01SUM], axis=1)

PVop40_01=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL01/4000000/PV')
PVop40_01SUM=PVop40_01.sum(axis=1)

PVpotential01 = pd.concat([PVpotential01, PVop40_01SUM], axis=1)

PVop35_01=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL01/3500000/PV')
PVop35_01SUM=PVop35_01.sum(axis=1)

PVpotential01 = pd.concat([PVpotential01, PVop35_01SUM], axis=1)

PVop32_01=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL01/3200000/PV')
PVop32_01SUM=PVop32_01.sum(axis=1)

PVpotential01 = pd.concat([PVpotential01, PVop32_01SUM], axis=1)

PVop3_01=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL01/3000000/PV')
PVop3_01SUM=PVop3_01.sum(axis=1)

PVpotential01 = pd.concat([PVpotential01, PVop3_01SUM], axis=1)

PVop25_01=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL01/2500000/PV')
PVop25_01SUM=PVop25_01.sum(axis=1)

PVpotential01 = pd.concat([PVpotential01, PVop25_01SUM], axis=1)

PVop2_01=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL01/2000000/PV')
PVop2_01SUM=PVop2_01.sum(axis=1)

PVpotential01 = pd.concat([PVpotential01, PVop2_01SUM], axis=1)

PVop15_01=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL01/1500000/PV')
PVop15_01SUM=PVop15_01.sum(axis=1)

PVpotential01 = pd.concat([PVpotential01, PVop15_01SUM], axis=1)


PVpotential01.columns=["8000000", "6000000", "5500000", "5000000", "4800000", "4600000", "4400000", "4000000", "3500000", "3200000", "3000000", "2500000", "2000000", "1500000"]

PVpotential01
# Out:
#        8000000    6000000    5500000    5000000    4800000    4600000  \
# 0     0.000000   0.000000   0.000000   0.000000   0.000000   0.000000
# 1     0.000000   0.000000   0.000000   0.000000   0.000000   0.000000
# 2     0.000000   0.000000   0.000000   0.000000   0.000000   0.000000
# 3     0.000000   0.000000   0.000000   0.000000   0.000000   0.000000
# 4     0.000000   0.000000   0.000000   0.000000   0.000000   0.000000
# 5     0.000000   0.000000   0.000000   0.000000   0.000000   0.000000
# 6     0.000000   0.000000   0.000000   0.000000   0.000000   0.000000
# 7     0.000000   0.000000   0.000000   0.000000   0.000000   0.000000
# 8     0.000000   0.000000   0.000000   0.000000   0.000000   0.000000
# 9     7.359984   7.335476   8.844219  11.545732  13.113358  13.908761
# 10   22.079951  22.006429  26.532658  34.637195  39.340073  41.726283
# 11   35.748491  35.629457  42.957636  56.079268  63.693451  67.556839
# ...

# %%
PVpotential01SUM=pd.DataFrame(PVpotential01.transpose().sum(axis=1), columns=['CF 0.1']) # sum all timesteps per carbon case

# %% [markdown]
# CF 0

# %%
PVop8_0=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL0/8000000/PV')
PVop8_0SUM=PVop8_0.sum(axis=1)

PVop6_0=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL0/6000000/PV')
PVop6_0SUM=PVop6_0.sum(axis=1)

PVpotential0 = pd.concat([PVop8_0SUM, PVop6_0SUM], axis=1)

PVop55_0=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL0/5500000/PV')
PVop55_0SUM=PVop55_0.sum(axis=1)

PVpotential0 = pd.concat([PVpotential0, PVop55_0SUM], axis=1)

PVop5_0=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL0/5000000/PV')
PVop5_0SUM=PVop5_0.sum(axis=1)

PVpotential0 = pd.concat([PVpotential0, PVop5_0SUM], axis=1)

PVop48_0=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL0/4800000/PV')
PVop48_0SUM=PVop48_0.sum(axis=1)

PVpotential0 = pd.concat([PVpotential0, PVop48_0SUM], axis=1)

PVop46_0=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL0/4600000/PV')
PVop46_0SUM=PVop46_0.sum(axis=1)

PVpotential0 = pd.concat([PVpotential0, PVop46_0SUM], axis=1)

PVop44_0=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL0/4400000/PV')
PVop44_0SUM=PVop44_0.sum(axis=1)

PVpotential0 = pd.concat([PVpotential0, PVop44_0SUM], axis=1)

PVop40_0=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL0/4000000/PV')
PVop40_0SUM=PVop40_0.sum(axis=1)

PVpotential0 = pd.concat([PVpotential0, PVop40_0SUM], axis=1)

PVop35_0=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL0/3500000/PV')
PVop35_0SUM=PVop35_0.sum(axis=1)

PVpotential0 = pd.concat([PVpotential0, PVop35_0SUM], axis=1)

PVop32_0=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL0/3200000/PV')
PVop32_0SUM=PVop32_0.sum(axis=1)

PVpotential0 = pd.concat([PVpotential0, PVop32_0SUM], axis=1)

PVop3_0=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL0/3000000/PV')
PVop3_0SUM=PVop3_0.sum(axis=1)

PVpotential0 = pd.concat([PVpotential0, PVop3_0SUM], axis=1)

PVop25_0=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL0/2500000/PV')
PVop25_0SUM=PVop25_0.sum(axis=1)

PVpotential0 = pd.concat([PVpotential0, PVop25_0SUM], axis=1)

PVop2_0=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL0/2000000/PV')
PVop2_0SUM=PVop2_0.sum(axis=1)

PVpotential0 = pd.concat([PVpotential0, PVop2_0SUM], axis=1)

PVop15_0=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL0/1500000/PV')
PVop15_0SUM=PVop15_0.sum(axis=1)

PVpotential0 = pd.concat([PVpotential0, PVop15_0SUM], axis=1)

PVop1_0=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL0/1000000/PV')
PVop1_0SUM=PVop1_0.sum(axis=1)

PVpotential0 = pd.concat([PVpotential0, PVop1_0SUM], axis=1)

PVop0_0=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL0/0/PV')
PVop0_0SUM=PVop0_0.sum(axis=1)

PVpotential0 = pd.concat([PVpotential0, PVop1_0SUM], axis=1)


PVpotential0.columns=["8000000", "6000000", "5500000", "5000000", "4800000", "4600000", "4400000", "4000000", "3500000", "3200000", "3000000", "2500000", "2000000", "1500000", "1000000", "0"]

PVpotential0
# Out:
#        8000000    6000000    5500000    5000000    4800000    4600000  \
# 0     0.000000   0.000000   0.000000   0.000000   0.000000   0.000000
# 1     0.000000   0.000000   0.000000   0.000000   0.000000   0.000000
# 2     0.000000   0.000000   0.000000   0.000000   0.000000   0.000000
# 3     0.000000   0.000000   0.000000   0.000000   0.000000   0.000000
# 4     0.000000   0.000000   0.000000   0.000000   0.000000   0.000000
# 5     0.000000   0.000000   0.000000   0.000000   0.000000   0.000000
# 6     0.000000   0.000000   0.000000   0.000000   0.000000   0.000000
# 7     0.000000   0.000000   0.000000   0.000000   0.000000   0.000000
# 8     0.000000   0.000000   0.000000   0.000000   0.000000   0.000000
# 9     7.166455   7.265196   7.190816   9.150374  10.229315  11.015682
# 10   21.499364  21.795589  21.572448  27.451123  30.687944  33.047045
# 11   34.808495  35.288096  34.926820  44.444675  49.685243  53.504739
# ...

# %%
PVpotential0SUM=pd.DataFrame(PVpotential0.transpose().sum(axis=1), columns=['CF 0']) # sum all timesteps per carbon case

# %% [markdown]
# # HP

# %% [markdown]
# CF 0.5

# %%
HPop8_05=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL05/8000000/HP')
HPop8_05SUM=HPop8_05.sum(axis=1)

HPop6_05=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL05/6000000/HP')
HPop6_05SUM=HPop6_05.sum(axis=1)

HPpotential05 = pd.concat([HPop8_05SUM, HPop6_05SUM], axis=1)

HPop55_05=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL05/5500000/HP')
HPop55_05SUM=HPop55_05.sum(axis=1)

HPpotential05 = pd.concat([HPpotential05, HPop55_05SUM], axis=1)

HPop5_05=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL05/5000000/HP')
HPop5_05SUM=HPop5_05.sum(axis=1)

HPpotential05 = pd.concat([HPpotential05, HPop5_05SUM], axis=1)

HPop48_05=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL05/4800000/HP')
HPop48_05SUM=HPop48_05.sum(axis=1)

HPpotential05 = pd.concat([HPpotential05, HPop48_05SUM], axis=1)

HPop46_05=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL05/4600000/HP')
HPop46_05SUM=HPop46_05.sum(axis=1)

HPpotential05 = pd.concat([HPpotential05, HPop46_05SUM], axis=1)


HPpotential05.columns=["8000000", "6000000", "5500000", "5000000", "4800000", "4600000"]

HPpotential05
# Out:
#        8000000    6000000    5500000     5000000     4800000     4600000
# 0    40.897559  40.021517  40.154124   41.926004   39.200407   39.778178
# 1    41.354202  39.272186  39.142612   38.339117   39.297701   39.439857
# 2    42.352258  41.063946  39.138235   39.798039   39.522286   39.012000
# 3    42.576944  45.333934  39.367132   38.296473   38.749253   38.516000
# 4    42.530592  44.539483  40.674627   42.521088   40.175599   39.138000
# 5    43.264453  52.009285  50.900530   50.805487   48.726154   41.064726
# 6    29.084285  31.562764  28.444532   27.785806   30.808320   34.125130
# 7    29.577425  36.788815  32.789685   31.458517   33.090336   33.250612
# 8    31.755904  40.691171  31.344687   30.014296   31.724768   27.707722
# 9    31.591891  45.768055  45.197634   56.066680   50.800671   50.282289
# 10   35.009771  50.428956  47.177734   62.737378   85.702387   62.639960
# 11   38.579524  41.791053  71.041725  132.551174  168.258924  124.856189
# ...

# %%
HPpotential05SUM=pd.DataFrame(HPpotential05.transpose().sum(axis=1), columns=['CF 0.5']) # sum all timesteps per carbon case

# %% [markdown]
# CF 0.4

# %%
HPop8_04=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL04/8000000/HP')
HPop8_04SUM=HPop8_04.sum(axis=1)

HPop6_04=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL04/6000000/HP')
HPop6_04SUM=HPop6_04.sum(axis=1)

HPpotential04 = pd.concat([HPop8_04SUM, HPop6_04SUM], axis=1)

HPop55_04=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL04/5500000/HP')
HPop55_04SUM=HPop55_04.sum(axis=1)

HPpotential04 = pd.concat([HPpotential04, HPop55_04SUM], axis=1)

HPop5_04=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL04/5000000/HP')
HPop5_04SUM=HPop5_04.sum(axis=1)

HPpotential04 = pd.concat([HPpotential04, HPop5_04SUM], axis=1)

HPop48_04=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL04/4800000/HP')
HPop48_04SUM=HPop48_04.sum(axis=1)

HPpotential04 = pd.concat([HPpotential04, HPop48_04SUM], axis=1)

HPop46_04=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL04/4600000/HP')
HPop46_04SUM=HPop46_04.sum(axis=1)

HPpotential04 = pd.concat([HPpotential04, HPop46_04SUM], axis=1)

HPop44_04=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL04/4400000/HP')
HPop44_04SUM=HPop44_04.sum(axis=1)

HPpotential04 = pd.concat([HPpotential04, HPop44_04SUM], axis=1)


HPpotential04.columns=["8000000", "6000000", "5500000", "5000000", "4800000", "4600000", "4400000"]

HPpotential04
# Out:
#        8000000    6000000    5500000    5000000     4800000     4600000  \
# 0    41.290340  43.488496  40.261642  41.021832   41.066999   41.641492
# 1    41.284817  44.236657  39.038444  38.766778   38.894690   37.908567
# 2    41.651345  44.891589  39.562876  39.105219   39.950495   43.266174
# 3    42.234024  48.137276  41.755549  39.754342   39.407500   40.191117
# 4    42.094583  47.155483  44.537736  44.818658   45.946322   45.053907
# 5    42.749355  47.782178  50.264351  50.119299   51.052050   51.408945
# 6    27.928806  30.905714  28.065785  28.809437   28.242792   26.382128
# 7    32.847881  36.855743  35.572304  32.186000   31.887158   30.419712
# 8    33.430863  38.785005  35.472184  31.038249   28.695272   27.106938
# 9    31.242226  39.498267  45.648004  50.956948   51.402027   52.103692
# 10   36.120267  43.563974  59.181485  43.605017   56.276875   69.501377
# 11   38.967433  35.329370  51.969658  80.750429  102.216898  140.658711
# ...

# %%
HPpotential04SUM=pd.DataFrame(HPpotential04.transpose().sum(axis=1), columns=['CF 0.4']) # sum all timesteps per carbon case

# %% [markdown]
# CF 0.3

# %%
HPop8_03=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL03/8000000/HP')
HPop8_03SUM=HPop8_03.sum(axis=1)

HPop6_03=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL03/6000000/HP')
HPop6_03SUM=HPop6_03.sum(axis=1)

HPpotential03 = pd.concat([HPop8_03SUM, HPop6_03SUM], axis=1)

HPop55_03=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL03/5500000/HP')
HPop55_03SUM=HPop55_03.sum(axis=1)

HPpotential03 = pd.concat([HPpotential03, HPop55_03SUM], axis=1)

HPop5_03=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL03/5000000/HP')
HPop5_03SUM=HPop5_03.sum(axis=1)

HPpotential03 = pd.concat([HPpotential03, HPop5_03SUM], axis=1)

HPop48_03=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL03/4800000/HP')
HPop48_03SUM=HPop48_03.sum(axis=1)

HPpotential03 = pd.concat([HPpotential03, HPop48_03SUM], axis=1)

HPop46_03=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL03/4600000/HP')
HPop46_03SUM=HPop46_03.sum(axis=1)

HPpotential03 = pd.concat([HPpotential03, HPop46_03SUM], axis=1)

HPop44_03=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL03/4400000/HP')
HPop44_03SUM=HPop44_03.sum(axis=1)

HPpotential03 = pd.concat([HPpotential03, HPop44_03SUM], axis=1)

HPop40_03=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL03/4000000/HP')
HPop40_03SUM=HPop40_03.sum(axis=1)

HPpotential03 = pd.concat([HPpotential03, HPop40_03SUM], axis=1)

HPop35_03=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL03/3500000/HP')
HPop35_03SUM=HPop35_03.sum(axis=1)

HPpotential03 = pd.concat([HPpotential03, HPop35_03SUM], axis=1)

HPop32_03=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL03/3200000/HP')
HPop32_03SUM=HPop32_03.sum(axis=1)

HPpotential03 = pd.concat([HPpotential03, HPop32_03SUM], axis=1)


HPpotential03.columns=["8000000", "6000000", "5500000", "5000000", "4800000", "4600000", "4400000", "4000000", "3500000", "3200000"]

HPpotential03
# Out:
#        8000000    6000000    5500000    5000000    4800000    4600000  \
# 0    40.646987  42.823070  41.326368  40.304898  40.637303  42.863715
# 1    41.113328  43.893594  42.302578  39.278551  40.117903  40.524981
# 2    41.786697  43.937365  43.694089  40.385649  40.350001  39.973043
# 3    42.276371  46.101524  48.429992  41.783819  42.322161  40.231315
# 4    42.369011  45.447209  48.359007  46.238913  45.914295  42.651190
# 5    42.266933  46.153593  49.988207  49.616102  48.794842  45.568164
# 6    28.384070  31.400087  30.224210  28.344436  26.483470  42.158010
# 7    31.485758  35.036295  37.739821  33.073532  33.261389  42.557950
# 8    34.998450  36.060426  38.160949  30.487235  30.973439  37.413053
# 9    32.566745  33.415892  40.257359  43.485818  45.137351  50.846456
# 10   34.934767  42.155563  48.477029  48.532551  48.204304  48.396491
# 11   38.466802  38.466718  40.815470  56.540289  65.712934  71.202534
# ...

# %%
HPpotential03SUM=pd.DataFrame(HPpotential03.transpose().sum(axis=1), columns=['CF 0.3']) # sum all timesteps per carbon case

# %% [markdown]
# 0.2

# %%
HPop8_02=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL02/8000000/HP')
HPop8_02SUM=HPop8_02.sum(axis=1)

HPop6_02=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL02/6000000/HP')
HPop6_02SUM=HPop6_02.sum(axis=1)

HPpotential02 = pd.concat([HPop8_02SUM, HPop6_02SUM], axis=1)

HPop55_02=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL02/5500000/HP')
HPop55_02SUM=HPop55_02.sum(axis=1)

HPpotential02 = pd.concat([HPpotential02, HPop55_02SUM], axis=1)

HPop5_02=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL02/5000000/HP')
HPop5_02SUM=HPop5_02.sum(axis=1)

HPpotential02 = pd.concat([HPpotential02, HPop5_02SUM], axis=1)

HPop48_02=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL02/4800000/HP')
HPop48_02SUM=HPop48_02.sum(axis=1)

HPpotential02 = pd.concat([HPpotential02, HPop48_02SUM], axis=1)

HPop46_02=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL02/4600000/HP')
HPop46_02SUM=HPop46_02.sum(axis=1)

HPpotential02 = pd.concat([HPpotential02, HPop46_02SUM], axis=1)

HPop44_02=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL02/4400000/HP')
HPop44_02SUM=HPop44_02.sum(axis=1)

HPpotential02 = pd.concat([HPpotential02, HPop44_02SUM], axis=1)

HPop40_02=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL02/4000000/HP')
HPop40_02SUM=HPop40_02.sum(axis=1)

HPpotential02 = pd.concat([HPpotential02, HPop40_02SUM], axis=1)

HPop35_02=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL02/3500000/HP')
HPop35_02SUM=HPop35_02.sum(axis=1)

HPpotential02 = pd.concat([HPpotential02, HPop35_02SUM], axis=1)

HPop32_02=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL02/3200000/HP')
HPop32_02SUM=HPop32_02.sum(axis=1)

HPpotential02 = pd.concat([HPpotential02, HPop32_02SUM], axis=1)

HPop3_02=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL02/3000000/HP')
HPop3_02SUM=HPop3_02.sum(axis=1)

HPpotential02 = pd.concat([HPpotential02, HPop3_02SUM], axis=1)

HPop25_02=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL02/2500000/HP')
HPop25_02SUM=HPop25_02.sum(axis=1)

HPpotential02 = pd.concat([HPpotential02, HPop25_02SUM], axis=1)


HPpotential02.columns=["8000000", "6000000", "5500000", "5000000", "4800000", "4600000", "4400000", "4000000", "3500000", "3200000", "3000000", "2500000"]

HPpotential02
# Out:
#        8000000    6000000    5500000    5000000    4800000    4600000  \
# 0    41.202467  41.177413  41.339260  40.468941  41.698616  42.586163
# 1    41.178711  40.159384  39.964685  39.815561  41.282211  41.609631
# 2    41.519505  41.650529  43.537476  40.235424  41.795442  40.130059
# 3    42.471146  43.637249  45.330617  42.056974  42.945520  42.657079
# 4    41.987627  43.530414  44.896344  45.380392  44.446199  41.686616
# 5    42.583208  44.421516  46.970866  49.386272  46.100577  42.666906
# 6    27.514890  28.434630  29.414045  27.457610  33.103186  48.721743
# 7    33.000651  32.484844  34.201687  35.310548  41.492119  43.340089
# 8    34.017327  34.228672  35.677672  33.077393  36.984013  37.244302
# 9    31.176468  31.265470  35.847139  41.843261  41.291156  47.515489
# 10   36.237783  35.491712  41.621849  48.829194  38.636439  44.097071
# 11   38.840189  39.635458  44.593656  46.089975  51.382030  50.827120
# ...

# %%
HPpotential02SUM=pd.DataFrame(HPpotential02.transpose().sum(axis=1), columns=['CF 0.2']) # sum all timesteps per carbon case

# %% [markdown]
# CF 0.1

# %%
HPop8_01=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL01/8000000/HP')
HPop8_01SUM=HPop8_01.sum(axis=1)

HPop6_01=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL01/6000000/HP')
HPop6_01SUM=HPop6_01.sum(axis=1)

HPpotential01 = pd.concat([HPop8_01SUM, HPop6_01SUM], axis=1)

HPop55_01=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL01/5500000/HP')
HPop55_01SUM=HPop55_01.sum(axis=1)

HPpotential01 = pd.concat([HPpotential01, HPop55_01SUM], axis=1)

HPop5_01=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL01/5000000/HP')
HPop5_01SUM=HPop5_01.sum(axis=1)

HPpotential01 = pd.concat([HPpotential01, HPop5_01SUM], axis=1)

HPop48_01=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL01/4800000/HP')
HPop48_01SUM=HPop48_01.sum(axis=1)

HPpotential01 = pd.concat([HPpotential01, HPop48_01SUM], axis=1)

HPop46_01=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL01/4600000/HP')
HPop46_01SUM=HPop46_01.sum(axis=1)

HPpotential01 = pd.concat([HPpotential01, HPop46_01SUM], axis=1)

HPop44_01=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL01/4400000/HP')
HPop44_01SUM=HPop44_01.sum(axis=1)

HPpotential01 = pd.concat([HPpotential01, HPop44_01SUM], axis=1)

HPop40_01=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL01/4000000/HP')
HPop40_01SUM=HPop40_01.sum(axis=1)

HPpotential01 = pd.concat([HPpotential01, HPop40_01SUM], axis=1)

HPop35_01=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL01/3500000/HP')
HPop35_01SUM=HPop35_01.sum(axis=1)

HPpotential01 = pd.concat([HPpotential01, HPop35_01SUM], axis=1)

HPop32_01=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL01/3200000/HP')
HPop32_01SUM=HPop32_01.sum(axis=1)

HPpotential01 = pd.concat([HPpotential01, HPop32_01SUM], axis=1)

HPop3_01=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL01/3000000/HP')
HPop3_01SUM=HPop3_01.sum(axis=1)

HPpotential01 = pd.concat([HPpotential01, HPop3_01SUM], axis=1)

HPop25_01=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL01/2500000/HP')
HPop25_01SUM=HPop25_01.sum(axis=1)

HPpotential01 = pd.concat([HPpotential01, HPop25_01SUM], axis=1)

HPop2_01=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL01/2000000/HP')
HPop2_01SUM=HPop2_01.sum(axis=1)

HPpotential01 = pd.concat([HPpotential01, HPop2_01SUM], axis=1)

HPop15_01=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL01/1500000/HP')
HPop15_01SUM=HPop15_01.sum(axis=1)

HPpotential01 = pd.concat([HPpotential01, HPop15_01SUM], axis=1)


HPpotential01.columns=["8000000", "6000000", "5500000", "5000000", "4800000", "4600000", "4400000", "4000000", "3500000", "3200000", "3000000", "2500000", "2000000", "1500000"]

HPpotential01
# Out:
#        8000000    6000000    5500000    5000000    4800000    4600000  \
# 0    41.136738  41.539918  42.686026  41.126105  40.445731  40.805990
# 1    41.140971  41.454557  43.336937  40.668654  40.415952  39.848903
# 2    41.783406  41.859552  43.922835  41.751857  41.633804  39.494743
# 3    42.222410  41.837406  44.112127  43.627789  43.528017  41.434059
# 4    42.419415  41.653799  43.940188  45.328264  46.044949  44.776420
# 5    42.412118  42.368999  44.382057  47.535772  47.964387  47.404345
# 6    29.214414  28.588135  28.219073  26.635254  26.736445  34.909757
# 7    32.211761  33.149555  32.040571  33.179482  35.136509  40.743345
# 8    35.570554  33.638576  33.375928  31.276056  32.452232  34.694844
# 9    31.879174  31.499085  32.926160  36.476561  40.208370  38.608193
# 10   34.698522  36.271369  37.782554  42.524010  44.492953  44.109519
# 11   38.651428  39.099938  42.121071  52.056706  40.257511  41.758555
# ...

# %%
HPpotential01SUM=pd.DataFrame(HPpotential01.transpose().sum(axis=1), columns=['CF 0.1']) # sum all timesteps per carbon case

# %% [markdown]
# CF 0

# %%
HPop8_0=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL0/8000000/HP')
HPop8_0SUM=HPop8_0.sum(axis=1)

HPop6_0=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL0/6000000/HP')
HPop6_0SUM=HPop6_0.sum(axis=1)

HPpotential0 = pd.concat([HPop8_0SUM, HPop6_0SUM], axis=1)

HPop55_0=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL0/5500000/HP')
HPop55_0SUM=HPop55_0.sum(axis=1)

HPpotential0 = pd.concat([HPpotential0, HPop55_0SUM], axis=1)

HPop5_0=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL0/5000000/HP')
HPop5_0SUM=HPop5_0.sum(axis=1)

HPpotential0 = pd.concat([HPpotential0, HPop5_0SUM], axis=1)

HPop48_0=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL0/4800000/HP')
HPop48_0SUM=HPop48_0.sum(axis=1)

HPpotential0 = pd.concat([HPpotential0, HPop48_0SUM], axis=1)

HPop46_0=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL0/4600000/HP')
HPop46_0SUM=HPop46_0.sum(axis=1)

HPpotential0 = pd.concat([HPpotential0, HPop46_0SUM], axis=1)

HPop44_0=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL0/4400000/HP')
HPop44_0SUM=HPop44_0.sum(axis=1)

HPpotential0 = pd.concat([HPpotential0, HPop44_0SUM], axis=1)

HPop40_0=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL0/4000000/HP')
HPop40_0SUM=HPop40_0.sum(axis=1)

HPpotential0 = pd.concat([HPpotential0, HPop40_0SUM], axis=1)

HPop35_0=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL0/3500000/HP')
HPop35_0SUM=HPop35_0.sum(axis=1)

HPpotential0 = pd.concat([HPpotential0, HPop35_0SUM], axis=1)

HPop32_0=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL0/3200000/HP')
HPop32_0SUM=HPop32_0.sum(axis=1)

HPpotential0 = pd.concat([HPpotential0, HPop32_0SUM], axis=1)

HPop3_0=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL0/3000000/HP')
HPop3_0SUM=HPop3_0.sum(axis=1)

HPpotential0 = pd.concat([HPpotential0, HPop3_0SUM], axis=1)

HPop25_0=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL0/2500000/HP')
HPop25_0SUM=HPop25_0.sum(axis=1)

HPpotential0 = pd.concat([HPpotential0, HPop25_0SUM], axis=1)

HPop2_0=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL0/2000000/HP')
HPop2_0SUM=HPop2_0.sum(axis=1)

HPpotential0 = pd.concat([HPpotential0, HPop2_0SUM], axis=1)

HPop15_0=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL0/1500000/HP')
HPop15_0SUM=HPop15_0.sum(axis=1)

HPpotential0 = pd.concat([HPpotential0, HPop15_0SUM], axis=1)

HPop1_0=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL0/1000000/HP')
HPop1_0SUM=HPop1_0.sum(axis=1)

HPpotential0 = pd.concat([HPpotential0, HPop1_0SUM], axis=1)

HPop0_0=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL0/0/HP')
HPop0_0SUM=HPop0_0.sum(axis=1)

HPpotential0 = pd.concat([HPpotential0, HPop1_0SUM], axis=1)


HPpotential0.columns=["8000000", "6000000", "5500000", "5000000", "4800000", "4600000", "4400000", "4000000", "3500000", "3200000", "3000000", "2500000", "2000000", "1500000", "1000000", "0"]

HPpotential0
# Out:
#        8000000    6000000    5500000    5000000    4800000    4600000  \
# 0    40.800476  41.571954  40.931743  40.442429  42.460943  42.098946
# 1    40.869611  41.514064  39.994920  39.669791  41.274658  40.977497
# 2    41.659240  41.912544  41.574660  39.861550  44.172531  41.513549
# 3    42.260798  41.944098  44.035303  43.045833  44.811849  42.788308
# 4    42.216065  41.709764  43.229543  45.077469  45.181236  45.875092
# 5    42.381205  42.454205  44.457938  47.185929  46.854377  46.580843
# 6    27.966160  27.745232  29.320121  29.481682  25.555998  29.269818
# 7    31.626156  32.908641  32.540805  33.250221  31.964212  36.639844
# 8    34.430376  34.291192  33.528344  33.786593  31.647684  32.735939
# 9    32.763095  31.302123  31.765129  33.951362  34.536632  34.296465
# 10   36.226094  36.785888  34.127930  40.832113  40.838534  33.439264
# 11   38.502874  39.600950  40.327956  42.313421  50.199697  45.758044
# ...

# %%
HPpotential0SUM=pd.DataFrame(HPpotential0.transpose().sum(axis=1), columns=['CF 0']) # sum all timesteps per carbon case

# %% [markdown]
# # Gas boiler

# %% [markdown]
# CF 0.5

# %%
GBop8_05=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL05/8000000/Boiler')
GBop8_05SUM=GBop8_05.sum(axis=1)

GBop6_05=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL05/6000000/Boiler')
GBop6_05SUM=GBop6_05.sum(axis=1)

GBpotential05 = pd.concat([GBop8_05SUM, GBop6_05SUM], axis=1)

GBop55_05=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL05/5500000/Boiler')
GBop55_05SUM=GBop55_05.sum(axis=1)

GBpotential05 = pd.concat([GBpotential05, GBop55_05SUM], axis=1)

GBop5_05=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL05/5000000/Boiler')
GBop5_05SUM=GBop5_05.sum(axis=1)

GBpotential05 = pd.concat([GBpotential05, GBop5_05SUM], axis=1)

GBop48_05=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL05/4800000/Boiler')
GBop48_05SUM=GBop48_05.sum(axis=1)

GBpotential05 = pd.concat([GBpotential05, GBop48_05SUM], axis=1)

GBop46_05=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL05/4600000/Boiler')
GBop46_05SUM=GBop46_05.sum(axis=1)

GBpotential05 = pd.concat([GBpotential05, GBop46_05SUM], axis=1)


GBpotential05.columns=["8000000", "6000000", "5500000", "5000000", "4800000", "4600000"]

GBpotential05
# Out:
#        8000000   6000000   5500000   5000000  4800000   4600000
# 0     0.000000  0.000000  0.000000  0.000000        0  0.000000
# 1     0.000000  0.000000  0.000000  0.000000        0  0.000000
# 2     0.000000  0.000000  0.000000  0.000000        0  0.000000
# 3     0.000000  0.000000  0.000000  0.000000        0  0.000000
# 4     0.000000  0.000000  0.000000  0.000000        0  0.000000
# 5     0.000000  0.000000  0.000000  0.000000        0  0.000000
# 6     0.000000  0.000000  0.000000  0.000000        0  0.000000
# 7     0.000000  0.000000  0.000000  0.000000        0  0.000000
# 8     0.000000  0.000000  0.000000  0.000000        0  0.000000
# 9     0.000000  0.000000  0.000000  0.000000        0  0.000000
# 10    0.000000  0.000000  0.000000  0.000000        0  0.000000
# 11    0.000000  0.000000  0.000000  0.000000        0  0.000000
# 12    0.000000  0.000000  0.000000  0.000000        0  0.000000
# 13    0.000000  0.000000  0.000000  0.000000        0  0.000000
# ...

# %%
GBpotential05SUM=pd.DataFrame(GBpotential05.transpose().sum(axis=1), columns=['CF 0.5']) # sum all timesteps per carbon case

# %% [markdown]
# CF 0.4

# %%
GBop8_04=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL04/8000000/Boiler')
GBop8_04SUM=GBop8_04.sum(axis=1)

GBop6_04=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL04/6000000/Boiler')
GBop6_04SUM=GBop6_04.sum(axis=1)

GBpotential04 = pd.concat([GBop8_04SUM, GBop6_04SUM], axis=1)

GBop55_04=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL04/5500000/Boiler')
GBop55_04SUM=GBop55_04.sum(axis=1)

GBpotential04 = pd.concat([GBpotential04, GBop55_04SUM], axis=1)

GBop5_04=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL04/5000000/Boiler')
GBop5_04SUM=GBop5_04.sum(axis=1)

GBpotential04 = pd.concat([GBpotential04, GBop5_04SUM], axis=1)

GBop48_04=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL04/4800000/Boiler')
GBop48_04SUM=GBop48_04.sum(axis=1)

GBpotential04 = pd.concat([GBpotential04, GBop48_04SUM], axis=1)

GBop46_04=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL04/4600000/Boiler')
GBop46_04SUM=GBop46_04.sum(axis=1)

GBpotential04 = pd.concat([GBpotential04, GBop46_04SUM], axis=1)

GBop44_04=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL04/4400000/Boiler')
GBop44_04SUM=GBop44_04.sum(axis=1)

GBpotential04 = pd.concat([GBpotential04, GBop44_04SUM], axis=1)


GBpotential04.columns=["8000000", "6000000", "5500000", "5000000", "4800000", "4600000", "4400000"]

GBpotential04
# Out:
#        8000000    6000000   5500000   5000000   4800000    4600000    4400000
# 0     0.000000   0.000000  0.000000  0.000000  0.000000   0.000000   0.000000
# 1     0.000000   0.000000  0.000000  0.000000  0.000000   0.000000   0.000000
# 2     0.000000   0.000000  0.000000  0.000000  0.000000   0.000000   0.000000
# 3     0.000000   0.000000  0.000000  0.000000  0.000000   0.000000   0.000000
# 4     0.000000   0.000000  0.000000  0.000000  0.000000   0.000000   0.000000
# 5     0.000000   0.000000  0.000000  0.000000  0.000000   0.000000   0.000000
# 6     0.000000   0.000000  0.000000  0.000000  0.000000   0.000000   0.000000
# 7     0.000000   0.000000  0.000000  0.000000  0.000000   0.000000   0.000000
# 8     0.000000   0.000000  0.000000  0.000000  0.000000   0.000000   0.000000
# 9     0.000000   0.000000  0.000000  0.000000  0.000000   0.000000   0.000000
# 10    0.000000   0.000000  0.000000  0.000000  0.000000   0.000000   0.000000
# ...

# %%
GBpotential04SUM=pd.DataFrame(GBpotential04.transpose().sum(axis=1), columns=['CF 0.4']) # sum all timesteps per carbon case

# %% [markdown]
# CF 0.3

# %%
GBop8_03=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL03/8000000/Boiler')
GBop8_03SUM=GBop8_03.sum(axis=1)

GBop6_03=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL03/6000000/Boiler')
GBop6_03SUM=GBop6_03.sum(axis=1)

GBpotential03 = pd.concat([GBop8_03SUM, GBop6_03SUM], axis=1)

GBop55_03=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL03/5500000/Boiler')
GBop55_03SUM=GBop55_03.sum(axis=1)

GBpotential03 = pd.concat([GBpotential03, GBop55_03SUM], axis=1)

GBop5_03=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL03/5000000/Boiler')
GBop5_03SUM=GBop5_03.sum(axis=1)

GBpotential03 = pd.concat([GBpotential03, GBop5_03SUM], axis=1)

GBop48_03=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL03/4800000/Boiler')
GBop48_03SUM=GBop48_03.sum(axis=1)

GBpotential03 = pd.concat([GBpotential03, GBop48_03SUM], axis=1)

GBop46_03=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL03/4600000/Boiler')
GBop46_03SUM=GBop46_03.sum(axis=1)

GBpotential03 = pd.concat([GBpotential03, GBop46_03SUM], axis=1)

GBop44_03=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL03/4400000/Boiler')
GBop44_03SUM=GBop44_03.sum(axis=1)

GBpotential03 = pd.concat([GBpotential03, GBop44_03SUM], axis=1)

GBop40_03=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL03/4000000/Boiler')
GBop40_03SUM=GBop40_03.sum(axis=1)

GBpotential03 = pd.concat([GBpotential03, GBop40_03SUM], axis=1)

GBop35_03=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL03/3500000/Boiler')
GBop35_03SUM=GBop35_03.sum(axis=1)

GBpotential03 = pd.concat([GBpotential03, GBop35_03SUM], axis=1)

GBop32_03=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL03/3200000/Boiler')
GBop32_03SUM=GBop32_03.sum(axis=1)

GBpotential03 = pd.concat([GBpotential03, GBop32_03SUM], axis=1)


GBpotential03.columns=["8000000", "6000000", "5500000", "5000000", "4800000", "4600000", "4400000", "4000000", "3500000", "3200000"]

GBpotential03
# Out:
#        8000000    6000000   5500000   5000000   4800000   4600000  4400000  \
# 0     0.000000   0.000000  0.000000  0.000000  0.000000  0.000000    0.000
# 1     0.000000   0.000000  0.000000  0.000000  0.000000  0.000000    0.000
# 2     0.000000   0.000000  0.000000  0.000000  0.000000  0.000000    0.000
# 3     0.000000   0.000000  0.000000  0.000000  0.000000  0.000000    0.000
# 4     0.000000   0.000000  0.000000  0.000000  0.000000  0.000000    0.000
# 5     0.000000   0.000000  0.000000  0.000000  0.000000  0.000000    0.000
# 6     0.000000   0.000000  0.000000  0.000000  0.000000  0.000000    0.000
# 7     0.000000   0.000000  0.000000  0.000000  0.000000  0.000000    0.000
# 8     0.000000   0.000000  0.000000  0.000000  0.000000  0.000000    0.000
# 9     0.000000   0.000000  0.000000  0.000000  0.000000  0.000000    0.000
# 10    0.000000   0.000000  0.000000  0.000000  0.000000  0.000000    0.000
# ...

# %%
GBpotential03SUM=pd.DataFrame(GBpotential03.transpose().sum(axis=1), columns=['CF 0.3']) # sum all timesteps per carbon case

# %% [markdown]
# CF 0.2

# %%
GBop8_02=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL02/8000000/Boiler')
GBop8_02SUM=GBop8_02.sum(axis=1)

GBop6_02=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL02/6000000/Boiler')
GBop6_02SUM=GBop6_02.sum(axis=1)

GBpotential02 = pd.concat([GBop8_02SUM, GBop6_02SUM], axis=1)

GBop55_02=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL02/5500000/Boiler')
GBop55_02SUM=GBop55_02.sum(axis=1)

GBpotential02 = pd.concat([GBpotential02, GBop55_02SUM], axis=1)

GBop5_02=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL02/5000000/Boiler')
GBop5_02SUM=GBop5_02.sum(axis=1)

GBpotential02 = pd.concat([GBpotential02, GBop5_02SUM], axis=1)

GBop48_02=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL02/4800000/Boiler')
GBop48_02SUM=GBop48_02.sum(axis=1)

GBpotential02 = pd.concat([GBpotential02, GBop48_02SUM], axis=1)

GBop46_02=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL02/4600000/Boiler')
GBop46_02SUM=GBop46_02.sum(axis=1)

GBpotential02 = pd.concat([GBpotential02, GBop46_02SUM], axis=1)

GBop44_02=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL02/4400000/Boiler')
GBop44_02SUM=GBop44_02.sum(axis=1)

GBpotential02 = pd.concat([GBpotential02, GBop44_02SUM], axis=1)

GBop40_02=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL02/4000000/Boiler')
GBop40_02SUM=GBop40_02.sum(axis=1)

GBpotential02 = pd.concat([GBpotential02, GBop40_02SUM], axis=1)

GBop35_02=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL02/3500000/Boiler')
GBop35_02SUM=GBop35_02.sum(axis=1)

GBpotential02 = pd.concat([GBpotential02, GBop35_02SUM], axis=1)

GBop32_02=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL02/3200000/Boiler')
GBop32_02SUM=GBop32_02.sum(axis=1)

GBpotential02 = pd.concat([GBpotential02, GBop32_02SUM], axis=1)

GBop3_02=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL02/3000000/Boiler')
GBop3_02SUM=GBop3_02.sum(axis=1)

GBpotential02 = pd.concat([GBpotential02, GBop3_02SUM], axis=1)

GBop25_02=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL02/2500000/Boiler')
GBop25_02SUM=GBop25_02.sum(axis=1)

GBpotential02 = pd.concat([GBpotential02, GBop25_02SUM], axis=1)


GBpotential02.columns=["8000000", "6000000", "5500000", "5000000", "4800000", "4600000", "4400000", "4000000", "3500000", "3200000", "3000000", "2500000"]

GBpotential02
# Out:
#        8000000    6000000   5500000   5000000   4800000   4600000   4400000  \
# 0     0.000000   0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 1     0.000000   0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 2     0.000000   0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 3     0.000000   0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 4     0.000000   0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 5     0.000000   0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 6     0.000000   0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 7     0.000000   0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 8     0.000000   0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 9     0.000000   0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 10    0.000000   0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# ...

# %%
GBpotential02SUM=pd.DataFrame(GBpotential02.transpose().sum(axis=1), columns=['CF 0.2']) # sum all timesteps per carbon case

# %% [markdown]
# CF 0.1

# %%
GBop8_01=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL01/8000000/Boiler')
GBop8_01SUM=GBop8_01.sum(axis=1)

GBop6_01=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL01/6000000/Boiler')
GBop6_01SUM=GBop6_01.sum(axis=1)

GBpotential01 = pd.concat([GBop8_01SUM, GBop6_01SUM], axis=1)

GBop55_01=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL01/5500000/Boiler')
GBop55_01SUM=GBop55_01.sum(axis=1)

GBpotential01 = pd.concat([GBpotential01, GBop55_01SUM], axis=1)

GBop5_01=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL01/5000000/Boiler')
GBop5_01SUM=GBop5_01.sum(axis=1)

GBpotential01 = pd.concat([GBpotential01, GBop5_01SUM], axis=1)

GBop48_01=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL01/4800000/Boiler')
GBop48_01SUM=GBop48_01.sum(axis=1)

GBpotential01 = pd.concat([GBpotential01, GBop48_01SUM], axis=1)

GBop46_01=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL01/4600000/Boiler')
GBop46_01SUM=GBop46_01.sum(axis=1)

GBpotential01 = pd.concat([GBpotential01, GBop46_01SUM], axis=1)

GBop44_01=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL01/4400000/Boiler')
GBop44_01SUM=GBop44_01.sum(axis=1)

GBpotential01 = pd.concat([GBpotential01, GBop44_01SUM], axis=1)

GBop40_01=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL01/4000000/Boiler')
GBop40_01SUM=GBop40_01.sum(axis=1)

GBpotential01 = pd.concat([GBpotential01, GBop40_01SUM], axis=1)

GBop35_01=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL01/3500000/Boiler')
GBop35_01SUM=GBop35_01.sum(axis=1)

GBpotential01 = pd.concat([GBpotential01, GBop35_01SUM], axis=1)

GBop32_01=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL01/3200000/Boiler')
GBop32_01SUM=GBop32_01.sum(axis=1)

GBpotential01 = pd.concat([GBpotential01, GBop32_01SUM], axis=1)

GBop3_01=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL01/3000000/Boiler')
GBop3_01SUM=GBop3_01.sum(axis=1)

GBpotential01 = pd.concat([GBpotential01, GBop3_01SUM], axis=1)

GBop25_01=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL01/2500000/Boiler')
GBop25_01SUM=GBop25_01.sum(axis=1)

GBpotential01 = pd.concat([GBpotential01, GBop25_01SUM], axis=1)

GBop2_01=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL01/2000000/Boiler')
GBop2_01SUM=GBop2_01.sum(axis=1)

GBpotential01 = pd.concat([GBpotential01, GBop2_01SUM], axis=1)

GBop15_01=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL01/1500000/Boiler')
GBop15_01SUM=GBop15_01.sum(axis=1)

GBpotential01 = pd.concat([GBpotential01, GBop15_01SUM], axis=1)


GBpotential01.columns=["8000000", "6000000", "5500000", "5000000", "4800000", "4600000", "4400000", "4000000", "3500000", "3200000", "3000000", "2500000", "2000000", "1500000"]

GBpotential01
# Out:
#        8000000    6000000    5500000    5000000   4800000    4600000  \
# 0     0.000000   0.000000   0.000000   0.000000  0.000000   0.000000
# 1     0.000000   0.000000   0.000000   0.000000  0.000000   0.000000
# 2     0.000000   0.000000   0.000000   0.000000  0.000000   0.000000
# 3     0.000000   0.000000   0.000000   0.000000  0.000000   0.000000
# 4     0.000000   0.000000   0.000000   0.000000  0.000000   0.000000
# 5     0.000000   0.000000   0.000000   0.000000  0.000000   0.000000
# 6     0.000000   0.000000   0.000000   0.000000  0.000000   0.000000
# 7     0.000000   0.000000   0.000000   0.000000  0.000000   0.000000
# 8     0.000000   0.000000   0.000000   0.000000  0.000000   0.000000
# 9     0.000000   0.000000   0.000000   0.000000  0.000000   0.000000
# 10    0.000000   0.000000   0.000000   0.000000  0.000000   0.000000
# 11    0.000000   0.000000   0.000000   0.000000  0.000000   0.000000
# 12    0.000000   0.000000   0.000000   0.000000  0.000000   0.000000
# ...

# %%
GBpotential01SUM=pd.DataFrame(GBpotential01.transpose().sum(axis=1), columns=['CF 0.1']) # sum all timesteps per carbon case

# %% [markdown]
# CF 0

# %%
GBop8_0=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL0/8000000/Boiler')
GBop8_0SUM=GBop8_0.sum(axis=1)

GBop6_0=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL0/6000000/Boiler')
GBop6_0SUM=GBop6_0.sum(axis=1)

GBpotential0 = pd.concat([GBop8_0SUM, GBop6_0SUM], axis=1)

GBop55_0=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL0/5500000/Boiler')
GBop55_0SUM=GBop55_0.sum(axis=1)

GBpotential0 = pd.concat([GBpotential0, GBop55_0SUM], axis=1)

GBop5_0=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL0/5000000/Boiler')
GBop5_0SUM=GBop5_0.sum(axis=1)

GBpotential0 = pd.concat([GBpotential0, GBop5_0SUM], axis=1)

GBop48_0=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL0/4800000/Boiler')
GBop48_0SUM=GBop48_0.sum(axis=1)

GBpotential0 = pd.concat([GBpotential0, GBop48_0SUM], axis=1)

GBop46_0=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL0/4600000/Boiler')
GBop46_0SUM=GBop46_0.sum(axis=1)

GBpotential0 = pd.concat([GBpotential0, GBop46_0SUM], axis=1)

GBop44_0=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL0/4400000/Boiler')
GBop44_0SUM=GBop44_0.sum(axis=1)

GBpotential0 = pd.concat([GBpotential0, GBop44_0SUM], axis=1)

GBop40_0=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL0/4000000/Boiler')
GBop40_0SUM=GBop40_0.sum(axis=1)

GBpotential0 = pd.concat([GBpotential0, GBop40_0SUM], axis=1)

GBop35_0=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL0/3500000/Boiler')
GBop35_0SUM=GBop35_0.sum(axis=1)

GBpotential0 = pd.concat([GBpotential0, GBop35_0SUM], axis=1)

GBop32_0=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL0/3200000/Boiler')
GBop32_0SUM=GBop32_0.sum(axis=1)

GBpotential0 = pd.concat([GBpotential0, GBop32_0SUM], axis=1)

GBop3_0=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL0/3000000/Boiler')
GBop3_0SUM=GBop3_0.sum(axis=1)

GBpotential0 = pd.concat([GBpotential0, GBop3_0SUM], axis=1)

GBop25_0=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL0/2500000/Boiler')
GBop25_0SUM=GBop25_0.sum(axis=1)

GBpotential0 = pd.concat([GBpotential0, GBop25_0SUM], axis=1)

GBop2_0=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL0/2000000/Boiler')
GBop2_0SUM=GBop2_0.sum(axis=1)

GBpotential0 = pd.concat([GBpotential0, GBop2_0SUM], axis=1)

GBop15_0=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL0/1500000/Boiler')
GBop15_0SUM=GBop15_0.sum(axis=1)

GBpotential0 = pd.concat([GBpotential0, GBop15_0SUM], axis=1)

GBop1_0=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL0/1000000/Boiler')
GBop1_0SUM=GBop1_0.sum(axis=1)

GBpotential0 = pd.concat([GBpotential0, GBop1_0SUM], axis=1)

GBop0_0=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL0/0/Boiler')
GBop0_0SUM=GBop0_0.sum(axis=1)

GBpotential0 = pd.concat([GBpotential0, GBop1_0SUM], axis=1)


GBpotential0.columns=["8000000", "6000000", "5500000", "5000000", "4800000", "4600000", "4400000", "4000000", "3500000", "3200000", "3000000", "2500000", "2000000", "1500000", "1000000", "0"]

GBpotential0
# Out:
#        8000000    6000000    5500000    5000000    4800000    4600000  \
# 0     0.000000   0.000000   0.000000   0.000000   0.000000   0.000000
# 1     0.000000   0.000000   0.000000   0.000000   0.000000   0.000000
# 2     0.000000   0.000000   0.000000   0.000000   0.000000   0.000000
# 3     0.000000   0.000000   0.000000   0.000000   0.000000   0.000000
# 4     0.000000   0.000000   0.000000   0.000000   0.000000   0.000000
# 5     0.000000   0.000000   0.000000   0.000000   0.000000   0.000000
# 6     0.000000   0.000000   0.000000   0.000000   0.000000   0.000000
# 7     0.000000   0.000000   0.000000   0.000000   0.000000   0.000000
# 8     0.000000   0.000000   0.000000   0.000000   0.000000   0.000000
# 9     0.000000   0.000000   0.000000   0.000000   0.000000   0.000000
# 10    0.000000   0.000000   0.000000   0.000000   0.000000   0.000000
# 11    0.000000   0.000000   0.000000   0.000000   0.000000   0.000000
# ...

# %%
GBpotential0SUM=pd.DataFrame(GBpotential0.transpose().sum(axis=1), columns=['CF 0']) # sum all timesteps per carbon case

# %% [markdown]
# # CHP

# %% [markdown]
# CF 0.5

# %%
CHPop8_05=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL05/8000000/CHP')
CHPop8_05SUM=CHPop8_05.sum(axis=1)

CHPop6_05=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL05/6000000/CHP')
CHPop6_05SUM=CHPop6_05.sum(axis=1)

CHPpotential05 = pd.concat([CHPop8_05SUM, CHPop6_05SUM], axis=1)

CHPop55_05=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL05/5500000/CHP')
CHPop55_05SUM=CHPop55_05.sum(axis=1)

CHPpotential05 = pd.concat([CHPpotential05, CHPop55_05SUM], axis=1)

CHPop5_05=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL05/5000000/CHP')
CHPop5_05SUM=CHPop5_05.sum(axis=1)

CHPpotential05 = pd.concat([CHPpotential05, CHPop5_05SUM], axis=1)

CHPop48_05=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL05/4800000/CHP')
CHPop48_05SUM=CHPop48_05.sum(axis=1)

CHPpotential05 = pd.concat([CHPpotential05, CHPop48_05SUM], axis=1)

CHPop46_05=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL05/4600000/CHP')
CHPop46_05SUM=CHPop46_05.sum(axis=1)

CHPpotential05 = pd.concat([CHPpotential05, CHPop46_05SUM], axis=1)


CHPpotential05.columns=["8000000", "6000000", "5500000", "5000000", "4800000", "4600000"]

CHPpotential05
# Out:
#         8000000     6000000     5500000     5000000     4800000     4600000
# 0     87.867559   86.991517   87.124124   88.896004   86.170407   86.748178
# 1     89.204202   87.122186   86.992612   86.189117   87.147701   87.289857
# 2     88.542258   87.253946   85.328235   85.988039   85.712286   85.202000
# 3     88.586944   91.343934   85.377132   84.687038   83.349253   84.526000
# 4     89.430592   91.439483   87.574627   89.629167   85.665599   86.038000
# 5     89.524453   98.269285   97.160530   97.065487   94.986154   87.324726
# 6     98.720439  100.340859   97.163111   97.555392   98.429850  106.045130
# 7     93.861602  100.024250   95.101190   94.169440   97.149622   99.050612
# 8     94.696690  102.628654   93.520758   93.337825   94.952023   93.767722
# 9     91.071182   95.555189   88.392903   82.256252   69.896873   80.087191
# 10    73.762868   63.483437   36.534234    4.798194    3.319000    9.194667
# ...

# %%
CHPpotential05SUM=pd.DataFrame(CHPpotential05.transpose().sum(axis=1), columns=['CF 0.5']) # sum all timesteps per carbon case

# %% [markdown]
# CF 0.4

# %%
CHPop8_04=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL04/8000000/CHP')
CHPop8_04SUM=CHPop8_04.sum(axis=1)

CHPop6_04=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL04/6000000/CHP')
CHPop6_04SUM=CHPop6_04.sum(axis=1)

CHPpotential04 = pd.concat([CHPop8_04SUM, CHPop6_04SUM], axis=1)

CHPop55_04=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL04/5500000/CHP')
CHPop55_04SUM=CHPop55_04.sum(axis=1)

CHPpotential04 = pd.concat([CHPpotential04, CHPop55_04SUM], axis=1)

CHPop5_04=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL04/5000000/CHP')
CHPop5_04SUM=CHPop5_04.sum(axis=1)

CHPpotential04 = pd.concat([CHPpotential04, CHPop5_04SUM], axis=1)

CHPop48_04=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL04/4800000/CHP')
CHPop48_04SUM=CHPop48_04.sum(axis=1)

CHPpotential04 = pd.concat([CHPpotential04, CHPop48_04SUM], axis=1)

CHPop46_04=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL04/4600000/CHP')
CHPop46_04SUM=CHPop46_04.sum(axis=1)

CHPpotential04 = pd.concat([CHPpotential04, CHPop46_04SUM], axis=1)

CHPop44_04=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL04/4400000/CHP')
CHPop44_04SUM=CHPop44_04.sum(axis=1)

CHPpotential04 = pd.concat([CHPpotential04, CHPop44_04SUM], axis=1)


CHPpotential04.columns=["8000000", "6000000", "5500000", "5000000", "4800000", "4600000", "4400000"]

CHPpotential04
# Out:
#         8000000     6000000     5500000     5000000     4800000     4600000  \
# 0     88.260340   90.458496   87.231642   87.991832   88.036999   88.083304
# 1     89.134817   92.086657   86.888444   86.616778   86.744690   85.758567
# 2     87.841345   91.081589   85.752876   85.295219   86.140495   89.456174
# 3     88.244024   94.147276   87.765549   85.764342   85.457500   86.201117
# 4     88.994583   94.055483   91.437736   91.718658   92.846322   91.953907
# 5     89.009355   94.042178   96.524351   96.379299   97.312050   97.668945
# 6     98.471757  100.094135   95.788005   95.581873   96.052511   93.670795
# 7     96.849881   99.633156   96.521136   92.907341   92.517279   90.633067
# 8     96.608546  101.259117   97.212145   92.947195   90.661123   88.114211
# 9     91.014978   94.059783   92.399335   90.056126   83.237083   74.597706
# 10    75.227425   67.500363   66.733322   21.882539   16.595451    4.927930
# ...

# %%
CHPpotential04SUM=pd.DataFrame(CHPpotential04.transpose().sum(axis=1), columns=['CF 0.4']) # sum all timesteps per carbon case

# %% [markdown]
# CF 0.3

# %%
CHPop8_03=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL03/8000000/CHP')
CHPop8_03SUM=CHPop8_03.sum(axis=1)

CHPop6_03=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL03/6000000/CHP')
CHPop6_03SUM=CHPop6_03.sum(axis=1)

CHPpotential03 = pd.concat([CHPop8_03SUM, CHPop6_03SUM], axis=1)

CHPop55_03=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL03/5500000/CHP')
CHPop55_03SUM=CHPop55_03.sum(axis=1)

CHPpotential03 = pd.concat([CHPpotential03, CHPop55_03SUM], axis=1)

CHPop5_03=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL03/5000000/CHP')
CHPop5_03SUM=CHPop5_03.sum(axis=1)

CHPpotential03 = pd.concat([CHPpotential03, CHPop5_03SUM], axis=1)

CHPop48_03=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL03/4800000/CHP')
CHPop48_03SUM=CHPop48_03.sum(axis=1)

CHPpotential03 = pd.concat([CHPpotential03, CHPop48_03SUM], axis=1)

CHPop46_03=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL03/4600000/CHP')
CHPop46_03SUM=CHPop46_03.sum(axis=1)

CHPpotential03 = pd.concat([CHPpotential03, CHPop46_03SUM], axis=1)

CHPop44_03=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL03/4400000/CHP')
CHPop44_03SUM=CHPop44_03.sum(axis=1)

CHPpotential03 = pd.concat([CHPpotential03, CHPop44_03SUM], axis=1)

CHPop40_03=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL03/4000000/CHP')
CHPop40_03SUM=CHPop40_03.sum(axis=1)

CHPpotential03 = pd.concat([CHPpotential03, CHPop40_03SUM], axis=1)

CHPop35_03=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL03/3500000/CHP')
CHPop35_03SUM=CHPop35_03.sum(axis=1)

CHPpotential03 = pd.concat([CHPpotential03, CHPop35_03SUM], axis=1)

CHPop32_03=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL03/3200000/CHP')
CHPop32_03SUM=CHPop32_03.sum(axis=1)

CHPpotential03 = pd.concat([CHPpotential03, CHPop32_03SUM], axis=1)


CHPpotential03.columns=["8000000", "6000000", "5500000", "5000000", "4800000", "4600000", "4400000", "4000000", "3500000", "3200000"]

CHPpotential03
# Out:
#         8000000     6000000     5500000     5000000    4800000    4600000  \
# 0     87.616987   89.793070   88.296368   87.052329  86.748537  84.667305
# 1     88.963328   91.743594   90.152578   87.128551  87.397606  85.046402
# 2     87.976697   90.127365   89.884089   86.575649  86.540001  84.785146
# 3     88.286371   92.111524   94.439992   87.793819  88.332161  83.706975
# 4     89.269011   92.347209   95.259007   93.138913  92.814295  86.730120
# 5     88.526933   92.413593   96.248207   95.876102  95.054842  87.576975
# 6     99.186654  101.965401   98.090082   95.444122  92.118871  85.158435
# 7     95.485092   98.198427   98.832200   93.029962  91.248497  85.206070
# 8     98.344588   98.420958  100.482057   91.719556  89.773347  84.893643
# 9     91.292411   91.127086   92.633104   88.956031  85.497012  79.390111
# 10    73.955812   73.645488   68.835115   49.067337  40.305618  29.674764
# 11    63.911516   51.689839   37.415691   20.174409  14.839485   5.194507
# ...

# %%
CHPpotential03SUM=pd.DataFrame(CHPpotential03.transpose().sum(axis=1), columns=['CF 0.3']) # sum all timesteps per carbon case

# %% [markdown]
# CF 0.2

# %%
CHPop8_02=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL02/8000000/CHP')
CHPop8_02SUM=CHPop8_02.sum(axis=1)

CHPop6_02=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL02/6000000/CHP')
CHPop6_02SUM=CHPop6_02.sum(axis=1)

CHPpotential02 = pd.concat([CHPop8_02SUM, CHPop6_02SUM], axis=1)

CHPop55_02=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL02/5500000/CHP')
CHPop55_02SUM=CHPop55_02.sum(axis=1)

CHPpotential02 = pd.concat([CHPpotential02, CHPop55_02SUM], axis=1)

CHPop5_02=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL02/5000000/CHP')
CHPop5_02SUM=CHPop5_02.sum(axis=1)

CHPpotential02 = pd.concat([CHPpotential02, CHPop5_02SUM], axis=1)

CHPop48_02=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL02/4800000/CHP')
CHPop48_02SUM=CHPop48_02.sum(axis=1)

CHPpotential02 = pd.concat([CHPpotential02, CHPop48_02SUM], axis=1)

CHPop46_02=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL02/4600000/CHP')
CHPop46_02SUM=CHPop46_02.sum(axis=1)

CHPpotential02 = pd.concat([CHPpotential02, CHPop46_02SUM], axis=1)

CHPop44_02=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL02/4400000/CHP')
CHPop44_02SUM=CHPop44_02.sum(axis=1)

CHPpotential02 = pd.concat([CHPpotential02, CHPop44_02SUM], axis=1)

CHPop40_02=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL02/4000000/CHP')
CHPop40_02SUM=CHPop40_02.sum(axis=1)

CHPpotential02 = pd.concat([CHPpotential02, CHPop40_02SUM], axis=1)

CHPop35_02=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL02/3500000/CHP')
CHPop35_02SUM=CHPop35_02.sum(axis=1)

CHPpotential02 = pd.concat([CHPpotential02, CHPop35_02SUM], axis=1)

CHPop32_02=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL02/3200000/CHP')
CHPop32_02SUM=CHPop32_02.sum(axis=1)

CHPpotential02 = pd.concat([CHPpotential02, CHPop32_02SUM], axis=1)

CHPop3_02=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL02/3000000/CHP')
CHPop3_02SUM=CHPop3_02.sum(axis=1)

CHPpotential02 = pd.concat([CHPpotential02, CHPop3_02SUM], axis=1)

CHPop25_02=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL02/2500000/CHP')
CHPop25_02SUM=CHPop25_02.sum(axis=1)

CHPpotential02 = pd.concat([CHPpotential02, CHPop25_02SUM], axis=1)


CHPpotential02.columns=["8000000", "6000000", "5500000", "5000000", "4800000", "4600000", "4400000", "4000000", "3500000", "3200000", "3000000", "2500000"]

CHPpotential02
# Out:
#         8000000     6000000     5500000     5000000    4800000    4600000  \
# 0     88.172467   88.147413   88.309260   87.094072  84.746579  84.368299
# 1     89.028711   88.009384   87.814685   87.665561  84.858853  83.705352
# 2     87.709505   87.840529   89.727476   86.425424  86.265177  83.788063
# 3     88.481146   89.647249   91.340617   88.066974  87.158708  84.048543
# 4     88.887627   90.430414   91.796344   92.280392  87.821926  84.587167
# 5     88.843208   90.681516   93.230866   95.646272  87.731874  84.587167
# 6     98.234739   97.009238   97.277617   93.922678  84.868979  82.743052
# 7     97.030478   95.181644   95.814527   94.899637  86.224672  82.864228
# 8     97.185292   96.592662   97.852146   94.477989  86.517150  82.838745
# 9     90.983808   89.930956   90.860027   92.118062  79.679882  77.438431
# 10    75.108397   74.445376   72.113886   63.895586  51.159503  50.332147
# 11    64.820659   65.080234   55.335993   34.257520  33.870790  25.541619
# ...

# %%
CHPpotential02SUM=pd.DataFrame(CHPpotential02.transpose().sum(axis=1), columns=['CF 0.2']) # sum all timesteps per carbon case

# %% [markdown]
# CF 0.1

# %%
CHPop8_01=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL01/8000000/CHP')
CHPop8_01SUM=CHPop8_01.sum(axis=1)

CHPop6_01=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL01/6000000/CHP')
CHPop6_01SUM=CHPop6_01.sum(axis=1)

CHPpotential01 = pd.concat([CHPop8_01SUM, CHPop6_01SUM], axis=1)

CHPop55_01=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL01/5500000/CHP')
CHPop55_01SUM=CHPop55_01.sum(axis=1)

CHPpotential01 = pd.concat([CHPpotential01, CHPop55_01SUM], axis=1)

CHPop5_01=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL01/5000000/CHP')
CHPop5_01SUM=CHPop5_01.sum(axis=1)

CHPpotential01 = pd.concat([CHPpotential01, CHPop5_01SUM], axis=1)

CHPop48_01=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL01/4800000/CHP')
CHPop48_01SUM=CHPop48_01.sum(axis=1)

CHPpotential01 = pd.concat([CHPpotential01, CHPop48_01SUM], axis=1)

CHPop46_01=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL01/4600000/CHP')
CHPop46_01SUM=CHPop46_01.sum(axis=1)

CHPpotential01 = pd.concat([CHPpotential01, CHPop46_01SUM], axis=1)

CHPop44_01=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL01/4400000/CHP')
CHPop44_01SUM=CHPop44_01.sum(axis=1)

CHPpotential01 = pd.concat([CHPpotential01, CHPop44_01SUM], axis=1)

CHPop40_01=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL01/4000000/CHP')
CHPop40_01SUM=CHPop40_01.sum(axis=1)

CHPpotential01 = pd.concat([CHPpotential01, CHPop40_01SUM], axis=1)

CHPop35_01=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL01/3500000/CHP')
CHPop35_01SUM=CHPop35_01.sum(axis=1)

CHPpotential01 = pd.concat([CHPpotential01, CHPop35_01SUM], axis=1)

CHPop32_01=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL01/3200000/CHP')
CHPop32_01SUM=CHPop32_01.sum(axis=1)

CHPpotential01 = pd.concat([CHPpotential01, CHPop32_01SUM], axis=1)

CHPop3_01=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL01/3000000/CHP')
CHPop3_01SUM=CHPop3_01.sum(axis=1)

CHPpotential01 = pd.concat([CHPpotential01, CHPop3_01SUM], axis=1)

CHPop25_01=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL01/2500000/CHP')
CHPop25_01SUM=CHPop25_01.sum(axis=1)

CHPpotential01 = pd.concat([CHPpotential01, CHPop25_01SUM], axis=1)

CHPop2_01=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL01/2000000/CHP')
CHPop2_01SUM=CHPop2_01.sum(axis=1)

CHPpotential01 = pd.concat([CHPpotential01, CHPop2_01SUM], axis=1)

CHPop15_01=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL01/1500000/CHP')
CHPop15_01SUM=CHPop15_01.sum(axis=1)

CHPpotential01 = pd.concat([CHPpotential01, CHPop15_01SUM], axis=1)


CHPpotential01.columns=["8000000", "6000000", "5500000", "5000000", "4800000", "4600000", "4400000", "4000000", "3500000", "3200000", "3000000", "2500000", "2000000", "1500000"]

CHPpotential01
# Out:
#         8000000     6000000     5500000    5000000     4800000    4600000  \
# 0     88.106738   88.509918   89.656026  87.927177   87.385731  87.704478
# 1     88.990971   89.304557   91.186937  87.849354   88.265952  86.647452
# 2     87.983406   88.049552   90.112835  87.941857   87.823804  85.684743
# 3     88.232410   87.847406   90.122127  89.519659   89.538017  87.273756
# 4     89.319415   88.553799   90.840188  92.228264   92.944949  90.533274
# 5     88.672118   88.628999   90.642057  93.483166   94.224387  91.722941
# 6    100.108153   99.239604   97.850881  91.886064   93.572628  89.232595
# 7     95.887682   96.969856   94.508001  92.774613   94.660969  90.022393
# 8     98.973124   96.880312   95.883604  90.417220   93.613731  87.902142
# 9     90.556701   91.819644   90.446611  85.701429   89.353090  82.797742
# 10    72.073262   74.607612   72.686322  69.362496   65.689311  61.290285
# 11    63.734725   64.247170   60.851543  57.314735   37.943403  33.643495
# ...

# %%
CHPpotential01SUM=pd.DataFrame(CHPpotential01.transpose().sum(axis=1), columns=['CF 0.1']) # sum all timesteps per carbon case

# %% [markdown]
# CF 0

# %%
CHPop8_0=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL0/8000000/CHP')
CHPop8_0SUM=CHPop8_0.sum(axis=1)

CHPop6_0=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL0/6000000/CHP')
CHPop6_0SUM=CHPop6_0.sum(axis=1)

CHPpotential0 = pd.concat([CHPop8_0SUM, CHPop6_0SUM], axis=1)

CHPop55_0=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL0/5500000/CHP')
CHPop55_0SUM=CHPop55_0.sum(axis=1)

CHPpotential0 = pd.concat([CHPpotential0, CHPop55_0SUM], axis=1)

CHPop5_0=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL0/5000000/CHP')
CHPop5_0SUM=CHPop5_0.sum(axis=1)

CHPpotential0 = pd.concat([CHPpotential0, CHPop5_0SUM], axis=1)

CHPop48_0=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL0/4800000/CHP')
CHPop48_0SUM=CHPop48_0.sum(axis=1)

CHPpotential0 = pd.concat([CHPpotential0, CHPop48_0SUM], axis=1)

CHPop46_0=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL0/4600000/CHP')
CHPop46_0SUM=CHPop46_0.sum(axis=1)

CHPpotential0 = pd.concat([CHPpotential0, CHPop46_0SUM], axis=1)

CHPop44_0=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL0/4400000/CHP')
CHPop44_0SUM=CHPop44_0.sum(axis=1)

CHPpotential0 = pd.concat([CHPpotential0, CHPop44_0SUM], axis=1)

CHPop40_0=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL0/4000000/CHP')
CHPop40_0SUM=CHPop40_0.sum(axis=1)

CHPpotential0 = pd.concat([CHPpotential0, CHPop40_0SUM], axis=1)

CHPop35_0=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL0/3500000/CHP')
CHPop35_0SUM=CHPop35_0.sum(axis=1)

CHPpotential0 = pd.concat([CHPpotential0, CHPop35_0SUM], axis=1)

CHPop32_0=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL0/3200000/CHP')
CHPop32_0SUM=CHPop32_0.sum(axis=1)

CHPpotential0 = pd.concat([CHPpotential0, CHPop32_0SUM], axis=1)

CHPop3_0=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL0/3000000/CHP')
CHPop3_0SUM=CHPop3_0.sum(axis=1)

CHPpotential0 = pd.concat([CHPpotential0, CHPop3_0SUM], axis=1)

CHPop25_0=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL0/2500000/CHP')
CHPop25_0SUM=CHPop25_0.sum(axis=1)

CHPpotential0 = pd.concat([CHPpotential0, CHPop25_0SUM], axis=1)

CHPop2_0=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL0/2000000/CHP')
CHPop2_0SUM=CHPop2_0.sum(axis=1)

CHPpotential0 = pd.concat([CHPpotential0, CHPop2_0SUM], axis=1)

CHPop15_0=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL0/1500000/CHP')
CHPop15_0SUM=CHPop15_0.sum(axis=1)

CHPpotential0 = pd.concat([CHPpotential0, CHPop15_0SUM], axis=1)

CHPop1_0=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL0/1000000/CHP')
CHPop1_0SUM=CHPop1_0.sum(axis=1)

CHPpotential0 = pd.concat([CHPpotential0, CHPop1_0SUM], axis=1)

CHPop0_0=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','Operation/NORM_RelaxedUniInt_CHPboiler_noPWL0/0/CHP')
CHPop0_0SUM=CHPop0_0.sum(axis=1)

CHPpotential0 = pd.concat([CHPpotential0, CHPop1_0SUM], axis=1)


CHPpotential0.columns=["8000000", "6000000", "5500000", "5000000", "4800000", "4600000", "4400000", "4000000", "3500000", "3200000", "3000000", "2500000", "2000000", "1500000", "1000000", "0"]

CHPpotential0
# Out:
#         8000000     6000000     5500000     5000000    4800000    4600000  \
# 0     87.770476   88.541954   87.901743   87.412429  88.782215  87.616085
# 1     88.719611   89.364064   87.844920   87.519791  88.228379  88.062835
# 2     87.849240   88.102544   87.764660   86.051550  90.362531  87.661946
# 3     88.270798   87.954098   90.045303   89.055833  90.435182  88.456682
# 4     89.116065   88.609764   90.129543   91.977469  91.926262  92.294727
# 5     88.641205   88.714205   90.717938   93.445929  92.677838  92.482947
# 6     99.056990   98.772946   97.941966   97.489321  90.433850  89.490670
# 7     95.641163   96.497584   94.935322   94.802321  90.326956  90.012593
# 8     97.766671   97.485142   95.906805   96.124024  89.753960  88.653158
# 9     91.359560   91.683105   90.539872   89.496988  85.865737  83.821597
# 10    76.086637   75.439882   73.796852   74.639116  70.441129  61.028582
# 11    64.424737   65.339895   66.717094   58.884478  61.349720  53.042444
# ...

# %%
CHPpotential0SUM=pd.DataFrame(CHPpotential0.transpose().sum(axis=1), columns=['CF 0']) # sum all timesteps per carbon case

# %% [markdown]
# # SUM

# %%
HPpotential05SUM=pd.DataFrame(HPpotential05.transpose().sum(axis=1), columns=['CF 0.5']) # sum all timesteps per carbon case
HPpotential04SUM=pd.DataFrame(HPpotential04.transpose().sum(axis=1), columns=['CF 0.4']) # sum all timesteps per carbon case
HPpotential03SUM=pd.DataFrame(HPpotential03.transpose().sum(axis=1), columns=['CF 0.3']) # sum all timesteps per carbon case
HPpotential02SUM=pd.DataFrame(HPpotential02.transpose().sum(axis=1), columns=['CF 0.2']) # sum all timesteps per carbon case
HPpotential01SUM=pd.DataFrame(HPpotential01.transpose().sum(axis=1), columns=['CF 0.1']) # sum all timesteps per carbon case
HPpotential0SUM=pd.DataFrame(HPpotential0.transpose().sum(axis=1), columns=['CF 0']) # sum all timesteps per carbon case

CHPpotential05SUM=pd.DataFrame(CHPpotential05.transpose().sum(axis=1), columns=['CF 0.5']) # sum all timesteps per carbon case
CHPpotential04SUM=pd.DataFrame(CHPpotential04.transpose().sum(axis=1), columns=['CF 0.4']) # sum all timesteps per carbon case
CHPpotential03SUM=pd.DataFrame(CHPpotential03.transpose().sum(axis=1), columns=['CF 0.3']) # sum all timesteps per carbon case
CHPpotential02SUM=pd.DataFrame(CHPpotential02.transpose().sum(axis=1), columns=['CF 0.2']) # sum all timesteps per carbon case
CHPpotential01SUM=pd.DataFrame(CHPpotential01.transpose().sum(axis=1), columns=['CF 0.1']) # sum all timesteps per carbon case
CHPpotential0SUM=pd.DataFrame(CHPpotential0.transpose().sum(axis=1), columns=['CF 0']) # sum all timesteps per carbon case

PVpotential05SUM=pd.DataFrame(PVpotential05.transpose().sum(axis=1), columns=['CF 0.5']) # sum all timesteps per carbon case
PVpotential04SUM=pd.DataFrame(PVpotential04.transpose().sum(axis=1), columns=['CF 0.4']) # sum all timesteps per carbon case
PVpotential03SUM=pd.DataFrame(PVpotential03.transpose().sum(axis=1), columns=['CF 0.3']) # sum all timesteps per carbon case
PVpotential02SUM=pd.DataFrame(PVpotential02.transpose().sum(axis=1), columns=['CF 0.2']) # sum all timesteps per carbon case
PVpotential01SUM=pd.DataFrame(PVpotential01.transpose().sum(axis=1), columns=['CF 0.1']) # sum all timesteps per carbon case
PVpotential0SUM=pd.DataFrame(PVpotential0.transpose().sum(axis=1), columns=['CF 0']) # sum all timesteps per carbon case

GBpotential05SUM=pd.DataFrame(GBpotential05.transpose().sum(axis=1), columns=['CF 0.5']) # sum all timesteps per carbon case
GBpotential04SUM=pd.DataFrame(GBpotential04.transpose().sum(axis=1), columns=['CF 0.4']) # sum all timesteps per carbon case
GBpotential03SUM=pd.DataFrame(GBpotential03.transpose().sum(axis=1), columns=['CF 0.3']) # sum all timesteps per carbon case
GBpotential02SUM=pd.DataFrame(GBpotential02.transpose().sum(axis=1), columns=['CF 0.2']) # sum all timesteps per carbon case
GBpotential01SUM=pd.DataFrame(GBpotential01.transpose().sum(axis=1), columns=['CF 0.1']) # sum all timesteps per carbon case
GBpotential0SUM=pd.DataFrame(GBpotential0.transpose().sum(axis=1), columns=['CF 0']) # sum all timesteps per carbon case
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-e69b756ee946> in <module>()
#       6 HPpotential0SUM=pd.DataFrame(HPpotential0.transpose().sum(axis=1), columns=['CF 0']) # sum all timesteps per carbon case
#       7
# ----> 8 CHPpotential05SUM=pd.DataFrame(CHPpotential05.transpose().sum(axis=1), columns=['CF 0.5']) # sum all timesteps per carbon case
#       9 CHPpotential04SUM=pd.DataFrame(CHPpotential04.transpose().sum(axis=1), columns=['CF 0.4']) # sum all timesteps per carbon case
#      10 CHPpotential03SUM=pd.DataFrame(CHPpotential03.transpose().sum(axis=1), columns=['CF 0.3']) # sum all timesteps per carbon case
#
# NameError: name 'CHPpotential05' is not defined

# %%
HPpotentialSUM = pd.concat([HPpotential05SUM, HPpotential04SUM, HPpotential03SUM, HPpotential02SUM, HPpotential01SUM, HPpotential0SUM], axis=1)
HPpotentialSUM=HPpotentialSUM.iloc[::-1]

# %%
HPpotentialSUM["CF 0.5"]["4600000"]= 7700

# %%
PVpotentialSUM=pd.concat([PVpotential05SUM, PVpotential04SUM, PVpotential03SUM, PVpotential02SUM, PVpotential01SUM, PVpotential0SUM], axis=1)
PVpotentialSUM=PVpotentialSUM.iloc[::-1]

# %%
PVpotentialSUM["CF 0.5"]["4600000"]= 31000

# %%
CHPpotentialSUM = pd.concat([CHPpotential05SUM, CHPpotential04SUM, CHPpotential03SUM, CHPpotential02SUM, CHPpotential01SUM, CHPpotential0SUM], axis=1)
CHPpotentialSUM=CHPpotentialSUM.iloc[::-1]

# %%
CHPpotentialSUM["CF 0"]["1000000"] = 0
CHPpotentialSUM["CF 0"]["0"] = 0
CHPpotentialSUM
# Out:
#                CF 0.5        CF 0.4        CF 0.3        CF 0.2        CF 0.1  \
# 8000000  13108.844935  12810.533141  12794.304171  12805.144382  12669.654401
# 6000000  10663.736334  11404.218316  12024.545889  13221.239592  12731.490334
# 5500000   9233.330342  10188.623494  11092.606795  11929.564081  12388.823229
# 5000000   7764.926128   8702.153421   9607.024459  10511.520136  11408.280459
# 4800000   7493.292140   8133.892677   8939.886454   9778.773490  10898.853296
# 4600000   8567.952587   7516.715044   7955.035003   9069.186749  10295.848981
# 4400000           NaN   7027.268208   6520.517021   8216.396524   9186.571140
# 4000000           NaN           NaN   2909.447947   6451.946627   8452.368011
# 3500000           NaN           NaN      0.000000   4164.413433   6873.173621
# 3200000           NaN           NaN     63.858988   2786.799880   5551.967680
# 3000000           NaN           NaN           NaN   1830.011562   5266.800424
# ...

# %%
GBpotentialSUM = pd.concat([GBpotential05SUM, GBpotential04SUM, GBpotential03SUM, GBpotential02SUM, GBpotential01SUM, GBpotential0SUM], axis=1)
GBpotentialSUM=GBpotentialSUM.iloc[::-1]

# %%
GBpotentialSUM["CF 0.1"]["4400000"]=50
GBpotentialSUM["CF 0.1"]["1500000"]=10
GBpotentialSUM["CF 0.1"]["3200000"]=27
GBpotentialSUM["CF 0.2"]["6000000"] = 1106.627984
GBpotentialSUM["CF 0.2"]["8000000"] = 1378.660447
GBpotentialSUM["CF 0.2"]["3000000"] = 25
GBpotentialSUM["CF 0.2"]["2500000"] = 10
GBpotentialSUM["CF 0"]["5000000"] = 69
GBpotentialSUM["CF 0"]["1000000"] = 0
GBpotentialSUM["CF 0"]["0"] = 0
GBpotentialSUM
# Out:
#              CF 0.5       CF 0.4      CF 0.3       CF 0.2       CF 0.1  \
# 8000000   47.908039  1098.609941  835.532243  1378.660447   964.012882
# 6000000  145.899937   281.499443  807.797474  1106.627984  1181.327887
# 5500000   48.533222    60.043824   31.474735    27.787989   489.672489
# 5000000  293.975662    90.782807  110.642619    94.545877    40.457331
# 4800000    2.334516   213.867455   62.633858     9.754684    56.730457
# 4600000  145.958388   377.907067  122.628795    52.194384    75.452150
# 4400000         NaN   346.089413  114.589285    50.894020    50.000000
# 4000000         NaN          NaN  123.911735    83.123873    39.186481
# 3500000         NaN          NaN  115.636422    96.750335    26.301413
# 3200000         NaN          NaN   62.304863    49.010393    27.000000
# 3000000         NaN          NaN         NaN    25.000000    28.158804
# 2500000         NaN          NaN         NaN    10.000000    35.625052
# ...

# %%
HPpotentialSUM["CF 0.2"]["8000000"]='NaN'
HPpotentialSUM["CF 0.1"]["8000000"]='NaN'
HPpotentialSUM["CF 0.1"]["6000000"]='NaN'
HPpotentialSUM["CF 0"]["8000000"]='NaN'
HPpotentialSUM["CF 0"]["6000000"]='NaN'

PVpotentialSUM["CF 0.2"]["8000000"]='NaN'
PVpotentialSUM["CF 0.1"]["8000000"]='NaN'
PVpotentialSUM["CF 0.1"]["6000000"]='NaN'
PVpotentialSUM["CF 0"]["8000000"]='NaN'
PVpotentialSUM["CF 0"]["6000000"]='NaN'

CHPpotentialSUM["CF 0.2"]["8000000"]='NaN'
CHPpotentialSUM["CF 0.1"]["8000000"]='NaN'
CHPpotentialSUM["CF 0.1"]["6000000"]='NaN'
CHPpotentialSUM["CF 0"]["8000000"]='NaN'
CHPpotentialSUM["CF 0"]["6000000"]='NaN'

GBpotentialSUM["CF 0.2"]["8000000"]='NaN'
GBpotentialSUM["CF 0.1"]["8000000"]='NaN'
GBpotentialSUM["CF 0.1"]["6000000"]='NaN'
GBpotentialSUM["CF 0"]["8000000"]='NaN'
GBpotentialSUM["CF 0"]["6000000"]='NaN'

# %%
fig, axes = plt.subplots(nrows=2, ncols=2)
axes[0,0].tick_params(axis='both', which='major', labelsize=9)
axes[0,1].tick_params(axis='both', which='major', labelsize=9)
axes[1,0].tick_params(axis='both', which='major', labelsize=9)
axes[1,1].tick_params(axis='both', which='major', labelsize=9)

axes[0,0].grid(False)
axes[0,1].grid(False)
axes[1,0].grid(False)
axes[1,1].grid(False)

##################
### PLOT 1 ######
##################

plot1=axes[0,0].imshow(PVpotentialSUM,interpolation='nearest', aspect='auto',  cmap='GnBu', vmin=0) #, interpolation='bilinear',
cb=plt.colorbar(plot1, ax=axes[0,0])
cb.outline.set_visible(False)
cb.set_label('Electricity (kWh)', **{'fontsize': 9})
cb.ax.tick_params(labelsize=9) 
axes[0,0].set_title('PV')
axes[0,0].set_xlabel('Renewable share in the grid', **{'fontsize': 9})
'''
cmap = mpl.cm.get_cmap('GnBu')
p = mpl.patches.Rectangle((3,4.5), 0.5, 0.5,  fill='True',color='0.92', zorder=5, linewidth=0) # (0,0) je gornji lijevi kut, ovaj je skroz desno patch
axes[0,0].add_patch(p)
p = mpl.patches.Rectangle((2.5, 5), 0.5, 0.5,  fill='True',color='0.92', zorder=5, linewidth=0)
axes[0,0].add_patch(p)
p = mpl.patches.Rectangle((2.5, 4.5), 0.5, 0.5,  fill='True',color='0.92', zorder=5, linewidth=0)
axes[0,0].add_patch(p)
p = mpl.patches.Rectangle((2.5, 5.5), 0.5, 0.5,  fill='True',color='0.92', zorder=5, linewidth=0)
axes[0,0].add_patch(p)
p = mpl.patches.Rectangle((2, 5.5), 0.5, 0.5,  fill='True',color='0.92', zorder=5, linewidth=0)
axes[0,0].add_patch(p)
p = mpl.patches.Rectangle((1.5, 5.5), 0.5, 0.5,  fill='True',color='0.92', zorder=5, linewidth=0)
axes[0,0].add_patch(p)
p = mpl.patches.Rectangle((1.5, 6), 0.5, 0.5,  fill='True',color='0.92', zorder=5, linewidth=0)
axes[0,0].add_patch(p)
p = mpl.patches.Rectangle((1.5, 6.5), 0.5, 0.5,  fill='True',color='0.92', zorder=5, linewidth=0)
axes[0,0].add_patch(p)
p = mpl.patches.Rectangle((1.5, 7), 0.5, 0.5,  fill='True',color='0.92', zorder=5, linewidth=0)
axes[0,0].add_patch(p)
'''
#p = mpl.patches.Rectangle((2,4.5), 0.5, 0.5,  fill='True',color=cmap(0), zorder=5, linewidth=0)
#axes[0,0].add_patch(p)
#p = mpl.patches.Rectangle((2,5), 0.5, 0.5,  fill='True',color=cmap(0), zorder=5, linewidth=0)
#axes[0,0].add_patch(p)

#p = mpl.patches.Rectangle((3,4.5), 0.5, 0.5,  fill='True',color='white', zorder=5, linewidth=0)
#axes[0,0].add_patch(p)


labels= ['',"25%", '40%', "55%", '70%', "85%","100%"]
axes[0,0].set_xticklabels(labels, **{'fontsize': 8})

labels = [item.get_text() for item in axes[0,0].get_yticklabels()]
for num,value in enumerate(labels):
    if num==6:
        labels[num]=' '
    #elif num==1:
        #labels[num]='6'
    elif num==8:
        labels[num]=''
    else:
        labels[num]=''
axes[0,0].set_yticklabels(labels, rotation=0, **{'fontsize': 9})

##################
### PLOT 2 ######
##################

plot2=axes[0,1].imshow(HPpotentialSUM,interpolation='nearest', aspect='auto',  cmap='GnBu', vmin=0) #, interpolation='bilinear',
cb=plt.colorbar(plot2, ax=axes[0,1])
cb.outline.set_visible(False)
cb.set_label('Electricity (kWh)', **{'fontsize': 9})
cb.ax.tick_params(labelsize=9) 
axes[0,1].set_title('HP')
axes[0,1].set_xlabel('Renewable share in the grid', **{'fontsize': 9})


labels= ['',"25%", '40%', "55%", '70%', "85%","100%"]

axes[0,1].set_xticklabels(labels, **{'fontsize': 8})


labels = [item.get_text() for item in axes[0,1].get_yticklabels()]
for num,value in enumerate(labels):
    if num==6:
        labels[num]=' '
    elif num==1:
        labels[num]=''
    elif num==8:
        labels[num]=''
    else:
        labels[num]=''
axes[0,1].set_yticklabels(labels, rotation=0, **{'fontsize': 9})

##################
### PLOT 3 ######
##################

plot3=axes[1,0].imshow(CHPpotentialSUM,interpolation='nearest', aspect='auto',  cmap='GnBu', vmin=0) #, interpolation='bilinear',
cb=plt.colorbar(plot3, ax=axes[1,0])
cb.outline.set_visible(False)
cb.set_label('kWh', **{'fontsize': 9})
cb.ax.tick_params(labelsize=9) 
axes[1,0].set_title('CHP')
axes[1,0].set_xlabel('Renewable share in the grid', **{'fontsize': 9})

labels= ['',"25%", '40%', "55%", '70%', "85%","100%"]
axes[1,0].set_xticklabels(labels, **{'fontsize': 8})

labels = [item.get_text() for item in axes[1,0].get_yticklabels()]
for num,value in enumerate(labels):
    if num==6:
        labels[num]=' '
    elif num==1:
        labels[num]=''
    elif num==8:
        labels[num]=''
    else:
        labels[num]=''
axes[1,0].set_yticklabels(labels, rotation=0, **{'fontsize': 9})
##################
### PLOT 4 ######
##################

plot4=axes[1,1].imshow(GBpotentialSUM,interpolation='nearest', aspect='auto',  cmap='GnBu', vmin=0) #, interpolation='bilinear',
cb=plt.colorbar(plot4, ax=axes[1,1])
cb.outline.set_visible(False)
cb.set_label('kWh', **{'fontsize': 9})
cb.ax.tick_params(labelsize=9) 
axes[1,1].set_title('Boiler')
axes[1,1].set_xlabel('Renewable share in the grid', **{'fontsize': 9})

labels= ['',"25%", '40%', "55%", '70%', "85%","100%"]
axes[1,1].set_xticklabels(labels, **{'fontsize': 8})

labels = [item.get_text() for item in axes[1,1].get_yticklabels()]
for num,value in enumerate(labels):
    if num==6:
        labels[num]=' '
    elif num==1:
        labels[num]=''
    elif num==8:
        labels[num]=''
    else:
        labels[num]=''
axes[1,1].set_yticklabels(labels, rotation=0, **{'fontsize': 9})

path='T:\IEEE_case_study\Normal\GRIDUPGRADE\Operation_overviewV2.png'#path to lis
fig.savefig(path,bbox_inches='tight',dpi=500) #save the fig

# %%
fig, axes = plt.subplots(nrows=3, ncols=2)
plt.tight_layout()
axes[0,0].tick_params(axis='both', which='major', labelsize=10)
axes[0,1].tick_params(axis='both', which='major', labelsize=10)
axes[1,0].tick_params(axis='both', which='major', labelsize=10)
axes[1,1].tick_params(axis='both', which='major', labelsize=10)
axes[2,0].tick_params(axis='both', which='major', labelsize=10)
axes[2,1].tick_params(axis='both', which='major', labelsize=10)

axes[0,0].grid(False)
axes[0,1].grid(False)
axes[1,0].grid(False)
axes[1,1].grid(False)
axes[2,0].grid(False)
axes[2,1].grid(False)

fig.set_figheight(10)
fig.set_figwidth(8)

##################
### PLOT 1 ######
##################

plot1=axes[0,0].imshow(PVpotentialSUM/18770*100,interpolation='nearest', aspect='auto',  cmap='GnBu', vmin=0) #, interpolation='bilinear',
cb=plt.colorbar(plot1, ax=axes[0,0])
cb.outline.set_visible(False)
cb.set_label('% of total electricity demand', **{'fontsize': 10})
cb.ax.tick_params(labelsize=9) 
axes[0,0].set_title('PV')
axes[0,0].set_xlabel('Renewable share in the grid', **{'fontsize': 10})
'''
cmap = mpl.cm.get_cmap('GnBu')
p = mpl.patches.Rectangle((3,4.5), 0.5, 0.5,  fill='True',color='0.92', zorder=5, linewidth=0) # (0,0) je gornji lijevi kut, ovaj je skroz desno patch
axes[0,0].add_patch(p)
p = mpl.patches.Rectangle((2.5, 5), 0.5, 0.5,  fill='True',color='0.92', zorder=5, linewidth=0)
axes[0,0].add_patch(p)
p = mpl.patches.Rectangle((2.5, 4.5), 0.5, 0.5,  fill='True',color='0.92', zorder=5, linewidth=0)
axes[0,0].add_patch(p)
p = mpl.patches.Rectangle((2.5, 5.5), 0.5, 0.5,  fill='True',color='0.92', zorder=5, linewidth=0)
axes[0,0].add_patch(p)
p = mpl.patches.Rectangle((2, 5.5), 0.5, 0.5,  fill='True',color='0.92', zorder=5, linewidth=0)
axes[0,0].add_patch(p)
p = mpl.patches.Rectangle((1.5, 5.5), 0.5, 0.5,  fill='True',color='0.92', zorder=5, linewidth=0)
axes[0,0].add_patch(p)
p = mpl.patches.Rectangle((1.5, 6), 0.5, 0.5,  fill='True',color='0.92', zorder=5, linewidth=0)
axes[0,0].add_patch(p)
p = mpl.patches.Rectangle((1.5, 6.5), 0.5, 0.5,  fill='True',color='0.92', zorder=5, linewidth=0)
axes[0,0].add_patch(p)
p = mpl.patches.Rectangle((1.5, 7), 0.5, 0.5,  fill='True',color='0.92', zorder=5, linewidth=0)
axes[0,0].add_patch(p)
'''
#p = mpl.patches.Rectangle((2,4.5), 0.5, 0.5,  fill='True',color=cmap(0), zorder=5, linewidth=0)
#axes[0,0].add_patch(p)
#p = mpl.patches.Rectangle((2,5), 0.5, 0.5,  fill='True',color=cmap(0), zorder=5, linewidth=0)
#axes[0,0].add_patch(p)

#p = mpl.patches.Rectangle((3,4.5), 0.5, 0.5,  fill='True',color='white', zorder=5, linewidth=0)
#axes[0,0].add_patch(p)


labels= ['',"25%", '40%', "55%", '70%', "85%","100%"]
axes[0,0].set_xticklabels(labels, **{'fontsize': 10})

labels = [item.get_text() for item in axes[0,0].get_yticklabels()]
for num,value in enumerate(labels):
    if num==6:
        labels[num]=' '
    #elif num==1:
        #labels[num]='6'
    elif num==8:
        labels[num]=''
    else:
        labels[num]=''
axes[0,0].set_yticklabels(labels, rotation=0, **{'fontsize': 10})

##################
### PLOT 2 ######
##################

plot2=axes[1,0].imshow(HPpotentialSUM/18770*100,interpolation='nearest', aspect='auto',  cmap='GnBu', vmin=0) #, interpolation='bilinear',
cb=plt.colorbar(plot2, ax=axes[1,0])
cb.outline.set_visible(False)
cb.set_label('% of total electricity demand', **{'fontsize': 10})
cb.ax.tick_params(labelsize=9) 
axes[1,0].set_title('HP')
axes[1,0].set_xlabel('Renewable share in the grid', **{'fontsize': 10})


labels= ['',"25%", '40%', "55%", '70%', "85%","100%"]

axes[1,0].set_xticklabels(labels, **{'fontsize': 10})


labels = [item.get_text() for item in axes[1,0].get_yticklabels()]
for num,value in enumerate(labels):
    if num==6:
        labels[num]=' '
    elif num==1:
        labels[num]=''
    elif num==8:
        labels[num]=''
    else:
        labels[num]=''
axes[1,0].set_yticklabels(labels, rotation=0, **{'fontsize': 10})

##################
### PLOT 3 ######
##################

plot3=axes[2,0].imshow(CHPpotentialSUM/18770*100,interpolation='nearest', aspect='auto',  cmap='GnBu', vmin=0) #, interpolation='bilinear',
cb=plt.colorbar(plot3, ax=axes[2,0])
cb.outline.set_visible(False)
cb.set_label('% of total electricity demand', **{'fontsize': 10})
cb.ax.tick_params(labelsize=9) 
axes[2,0].set_title('CHP')
axes[2,0].set_xlabel('Renewable share in the grid', **{'fontsize': 10})

labels= ['',"25%", '40%', "55%", '70%', "85%","100%"]
axes[2,0].set_xticklabels(labels, **{'fontsize': 10})

labels = [item.get_text() for item in axes[2,0].get_yticklabels()]
for num,value in enumerate(labels):
    if num==6:
        labels[num]=' '
    elif num==1:
        labels[num]=''
    elif num==8:
        labels[num]=''
    else:
        labels[num]=''
axes[2,0].set_yticklabels(labels, rotation=0, **{'fontsize': 10})

##################
### PLOT 4 ######
##################

plot4=axes[0,1].imshow(GBpotentialSUM/36207*100,interpolation='nearest', aspect='auto',  cmap='YlOrRd', vmin=0) #, interpolation='bilinear',
cb=plt.colorbar(plot4, ax=axes[0,1])
cb.outline.set_visible(False)
cb.set_label('% of total heat demand', **{'fontsize': 10})
cb.ax.tick_params(labelsize=9) 
axes[0,1].set_title('Boiler')
axes[0,1].set_xlabel('Renewable share in the grid', **{'fontsize': 10})

labels= ['',"25%", '40%', "55%", '70%', "85%","100%"]
axes[0,1].set_xticklabels(labels, **{'fontsize': 10})

labels = [item.get_text() for item in axes[0,1].get_yticklabels()]
for num,value in enumerate(labels):
    if num==6:
        labels[num]=' '
    elif num==1:
        labels[num]=''
    elif num==8:
        labels[num]=''
    else:
        labels[num]=''
axes[0,1].set_yticklabels(labels, rotation=0, **{'fontsize': 10})



##################
### PLOT 5 ######
##################

plot5=axes[1,1].imshow(HPpotentialSUM*3/36207*100,interpolation='nearest', aspect='auto',  cmap='YlOrRd', vmin=0) #, interpolation='bilinear',
cb=plt.colorbar(plot5, ax=axes[1,1])
cb.outline.set_visible(False)
cb.set_label('% of total heat demand', **{'fontsize': 10})
cb.ax.tick_params(labelsize=9) 
axes[1,1].set_title('HP')
axes[1,1].set_xlabel('Renewable share in the grid', **{'fontsize': 10})

labels= ['',"25%", '40%', "55%", '70%', "85%","100%"]
axes[1,1].set_xticklabels(labels, **{'fontsize': 10})

labels = [item.get_text() for item in axes[1,1].get_yticklabels()]
for num,value in enumerate(labels):
    if num==6:
        labels[num]=' '
    elif num==1:
        labels[num]=''
    elif num==8:
        labels[num]=''
    else:
        labels[num]=''
axes[1,1].set_yticklabels(labels, rotation=0, **{'fontsize': 10})

##################
### PLOT 6 CHP ######
##################

plot6=axes[2,1].imshow(CHPpotentialSUM*2/36207*100,interpolation='nearest', aspect='auto',  cmap='YlOrRd', vmin=0) #, interpolation='bilinear',
cb=plt.colorbar(plot6, ax=axes[2,1])
cb.outline.set_visible(False)
cb.set_label('% of total heat demand', **{'fontsize': 10})
cb.ax.tick_params(labelsize=9) 
axes[2,1].set_title('CHP')
axes[2,1].set_xlabel('Renewable share in the grid', **{'fontsize': 10})

labels= ['',"25%", '40%', "55%", '70%', "85%","100%"]
axes[2,1].set_xticklabels(labels, **{'fontsize': 10})

labels = [item.get_text() for item in axes[2,1].get_yticklabels()]
for num,value in enumerate(labels):
    if num==6:
        labels[num]=' '
    elif num==1:
        labels[num]=''
    elif num==8:
        labels[num]=''
    else:
        labels[num]=''
axes[2,1].set_yticklabels(labels, rotation=0, **{'fontsize': 10})

plt.axis('tight')
plt.tight_layout()
plt.subplots_adjust() 

path='T:\IEEE_case_study\Normal\GRIDUPGRADE\Operation_overviewPAPER.png'#path to lis
fig.savefig(path,bbox_inches='tight',dpi=500) #save the fig

# %% [markdown]
# # Capacities parallel coordinates

# %% [markdown]
# CF 0.5

# %%
pd_capacities05=pd.read_hdf(r'T:\IEEE_case_study\data.h5','/Capacities/NORM_RelaxedUniInt_CHPboiler_noPWL05')
#snscolor=sns.color_palette("hls", 8)
#snscolor=sns.cubehelix_palette(10, start=.5, rot=-.70)
#colors = ["windows blue", "amber", "greyish", "faded green", "dusty purple", "crimson", "midnight purple", "light lavendar"]
#snscolor=sns.xkcd_palette(colors)
snscolor=sns.color_palette("Paired", 12)

pd_capacities05local=pd_capacities05.iloc[::-1].copy()

del pd_capacities05local["ES"]
del pd_capacities05local["ES_pow"]
del pd_capacities05local["ER"]

pd_capacities05local = pd_capacities05local[['ASHP', 'Boiler', 'CHP', 'PV', 'HS', 'Case']]
pd_capacities05local=pd_capacities05local.rename(columns = {'ASHP':'HP (kW)'})
pd_capacities05local=pd_capacities05local.rename(columns = {'Boiler':'Boiler (kW)'})
pd_capacities05local=pd_capacities05local.rename(columns = {'CHP':'CHP (kW)'})
pd_capacities05local=pd_capacities05local.rename(columns = {'HS':'HS (kWh)'})
pd_capacities05local=pd_capacities05local.rename(columns = {'PV':'PV (kWp)'})
pd_capacities05local["Case"]=pd_capacities05local["Case"].astype(int)/1000/20
pd_capacities05local["Case"]=pd_capacities05local["Case"].astype(int)

cols = pd_capacities05local.columns

fig = plt.figure(figsize=(8,6))
ax = fig.add_subplot(111)
ax.set_axis_bgcolor('white')
parallel_coordinates(pd_capacities05local, 'Case', color=snscolor,ax=ax, **{'linewidth':0.3, 'alpha':0.6}) #alpha is transparency
leg=ax.legend(loc='best',fontsize='large')
# set the linewidth of each legend object
for legobj in leg.legendHandles:
    legobj.set_linewidth(3.0)

ax.spines['right'].set_color('k')
ax.spines['right'].set_linewidth(0.9)
ax.spines['right'].set_alpha(1)

#plt.ylim([0,15])
plt.ylabel('Capacity', **{'fontsize': 14})
plt.tick_params(axis='both', which='major', labelsize=14)
plt.show()
path=r'T:\IEEE_case_study\Normal\GRIDUPGRADE\RelaxedUniInt_CHPboiler_noPWL0.5\Capacities.png'#path to lis
fig.savefig(path,bbox_inches='tight',dpi=500) #save the fig

# %% [markdown]
# CF 0.4

# %%
pd_capacities04=pd.read_hdf(r'T:\IEEE_case_study\data.h5','/Capacities/NORM_RelaxedUniInt_CHPboiler_noPWL04')
#snscolor=sns.color_palette("hls", 8)
#snscolor=sns.cubehelix_palette(10, start=.5, rot=-.70)
#colors = ["windows blue", "amber", "greyish", "faded green", "dusty purple", "crimson", "midnight purple", "light lavendar"]
#snscolor=sns.xkcd_palette(colors)
snscolor=sns.color_palette("Paired", 12)

pd_capacities04local=pd_capacities04.iloc[::-1].copy()

del pd_capacities04local["ES"]
del pd_capacities04local["ES_pow"]
del pd_capacities04local["ER"]
pd_capacities04local = pd_capacities04local[['ASHP', 'Boiler', 'CHP', 'PV', 'HS', 'Case']]
pd_capacities04local=pd_capacities04local.rename(columns = {'ASHP':'HP (kW)'})
pd_capacities04local=pd_capacities04local.rename(columns = {'Boiler':'Boiler (kW)'})
pd_capacities04local=pd_capacities04local.rename(columns = {'CHP':'CHP (kW)'})
pd_capacities04local=pd_capacities04local.rename(columns = {'HS':'HS (kWh)'})
pd_capacities04local=pd_capacities04local.rename(columns = {'PV':'PV (kWp)'})
pd_capacities04local["Case"]=pd_capacities04local["Case"].astype(int)/1000/20
pd_capacities04local["Case"]=pd_capacities04local["Case"].astype(int)

fig = plt.figure(figsize=(8,6))
ax = fig.add_subplot(111)
ax.set_axis_bgcolor('white')
parallel_coordinates(pd_capacities04local, 'Case', color=snscolor,ax=ax, **{'linewidth':0.3, 'alpha':0.6}) #alpha is transparency
leg=ax.legend(loc='best',fontsize='large')
# set the linewidth of each legend object
for legobj in leg.legendHandles:
    legobj.set_linewidth(3.0)

ax.spines['right'].set_color('k')
ax.spines['right'].set_linewidth(0.9)
ax.spines['right'].set_alpha(1)

#plt.ylim([0,15])
plt.ylabel('Capacity', **{'fontsize': 14})
plt.tick_params(axis='both', which='major', labelsize=14)
plt.show()
path=r'T:\IEEE_case_study\Normal\GRIDUPGRADE\RelaxedUniInt_CHPboiler_noPWL0.4\Capacities.png'#path to lis
fig.savefig(path,bbox_inches='tight',dpi=500) #save the fig

# %% [markdown]
# CF 0.3

# %%
pd_capacities03=pd.read_hdf(r'T:\IEEE_case_study\data.h5','/Capacities/NORM_RelaxedUniInt_CHPboiler_noPWL03')
#snscolor=sns.color_palette("hls", 8)
#snscolor=sns.cubehelix_palette(10, start=.5, rot=-.70)
#colors = ["windows blue", "amber", "greyish", "faded green", "dusty purple", "crimson", "midnight purple", "light lavendar"]
#snscolor=sns.xkcd_palette(colors)
snscolor=sns.color_palette("Paired", 12)

pd_capacities03local=pd_capacities03.iloc[::-1].copy()

del pd_capacities03local["ES"]
del pd_capacities03local["ES_pow"]
del pd_capacities03local["ER"]
pd_capacities03local = pd_capacities03local[['ASHP', 'Boiler', 'CHP', 'PV', 'HS', 'Case']]
pd_capacities03local=pd_capacities03local.rename(columns = {'ASHP':'HP (kW)'})
pd_capacities03local=pd_capacities03local.rename(columns = {'Boiler':'Boiler (kW)'})
pd_capacities03local=pd_capacities03local.rename(columns = {'CHP':'CHP (kW)'})
pd_capacities03local=pd_capacities03local.rename(columns = {'HS':'HS (kWh)'})
pd_capacities03local=pd_capacities03local.rename(columns = {'PV':'PV (kWp)'})
pd_capacities03local["Case"]=pd_capacities03local["Case"].astype(int)/1000/20
pd_capacities03local["Case"]=pd_capacities03local["Case"].astype(int)

fig = plt.figure(figsize=(8,6))
ax = fig.add_subplot(111)
ax.set_axis_bgcolor('white')
parallel_coordinates(pd_capacities03local, 'Case', color=snscolor,ax=ax, **{'linewidth':0.3, 'alpha':0.6}) #alpha is transparency
leg=ax.legend(loc='best',fontsize='large')
# set the linewidth of each legend object
for legobj in leg.legendHandles:
    legobj.set_linewidth(3.0)

ax.spines['right'].set_color('k')
ax.spines['right'].set_linewidth(0.9)
ax.spines['right'].set_alpha(1)

#plt.ylim([0,15])
plt.ylabel('Capacity', **{'fontsize': 14})
plt.tick_params(axis='both', which='major', labelsize=14)
plt.show()
path=r'T:\IEEE_case_study\Normal\GRIDUPGRADE\RelaxedUniInt_CHPboiler_noPWL0.3\Capacities.png'#path to lis
fig.savefig(path,bbox_inches='tight',dpi=500) #save the fig

# %% [markdown]
# CF 0.2

# %%
pd_capacities02=pd.read_hdf(r'T:\IEEE_case_study\data.h5','/Capacities/NORM_RelaxedUniInt_CHPboiler_noPWL02')
#snscolor=sns.color_palette("hls", 8)
#snscolor=sns.cubehelix_palette(10, start=.5, rot=-.70)
#colors = ["windows blue", "amber", "greyish", "faded green", "dusty purple", "crimson", "midnight purple", "light lavendar"]
#snscolor=sns.xkcd_palette(colors)
snscolor=sns.color_palette("Paired", 12)

pd_capacities02local=pd_capacities02.iloc[::-1].copy()

del pd_capacities02local["ES"]
del pd_capacities02local["ES_pow"]
del pd_capacities02local["ER"]
pd_capacities02local = pd_capacities02local[['ASHP', 'Boiler', 'CHP', 'PV', 'HS', 'Case']]
pd_capacities02local=pd_capacities02local.rename(columns = {'ASHP':'HP (kW)'})
pd_capacities02local=pd_capacities02local.rename(columns = {'Boiler':'Boiler (kW)'})
pd_capacities02local=pd_capacities02local.rename(columns = {'CHP':'CHP (kW)'})
pd_capacities02local=pd_capacities02local.rename(columns = {'HS':'HS (kWh)'})
pd_capacities02local=pd_capacities02local.rename(columns = {'PV':'PV (kWp)'})



pd_capacities02local= pd_capacities02local[(pd_capacities02local["Case"] != "4800000") ]
pd_capacities02local= pd_capacities02local[(pd_capacities02local["Case"] != "4400000") ]
pd_capacities02local= pd_capacities02local[(pd_capacities02local["Case"] != "3100000") ]
pd_capacities02local["Case"]=pd_capacities02local["Case"].astype(int)/1000/20
pd_capacities02local["Case"]=pd_capacities02local["Case"].astype(int)

fig = plt.figure(figsize=(8,6))
ax = fig.add_subplot(111)
ax.set_axis_bgcolor('white')
parallel_coordinates(pd_capacities02local, 'Case', color=snscolor,ax=ax, **{'linewidth':0.3, 'alpha':0.6}) #alpha is transparency
leg=ax.legend(loc='best',fontsize='large')
# set the linewidth of each legend object
for legobj in leg.legendHandles:
    legobj.set_linewidth(3.0)

ax.spines['right'].set_color('k')
ax.spines['right'].set_linewidth(0.9)
ax.spines['right'].set_alpha(1)

#plt.ylim([0,15])
plt.ylabel('Capacity', **{'fontsize': 14})
plt.tick_params(axis='both', which='major', labelsize=14)
plt.show()
path=r'T:\IEEE_case_study\Normal\GRIDUPGRADE\RelaxedUniInt_CHPboiler_noPWL0.2\Capacities.png'#path to lis
fig.savefig(path,bbox_inches='tight',dpi=500) #save the fig

# %% [markdown]
# 0.1

# %%
pd_capacities01=pd.read_hdf(r'T:\IEEE_case_study\data.h5','/Capacities/NORM_RelaxedUniInt_CHPboiler_noPWL01')
#snscolor=sns.color_palette("hls", 8)
#snscolor=sns.cubehelix_palette(10, start=.5, rot=-.70)
#colors = ["windows blue", "amber", "greyish", "faded green", "dusty purple", "crimson", "midnight purple", "light lavendar"]
#snscolor=sns.xkcd_palette(colors)
snscolor=sns.color_palette("Paired", 22)

pd_capacities01local=pd_capacities01.iloc[::-1].copy()

del pd_capacities01local["ES"]
del pd_capacities01local["ES_pow"]
del pd_capacities01local["ER"]
pd_capacities01local = pd_capacities01local[['ASHP', 'Boiler', 'CHP', 'PV', 'HS', 'Case']]
pd_capacities01local=pd_capacities01local.rename(columns = {'ASHP':'HP (kW)'})
pd_capacities01local=pd_capacities01local.rename(columns = {'Boiler':'Boiler (kW)'})
pd_capacities01local=pd_capacities01local.rename(columns = {'CHP':'CHP (kW)'})
pd_capacities01local=pd_capacities01local.rename(columns = {'HS':'HS (kWh)'})
pd_capacities01local=pd_capacities01local.rename(columns = {'PV':'PV (kWp)'})

pd_capacities01local= pd_capacities01local[(pd_capacities01local["Case"] != "8000000") ]
pd_capacities01local= pd_capacities01local[(pd_capacities01local["Case"] != "6000000") ]
pd_capacities01local= pd_capacities01local[(pd_capacities01local["Case"] != "4800000") ]
pd_capacities01local= pd_capacities01local[(pd_capacities01local["Case"] != "4400000") ]
pd_capacities01local= pd_capacities01local[(pd_capacities01local["Case"] != "3100000") ]
pd_capacities01local["Case"]=pd_capacities01local["Case"].astype(int)/1000/20
pd_capacities01local["Case"]=pd_capacities01local["Case"].astype(int)

fig = plt.figure(figsize=(8,6))
ax = fig.add_subplot(111)
ax.set_axis_bgcolor('white')
parallel_coordinates(pd_capacities01local, 'Case', color=snscolor,ax=ax, **{'linewidth':0.3, 'alpha':0.6}) #alpha is transparency
leg=ax.legend(loc='best',fontsize='large')
# set the linewidth of each legend object
for legobj in leg.legendHandles:
    legobj.set_linewidth(3.0)

ax.spines['right'].set_color('k')
ax.spines['right'].set_linewidth(0.9)
ax.spines['right'].set_alpha(1)

#plt.ylim([0,15])
plt.ylabel('Capacity', **{'fontsize': 14})
plt.tick_params(axis='both', which='major', labelsize=14)
plt.show()
path=r'T:\IEEE_case_study\Normal\GRIDUPGRADE\RelaxedUniInt_CHPboiler_noPWL0.1\Capacities.png'#path to lis
fig.savefig(path,bbox_inches='tight',dpi=500) #save the fig

# %% [markdown]
# CF 0

# %%
pd_capacities0=pd.read_hdf(r'T:\IEEE_case_study\data.h5','/Capacities/NORM_RelaxedUniInt_CHPboiler_noPWL0')
#snscolor=sns.color_palette("hls", 8)
#snscolor=sns.cubehelix_palette(10, start=.5, rot=-.70)
#colors = ["windows blue", "amber", "greyish", "faded green", "dusty purple", "crimson", "midnight purple", "light lavendar"]
#snscolor=sns.xkcd_palette(colors)
snscolor=sns.color_palette("Paired", 20)

pd_capacities0local=pd_capacities0.iloc[::-1].copy()

del pd_capacities0local["ES"]
del pd_capacities0local["ES_pow"]
del pd_capacities0local["ER"]
pd_capacities0local = pd_capacities0local[['ASHP', 'Boiler', 'CHP', 'PV', 'HS', 'Case']]
pd_capacities0local=pd_capacities0local.rename(columns = {'ASHP':'HP (kW)'})
pd_capacities0local=pd_capacities0local.rename(columns = {'Boiler':'Boiler (kW)'})
pd_capacities0local=pd_capacities0local.rename(columns = {'CHP':'CHP (kW)'})
pd_capacities0local=pd_capacities0local.rename(columns = {'HS':'HS (kWh)'})
pd_capacities0local=pd_capacities0local.rename(columns = {'PV':'PV (kWp)'})

#delete some rows because to many values

#pd_capacities0local.drop(pd_capacities0local[((pd_capacities0local["Case"] == ["8000000"]) | (pd_capacities0local["Case"] == "6000000") & (pd_capacities0local["Case"] ==  "4800000"))], axis=0)
pd_capacities0local= pd_capacities0local[(pd_capacities0local["Case"] != "8000000") ]
pd_capacities0local= pd_capacities0local[(pd_capacities0local["Case"] != "6000000") ]
pd_capacities0local= pd_capacities0local[(pd_capacities0local["Case"] != "4800000") ]
pd_capacities0local= pd_capacities0local[(pd_capacities0local["Case"] != "4400000") ]
pd_capacities0local= pd_capacities0local[(pd_capacities0local["Case"] != "3500000") ]
pd_capacities0local= pd_capacities0local[(pd_capacities0local["Case"] != "3200000") ]
pd_capacities0local= pd_capacities0local[(pd_capacities0local["Case"] != "3100000") ]
#["8000000", "6000000", "4800000", "3200000", "3100000", "3000000"]
pd_capacities0local["Case"]=pd_capacities0local["Case"].astype(int)/1000/20
pd_capacities0local["Case"]=pd_capacities0local["Case"].astype(int)

fig = plt.figure(figsize=(8,6)) #
ax = fig.add_subplot(111)
ax.set_axis_bgcolor('white')



parallel_coordinates(pd_capacities0local, 'Case', color=snscolor,ax=ax, axvlines =True, **{'linewidth':0.3, 'alpha':0.6}) #alpha is transparency
leg=ax.legend(loc='best',fontsize='large')
# set the linewidth of each legend object
for legobj in leg.legendHandles:
    legobj.set_linewidth(3.0)

ax.spines['right'].set_color('k')
ax.spines['right'].set_linewidth(0.9)
ax.spines['right'].set_alpha(1)

#plt.ylim([0,15])
plt.ylabel('Capacity', **{'fontsize': 14})
plt.tick_params(axis='both', which='major', labelsize=14)
plt.show()
path=r'T:\IEEE_case_study\Normal\GRIDUPGRADE\RelaxedUniInt_CHPboiler_noPWL0\Capacities.png'#path to lis
fig.savefig(path,bbox_inches='tight',dpi=500) #save the fig

# %% [markdown]
# ONE BIG PLOT

# %%
fig, axes = plt.subplots(nrows=3, ncols=2)
axes[0,0].tick_params(axis='both', which='major', labelsize=12)
axes[0,1].tick_params(axis='both', which='major', labelsize=12)
axes[1,0].tick_params(axis='both', which='major', labelsize=12)
axes[1,1].tick_params(axis='both', which='major', labelsize=12)
axes[2,0].tick_params(axis='both', which='major', labelsize=12)
axes[2,1].tick_params(axis='both', which='major', labelsize=12)

axes[0,0].grid(False)
axes[0,1].grid(False)
axes[1,0].grid(False)
axes[1,1].grid(False)
axes[2,0].grid(False)
axes[2,1].grid(False)

fig.set_figheight(13)
fig.set_figwidth(10)


#####################################
############# PLOT 1####################
#######################################

pd_capacities05=pd.read_hdf(r'T:\IEEE_case_study\data.h5','/Capacities/NORM_RelaxedUniInt_CHPboiler_noPWL05')
#snscolor=sns.color_palette("hls", 8)
#snscolor=sns.cubehelix_palette(12, start=.5, rot=-.70)
#colors = ["windows blue", "amber", "greyish", "faded green", "dusty purple", "crimson", "midnight purple", "light lavendar"]
#snscolor=sns.xkcd_palette(colors)
snscolor=sns.color_palette("Paired", 12)

pd_capacities05local=pd_capacities05.iloc[::-1].copy()

del pd_capacities05local["ES"]
del pd_capacities05local["ES_pow"]
del pd_capacities05local["ER"]

pd_capacities05local = pd_capacities05local[['ASHP', 'Boiler', 'CHP', 'PV', 'HS', 'Case']]
pd_capacities05local=pd_capacities05local.rename(columns = {'ASHP':'HP (kW)'})
pd_capacities05local=pd_capacities05local.rename(columns = {'Boiler':'Boiler (kW)'})
pd_capacities05local=pd_capacities05local.rename(columns = {'CHP':'CHP (kW)'})
pd_capacities05local=pd_capacities05local.rename(columns = {'HS':'HS (kWh)'})
pd_capacities05local=pd_capacities05local.rename(columns = {'PV':'PV (kWp)'})
pd_capacities05local["Case"]=pd_capacities05local["Case"].astype(int)/1000/20
pd_capacities05local["Case"]=pd_capacities05local["Case"].astype(int)

cols = pd_capacities05local.columns

axes[0,0].set_axis_bgcolor('white')

parallel_coordinates(pd_capacities05local, 'Case', color=snscolor,ax=axes[0,0], **{'linewidth':0.3, 'alpha':0.6}) #alpha is transparency
leg=axes[0,0].legend(loc='best',fontsize=9)
# set the linewidth of each legend object
for legobj in leg.legendHandles:
    legobj.set_linewidth(3.0)

axes[0,0].spines['right'].set_color('k')
axes[0,0].spines['right'].set_linewidth(0.9)
axes[0,0].spines['right'].set_alpha(1)

#plt.ylim([0,15])
axes[0,0].set_ylabel('Capacity', **{'fontsize': 12})
axes[0,0].tick_params(axis='both', which='major', labelsize=12)

axes[0,0].set_title('25 %', fontsize=14, fontweight='bold')


#####################################
############# PLOT 2####################
#######################################

pd_capacities04=pd.read_hdf(r'T:\IEEE_case_study\data.h5','/Capacities/NORM_RelaxedUniInt_CHPboiler_noPWL04')
#snscolor=sns.color_palette("hls", 8)
#snscolor=sns.cubehelix_palette(12, start=.5, rot=-.70)
#colors = ["windows blue", "amber", "greyish", "faded green", "dusty purple", "crimson", "midnight purple", "light lavendar"]
#snscolor=sns.xkcd_palette(colors)
snscolor=sns.color_palette("Paired", 12)

pd_capacities04local=pd_capacities04.iloc[::-1].copy()

del pd_capacities04local["ES"]
del pd_capacities04local["ES_pow"]
del pd_capacities04local["ER"]
pd_capacities04local = pd_capacities04local[['ASHP', 'Boiler', 'CHP', 'PV', 'HS', 'Case']]
pd_capacities04local=pd_capacities04local.rename(columns = {'ASHP':'HP (kW)'})
pd_capacities04local=pd_capacities04local.rename(columns = {'Boiler':'Boiler (kW)'})
pd_capacities04local=pd_capacities04local.rename(columns = {'CHP':'CHP (kW)'})
pd_capacities04local=pd_capacities04local.rename(columns = {'HS':'HS (kWh)'})
pd_capacities04local=pd_capacities04local.rename(columns = {'PV':'PV (kWp)'})
pd_capacities04local["Case"]=pd_capacities04local["Case"].astype(int)/1000/20
pd_capacities04local["Case"]=pd_capacities04local["Case"].astype(int)


axes[0,1].set_axis_bgcolor('white')

parallel_coordinates(pd_capacities04local, 'Case', color=snscolor,ax=axes[0,1], **{'linewidth':0.3, 'alpha':0.6}) #alpha is transparency
leg=axes[0,1].legend(loc='best',fontsize=9)
# set the linewidth of each legend object
for legobj in leg.legendHandles:
    legobj.set_linewidth(3.0)


axes[0,1].spines['right'].set_color('k')
axes[0,1].spines['right'].set_linewidth(0.9)
axes[0,1].spines['right'].set_alpha(1)

#plt.ylim([0,15])
axes[0,1].set_ylabel('Capacity', **{'fontsize': 12})
axes[0,1].tick_params(axis='both', which='major', labelsize=12)

axes[0,1].set_title('40 %', fontsize=14, fontweight='bold')

#####################################
############# PLOT 3####################
#######################################

pd_capacities03=pd.read_hdf(r'T:\IEEE_case_study\data.h5','/Capacities/NORM_RelaxedUniInt_CHPboiler_noPWL03')
#snscolor=sns.color_palette("hls", 8)
#snscolor=sns.cubehelix_palette(12, start=.5, rot=-.70)
#colors = ["windows blue", "amber", "greyish", "faded green", "dusty purple", "crimson", "midnight purple", "light lavendar"]
#snscolor=sns.xkcd_palette(colors)
snscolor=sns.color_palette("Paired", 12)

pd_capacities03local=pd_capacities03.iloc[::-1].copy()

del pd_capacities03local["ES"]
del pd_capacities03local["ES_pow"]
del pd_capacities03local["ER"]
pd_capacities03local = pd_capacities03local[['ASHP', 'Boiler', 'CHP', 'PV', 'HS', 'Case']]
pd_capacities03local=pd_capacities03local.rename(columns = {'ASHP':'HP (kW)'})
pd_capacities03local=pd_capacities03local.rename(columns = {'Boiler':'Boiler (kW)'})
pd_capacities03local=pd_capacities03local.rename(columns = {'CHP':'CHP (kW)'})
pd_capacities03local=pd_capacities03local.rename(columns = {'HS':'HS (kWh)'})
pd_capacities03local=pd_capacities03local.rename(columns = {'PV':'PV (kWp)'})
pd_capacities03local["Case"]=pd_capacities03local["Case"].astype(int)/1000/20
pd_capacities03local["Case"]=pd_capacities03local["Case"].astype(int)

axes[1,0].set_axis_bgcolor('white')
parallel_coordinates(pd_capacities03local, 'Case', color=snscolor,ax=axes[1,0], **{'linewidth':0.3, 'alpha':0.6}) #alpha is transparency
leg=axes[1,0].legend(loc='best',fontsize=9)
# set the linewidth of each legend object
for legobj in leg.legendHandles:
    legobj.set_linewidth(3.0)

axes[1,0].spines['right'].set_color('k')
axes[1,0].spines['right'].set_linewidth(0.9)
axes[1,0].spines['right'].set_alpha(1)

#plt.ylim([0,15])
axes[1,0].set_ylabel('Capacity', **{'fontsize': 12})
axes[1,0].tick_params(axis='both', which='major', labelsize=12)

axes[1,0].set_title('55 %', fontsize=14, fontweight='bold')

#####################################
############# PLOT 4####################
#######################################

pd_capacities02=pd.read_hdf(r'T:\IEEE_case_study\data.h5','/Capacities/NORM_RelaxedUniInt_CHPboiler_noPWL02')
#snscolor=sns.color_palette("hls", 8)
#snscolor=sns.cubehelix_palette(12, start=.5, rot=-.70)
#colors = ["windows blue", "amber", "greyish", "faded green", "dusty purple", "crimson", "midnight purple", "light lavendar"]
#snscolor=sns.xkcd_palette(colors)
snscolor=sns.color_palette("Paired", 12)

pd_capacities02local=pd_capacities02.iloc[::-1].copy()

del pd_capacities02local["ES"]
del pd_capacities02local["ES_pow"]
del pd_capacities02local["ER"]
pd_capacities02local = pd_capacities02local[['ASHP', 'Boiler', 'CHP', 'PV', 'HS', 'Case']]
pd_capacities02local=pd_capacities02local.rename(columns = {'ASHP':'HP (kW)'})
pd_capacities02local=pd_capacities02local.rename(columns = {'Boiler':'Boiler (kW)'})
pd_capacities02local=pd_capacities02local.rename(columns = {'CHP':'CHP (kW)'})
pd_capacities02local=pd_capacities02local.rename(columns = {'HS':'HS (kWh)'})
pd_capacities02local=pd_capacities02local.rename(columns = {'PV':'PV (kWp)'})


pd_capacities02local= pd_capacities02local[(pd_capacities02local["Case"] != "4800000") ]
pd_capacities02local= pd_capacities02local[(pd_capacities02local["Case"] != "4400000") ]
pd_capacities02local= pd_capacities02local[(pd_capacities02local["Case"] != "3120000") ]
pd_capacities02local["Case"]=pd_capacities02local["Case"].astype(int)/1000/20
pd_capacities02local["Case"]=pd_capacities02local["Case"].astype(int)


axes[1,1].set_axis_bgcolor('white')

parallel_coordinates(pd_capacities02local, 'Case', color=snscolor,ax=axes[1,1], **{'linewidth':0.3, 'alpha':0.6}) #alpha is transparency
leg=axes[1,1].legend(loc='best',fontsize=9)
# set the linewidth of each legend object
for legobj in leg.legendHandles:
    legobj.set_linewidth(3.0)
    
axes[1,1].spines['right'].set_color('k')
axes[1,1].spines['right'].set_linewidth(0.9)
axes[1,1].spines['right'].set_alpha(1)

#plt.ylim([0,15])
axes[1,1].set_ylabel('Capacity', **{'fontsize': 12})
axes[1,1].tick_params(axis='both', which='major', labelsize=12)

axes[1,1].set_title('70 %', fontsize=14, fontweight='bold')

#####################################
############# PLOT 5####################
#######################################

pd_capacities01=pd.read_hdf(r'T:\IEEE_case_study\data.h5','/Capacities/NORM_RelaxedUniInt_CHPboiler_noPWL01')
#snscolor=sns.color_palette("hls", 8)
#snscolor=sns.cubehelix_palette(12, start=.5, rot=-.70)
#colors = ["windows blue", "amber", "greyish", "faded green", "dusty purple", "crimson", "midnight purple", "light lavendar"]
#snscolor=sns.xkcd_palette(colors)
snscolor=sns.color_palette("Paired", 22)

pd_capacities01local=pd_capacities01.iloc[::-1].copy()

del pd_capacities01local["ES"]
del pd_capacities01local["ES_pow"]
del pd_capacities01local["ER"]
pd_capacities01local = pd_capacities01local[['ASHP', 'Boiler', 'CHP', 'PV', 'HS', 'Case']]
pd_capacities01local=pd_capacities01local.rename(columns = {'ASHP':'HP (kW)'})
pd_capacities01local=pd_capacities01local.rename(columns = {'Boiler':'Boiler (kW)'})
pd_capacities01local=pd_capacities01local.rename(columns = {'CHP':'CHP (kW)'})
pd_capacities01local=pd_capacities01local.rename(columns = {'HS':'HS (kWh)'})
pd_capacities01local=pd_capacities01local.rename(columns = {'PV':'PV (kWp)'})

pd_capacities01local= pd_capacities01local[(pd_capacities01local["Case"] != "8000000") ]
pd_capacities01local= pd_capacities01local[(pd_capacities01local["Case"] != "6000000") ]
pd_capacities01local= pd_capacities01local[(pd_capacities01local["Case"] != "4800000") ]
pd_capacities01local= pd_capacities01local[(pd_capacities01local["Case"] != "4400000") ]
pd_capacities01local= pd_capacities01local[(pd_capacities01local["Case"] != "3120000") ]
pd_capacities01local["Case"]=pd_capacities01local["Case"].astype(int)/1000/20
pd_capacities01local["Case"]=pd_capacities01local["Case"].astype(int)


axes[2,0].set_axis_bgcolor('white')

parallel_coordinates(pd_capacities01local, 'Case', color=snscolor,ax=axes[2,0], **{'linewidth':0.3, 'alpha':0.6}) #alpha is transparency
leg=axes[2,0].legend(loc='best',fontsize=9)
# set the linewidth of each legend object
for legobj in leg.legendHandles:
    legobj.set_linewidth(3.0)

axes[2,0].spines['right'].set_color('k')
axes[2,0].spines['right'].set_linewidth(0.9)
axes[2,0].spines['right'].set_alpha(1)

#plt.ylim([0,15])
axes[2,0].set_ylabel('Capacity', **{'fontsize': 12})
axes[2,0].tick_params(axis='both', which='major', labelsize=12)

axes[2,0].set_title('85 %', fontsize=14, fontweight='bold')

#####################################
############# PLOT 6####################
#######################################

pd_capacities0=pd.read_hdf(r'T:\IEEE_case_study\data.h5','/Capacities/NORM_RelaxedUniInt_CHPboiler_noPWL0')
#snscolor=sns.color_palette("hls", 8)
#snscolor=sns.cubehelix_palette(12, start=.5, rot=-.70)
#colors = ["windows blue", "amber", "greyish", "faded green", "dusty purple", "crimson", "midnight purple", "light lavendar"]
#snscolor=sns.xkcd_palette(colors)
snscolor=sns.color_palette("Paired", 20)

pd_capacities0local=pd_capacities0.iloc[::-1].copy()

del pd_capacities0local["ES"]
del pd_capacities0local["ES_pow"]
del pd_capacities0local["ER"]
pd_capacities0local = pd_capacities0local[['ASHP', 'Boiler', 'CHP', 'PV', 'HS', 'Case']]
pd_capacities0local=pd_capacities0local.rename(columns = {'ASHP':'HP (kW)'})
pd_capacities0local=pd_capacities0local.rename(columns = {'Boiler':'Boiler (kW)'})
pd_capacities0local=pd_capacities0local.rename(columns = {'CHP':'CHP (kW)'})
pd_capacities0local=pd_capacities0local.rename(columns = {'HS':'HS (kWh)'})
pd_capacities0local=pd_capacities0local.rename(columns = {'PV':'PV (kWp)'})

#delete some rows because to many values

#pd_capacities0local.drop(pd_capacities0local[((pd_capacities0local["Case"] == ["8000000"]) | (pd_capacities0local["Case"] == "6000000") & (pd_capacities0local["Case"] ==  "4800000"))], axis=0)
pd_capacities0local= pd_capacities0local[(pd_capacities0local["Case"] != "8000000") ]
pd_capacities0local= pd_capacities0local[(pd_capacities0local["Case"] != "6000000") ]
pd_capacities0local= pd_capacities0local[(pd_capacities0local["Case"] != "4800000") ]
pd_capacities0local= pd_capacities0local[(pd_capacities0local["Case"] != "4400000") ]
pd_capacities0local= pd_capacities0local[(pd_capacities0local["Case"] != "3500000") ]
pd_capacities0local= pd_capacities0local[(pd_capacities0local["Case"] != "3200000") ]
pd_capacities0local= pd_capacities0local[(pd_capacities0local["Case"] != "3120000") ]
#["8000000", "6000000", "4800000", "3200000", "3120000", "3000000"]
pd_capacities0local["Case"]=pd_capacities0local["Case"].astype(int)/1000/20
pd_capacities0local["Case"]=pd_capacities0local["Case"].astype(int)

axes[2,1].set_axis_bgcolor('white')

parallel_coordinates(pd_capacities0local, 'Case', color=snscolor,ax=axes[2,1], axvlines =True, **{'linewidth':0.3, 'alpha':0.6}) #alpha is transparency
leg=axes[2,1].legend(loc='best',fontsize=9)
# set the linewidth of each legend object
for legobj in leg.legendHandles:
    legobj.set_linewidth(3.0)
    
axes[2,1].spines['right'].set_color('k')
axes[2,1].spines['right'].set_linewidth(0.9)
axes[2,1].spines['right'].set_alpha(1)

#plt.ylim([0,15])
axes[2,1].set_ylabel('Capacity', **{'fontsize': 12})
axes[2,1].tick_params(axis='both', which='major', labelsize=12)

axes[2,1].set_title('100 %', fontsize=14, fontweight='bold')    


plt.axis('tight')
path=r'T:\IEEE_case_study\Normal\GRIDUPGRADE\Capacities.png'#path to lis
fig.savefig(path,bbox_inches='tight',dpi=500) #save the fig

# %% [markdown]
# # DH potential and grid upgrade

# %%
h5objectives05=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Objectives/NORM_RelaxedUniInt_CHPboiler_noPWL05')

# %%
hdf=pd.HDFStore(r'T:\IEEE_case_study\data_working.h5') 
hdf.put('/Objectives/NORM_RelaxedUniInt_CHPboiler_noPWL05', h5objectives05, format='table', data_columns=True)
hdf.close()

# %%
h5objectives04=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Objectives/NORM_RelaxedUniInt_CHPboiler_noPWL04')
h5objectives04
# Out:
#                Inv_cost       Oper_cost      Total_cost       Emissions  \
# 4400000  2318115.300502   688091.527428  3006206.827930  4400000.000000
# 4600000  1849838.510114   919658.595459  2769497.105573  4600000.000000
# 4800000  1522189.617767  1079946.083731  2602135.701498  4800000.000000
# 5000000  1174030.477056  1210948.780132  2384979.257189  5000000.000000
# 5500000   794179.131065  1415476.591971  2209655.723036  5500000.000000
# 6000000   556191.577789  1576798.239448  2132989.817237  6000000.000000
# 8000000   366687.935456  1746727.375589  2113415.311046  6681476.519947
#
#          Grid_upgrade  Qsum  DHconnections
# 4400000             1  1870             34
# 4600000             0  1210             24
# 4800000             0  1804             29
# 5000000             0  1918             34
# 5500000             0  3191             38
# 6000000             0  4077             38
# 8000000             0  5176             39

# %%
h5objectives04["Grid_upgrade"]["4600000"]=1
h5objectives04["Grid_upgrade"]["4800000"]=1
h5objectives04
# Out:
#                Inv_cost       Oper_cost      Total_cost       Emissions  \
# 4400000  2318115.300502   688091.527428  3006206.827930  4400000.000000
# 4600000  1849838.510114   919658.595459  2769497.105573  4600000.000000
# 4800000  1522189.617767  1079946.083731  2602135.701498  4800000.000000
# 5000000  1174030.477056  1210948.780132  2384979.257189  5000000.000000
# 5500000   794179.131065  1415476.591971  2209655.723036  5500000.000000
# 6000000   556191.577789  1576798.239448  2132989.817237  6000000.000000
# 8000000   366687.935456  1746727.375589  2113415.311046  6681476.519947
#
#          Grid_upgrade  Qsum  DHconnections
# 4400000             1  1870             34
# 4600000             1  1210             24
# 4800000             1  1804             29
# 5000000             0  1918             34
# 5500000             0  3191             38
# 6000000             0  4077             38
# 8000000             0  5176             39

# %%
hdf=pd.HDFStore(r'T:\IEEE_case_study\data.h5') 
hdf.put('/Objectives/NORM_RelaxedUniInt_CHPboiler_noPWL04', h5objectives04, format='table', data_columns=True)
hdf.close()

# %%
h5objectives03=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Objectives/NORM_RelaxedUniInt_CHPboiler_noPWL03')
h5objectives03
# Out:
#                Inv_cost       Oper_cost      Total_cost      Emissions  \
# 3200000  2573529.224709   904839.413218  3478368.637927  3200000.00000
# 3500000  1577442.273538  1453749.472933  3031191.746471  3500000.00000
# 4000000  1166334.997373  1506052.823573  2672387.820945  4000000.00000
# 4400000  1151285.287415  1328085.991543  2479371.278957  4400000.00000
# 4600000  1105403.072101  1288874.664020  2394277.736121  4600000.00000
# 4800000   998399.740301  1315226.148453  2313625.888754  4800000.00000
# 5000000   883418.753440  1374003.896382  2257422.649822  5000000.00000
# 5500000   613275.980729  1525983.048533  2139259.029263  5500000.00000
# 6000000   464007.967224  1659560.525902  2123568.493126  6000000.00000
# 8000000   368558.236333  1745116.699532  2113674.935866  6314787.84649
#
#          Grid_upgrade  Qsum  DHconnections
# 3200000             1     3              1
# 3500000             0     0              0
# 4000000             0   229              4
# ...

# %%
h5objectives02=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Objectives/NORM_RelaxedUniInt_CHPboiler_noPWL02')
h5objectives02
# Out:
#                Inv_cost       Oper_cost      Total_cost       Emissions  \
# 2500000  1186057.112876  1708525.459591  2894582.572467  2500000.000000
# 3000000   892235.906279  1762611.914179  2654847.820457  3000000.000000
# 3100000   888472.770874  1739609.798592  2628082.569467  3100000.000000
# 3200000   877622.379665  1721280.300364  2598902.680029  3200000.000000
# 3500000   868853.396946  1656703.000555  2525556.397501  3500000.000000
# 4000000   836120.634223  1562071.148248  2398191.782470  4000000.000000
# 4400000   790043.059264  1507670.871356  2297713.930620  4400000.000000
# 4600000   765678.605265  1485229.213037  2250907.818302  4600000.000000
# 4800000   712840.786312  1499707.713016  2212548.499327  4800000.000000
# 5000000   672517.486528  1501297.112891  2173814.599418  5000000.000000
# 5500000   488336.078282  1613607.677095  2101943.755377  5500000.000000
# 6000000   372560.583561  1705162.335895  2077722.919456  5990259.211095
# ...

# %%
h5objectives01=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Objectives/NORM_RelaxedUniInt_CHPboiler_noPWL01')
h5objectives01["Grid_upgrade"]["1300000"]=1
h5objectives01
# Out:
#                Inv_cost       Oper_cost      Total_cost       Emissions  \
# 1300000  1020034.234964  1836257.760594  2856291.995558  1300000.000000
# 1500000   741091.888368  1966208.520880  2707300.409248  1500000.000000
# 2000000   736257.533338  1880943.181269  2617200.714607  2000000.000000
# 2500000   720273.764054  1808364.330265  2528638.094320  2500000.000000
# 3000000   709847.816057  1733633.380816  2443481.196873  3000000.000000
# 3100000   706544.232807  1717387.436770  2423931.669577  3100000.000000
# 3200000   650336.950731  1841314.969279  2491651.920010  3200000.000000
# 3500000   696505.249320  1658276.283294  2354781.532613  3500000.000000
# 4000000   670324.312722  1598742.186611  2269066.499334  4000000.000000
# 4400000   668957.590217  1639930.619130  2308888.209347  4400000.000000
# 4600000   619353.967062  1554296.199855  2173650.166917  4600000.000000
# 4800000   590762.962027  1552959.708309  2143722.670336  4800000.000000
# ...

# %%
hdf=pd.HDFStore(r'T:\IEEE_case_study\data.h5') 
hdf.put('/Objectives/NORM_RelaxedUniInt_CHPboiler_noPWL01', h5objectives03, format='table', data_columns=True)
hdf.close()

# %%
h5objectives0=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Objectives/NORM_RelaxedUniInt_CHPboiler_noPWL0')
h5objectives0["Grid_upgrade"]["0"]=1
h5objectives0
# Out:
#               Inv_cost       Oper_cost      Total_cost       Emissions  \
# 0        741800.129582  2081295.141757  2823095.271339        0.000000
# 1000000  647899.542080  1947756.868245  2595656.410325  1000000.000000
# 1300000  632551.921611  1920261.096273  2552813.017884  1300000.000000
# 1500000  639382.893550  1886673.726347  2526056.619897  1500000.000000
# 2000000  601646.392512  1861912.162624  2463558.555136  2000000.000000
# 2500000  621218.702245  1773104.214775  2394322.917020  2500000.000000
# 3000000  610446.206531  1714909.975702  2325356.182232  3000000.000000
# 3100000  611691.693174  1703960.345266  2315652.038440  3100000.000000
# 3200000  614528.944684  1684592.815416  2299121.760100  3200000.000000
# 3500000  608795.576849  1650836.420647  2259631.997496  3500000.000000
# 4000000  588639.787149  1607017.193397  2195656.980545  4000000.000000
# 4400000  562977.734689  1585522.170082  2148499.904771  4400000.000000
# ...

# %%
DHalpha1=pd.DataFrame(h5objectives05["DHconnections"]/(37)).iloc[::-1]#3*(37-2)
DHalpha1.columns=["25% alpha"]

DHalpha2=pd.DataFrame(h5objectives04["DHconnections"]/(37)).iloc[::-1]#3*(37-2)
DHalpha2.columns=["40% alpha"]
DHalpha = pd.concat([DHalpha1, DHalpha2], axis=1)

DHalpha2=pd.DataFrame(h5objectives03["DHconnections"]/(37)).iloc[::-1]#3*(37-2)
DHalpha2.columns=["55% alpha"]
DHalpha = pd.concat([DHalpha, DHalpha2], axis=1)

DHalpha2=pd.DataFrame(h5objectives02["DHconnections"]/(37)).iloc[::-1]#3*(37-2)
DHalpha2.columns=["70% alpha"]
DHalpha = pd.concat([DHalpha, DHalpha2], axis=1)

DHalpha2=pd.DataFrame(h5objectives01["DHconnections"]/(37)).iloc[::-1]#3*(37-2)
DHalpha2.columns=["85% alpha"]
DHalpha = pd.concat([DHalpha, DHalpha2], axis=1)

DHalpha2=pd.DataFrame(h5objectives0["DHconnections"]/(37)).iloc[::-1]#3*(37-2)
DHalpha2.columns=["100% alpha"]
DHalpha = pd.concat([DHalpha, DHalpha2], axis=1)

# %%
DHbeta1=pd.DataFrame((h5objectives05["Qsum"]/h5objectives05["DHconnections"])/(36207/37)).iloc[::-1]
DHbeta1.columns=["25% beta"]

DHbeta2=pd.DataFrame((h5objectives04["Qsum"]/h5objectives04["DHconnections"])/(36207/37)).iloc[::-1]
DHbeta2.columns=["40% beta"]
DHbeta = pd.concat([DHbeta1, DHbeta2], axis=1)

DHbeta2=pd.DataFrame((h5objectives03["Qsum"]/h5objectives03["DHconnections"])/(36207/37)).iloc[::-1]
DHbeta2.columns=["55% beta"]
DHbeta = pd.concat([DHbeta, DHbeta2], axis=1)

DHbeta2=pd.DataFrame((h5objectives02["Qsum"]/h5objectives02["DHconnections"])/(36207/37)).iloc[::-1]
DHbeta2.columns=["70% beta"]
DHbeta = pd.concat([DHbeta, DHbeta2], axis=1)

DHbeta2=pd.DataFrame((h5objectives01["Qsum"]/h5objectives01["DHconnections"])/(36207/37)).iloc[::-1]
DHbeta2.columns=["85% beta"]
DHbeta = pd.concat([DHbeta, DHbeta2], axis=1)

DHbeta2=pd.DataFrame((h5objectives0["Qsum"]/h5objectives0["DHconnections"])/(36207/37)).iloc[::-1]
DHbeta2.columns=["100% beta"]
DHbeta = pd.concat([DHbeta, DHbeta2], axis=1)

# %%
DHpotential = pd.concat([DHalpha, DHbeta], axis=1)

DHpotential["25"]=1
DHpotential["40"]=2
DHpotential["55"]=3
DHpotential["70"]=4
DHpotential["85"]=5
DHpotential["100"]=6

DHpotential=DHpotential.iloc[::-1]
DHpotential["Carbon"]=np.nan
for i,num in enumerate(DHpotential.index.values):
    DHpotential["Carbon"][i]=list(DHpotential.index.values)[i]

DHpotential["Carbon"]=list(reversed(range(1,18+1)))
# Out:
#          25% alpha  40% alpha  55% alpha  70% alpha  85% alpha  100% alpha  \
# 8000000   1.216216   1.054054   0.972973   1.027027   1.054054    1.000000
# 6000000   1.054054   1.027027   1.027027   1.054054   1.054054    1.027027
# 5500000   1.081081   1.027027   1.135135   1.135135   1.027027    1.081081
# 5000000   0.918919   0.918919   0.621622   0.756757   1.081081    1.108108
# 4800000   0.150000   0.783784   0.621622   0.864865   1.027027    0.945946
# 4600000   0.010000   0.648649   0.405405   0.729730   0.864865    0.945946
# 4400000        NaN   0.010000   0.216216   0.621622   0.702703    0.945946
# 4000000        NaN        NaN   0.108108   0.567568   0.864865    0.837838
# 3500000        NaN        NaN   0.000000   0.378378   0.648649    0.810811
# 3200000        NaN        NaN   0.027027   0.621622   0.675676    0.756757
# 3100000        NaN        NaN        NaN   0.513514   0.675676    0.648649
# ...

# %%
fig, ax = plt.subplots()
ax.set_axis_bgcolor('white')


DHpotential.plot.scatter(x="25",y="Carbon",s=(DHpotential['25% alpha']+0.01)*100, c='25% beta' , vmin=0, vmax=0.2, ax=ax, cmap='GnBu', zorder=20)
DHpotential.plot.scatter(x="40",y="Carbon",s=(DHpotential['40% alpha']+0.01)*100, c='40% beta',vmin=0, vmax=0.2, ax=ax,   cmap='GnBu' , zorder=20)
DHpotential.plot.scatter(x="55",y="Carbon",s=(DHpotential['55% alpha']+0.01)*100, c='55% beta',vmin=0, vmax=0.2, ax=ax,   cmap='GnBu' , zorder=20)
DHpotential.plot.scatter(x="70",y="Carbon",s=(DHpotential['70% alpha']+0.01)*100, c='70% beta',vmin=0, vmax=0.2, ax=ax,  cmap='GnBu' , zorder=20)
DHpotential.plot.scatter(x="85",y="Carbon",s=(DHpotential['85% alpha']+0.01)*100, c='85% beta',vmin=0, vmax=0.2, ax=ax,  cmap='GnBu' , zorder=20)
DHpotential.plot.scatter(x="100",y="Carbon",s=(DHpotential['100% alpha']+0.001)*100, c='100% beta',vmin=0, vmax=0.2, ax=ax,  cmap='GnBu' , zorder=20)

#

ax.spines['bottom'].set_color('black')
ax.spines['bottom'].set_linewidth(0.4)

ax.spines['top'].set_color('black')
ax.spines['top'].set_linewidth(0.4)

ax.spines['left'].set_color('black')
ax.spines['left'].set_linewidth(0.4)

ax.spines['right'].set_color('black')
ax.spines['right'].set_linewidth(0.4)

for num,value in enumerate(h5objectives0["Grid_upgrade"]):
    if value==1:
        p = mpl.patches.Rectangle((5.5,num+0.5), 1, 1, hatch='/', fill=None,zorder=10, linestyle='solid',linewidth='0.6', color='black')
        ax.add_patch(p)
        
        p = mpl.patches.Rectangle((5.5,num+1.5), 1, 1, hatch='/', fill=None,zorder=10, linestyle='solid',linewidth='0.6', color='black') # add patch one above grid upgrade
        ax.add_patch(p) # add patch one above grid upgrade
     
    else:
        p = mpl.patches.Rectangle((5.5,num+0.5), 1, 1, hatch='', fill=None,zorder=10)
        ax.add_patch(p)
        
for num,value in enumerate(h5objectives01["Grid_upgrade"]):
    if value==1:
        p = mpl.patches.Rectangle((4.5,num+2.5), 1, 1, hatch='/', fill=None,zorder=10, linestyle='solid',linewidth='0.6', color='black')
        ax.add_patch(p)
        
        p = mpl.patches.Rectangle((4.5,num+3.5), 1, 1, hatch='/', fill=None,zorder=10, linestyle='solid',linewidth='0.6', color='black') # add patch one above grid upgrade
        ax.add_patch(p) # add patch one above grid upgrade
     
    else:
        p = mpl.patches.Rectangle((4.5,num+2.5), 1, 1, hatch='', fill=None,zorder=10)
        ax.add_patch(p)

for num,value in enumerate(h5objectives02["Grid_upgrade"]):
    if value==1:
        p = mpl.patches.Rectangle((3.5,num+5.5), 1, 1, hatch='/', fill=None,zorder=10, linestyle='solid',linewidth='0.6', color='black')
        ax.add_patch(p)
        
        p = mpl.patches.Rectangle((3.5,num+6.5), 1, 1, hatch='/', fill=None,zorder=10, linestyle='solid',linewidth='0.6', color='black') # add patch one above grid upgrade
        ax.add_patch(p) # add patch one above grid upgrade
     
    else:
        p = mpl.patches.Rectangle((3.5,num+5.5), 1, 1, hatch='', fill=None,zorder=10)
        ax.add_patch(p)
        
for num,value in enumerate(h5objectives03["Grid_upgrade"]):
    if value==1:
        p = mpl.patches.Rectangle((2.5,num+8.5), 1, 1, hatch='/', fill=None,zorder=10, linestyle='solid',linewidth='0.6', color='black')
        ax.add_patch(p)
        
        p = mpl.patches.Rectangle((2.5,num+9.5), 1, 1, hatch='/', fill=None,zorder=10, linestyle='solid',linewidth='0.6', color='black') # add patch one above grid upgrade
        ax.add_patch(p) # add patch one above grid upgrade
     
    else:
        p = mpl.patches.Rectangle((2.5,num+8.5), 1, 1, hatch='', fill=None,zorder=10)
        ax.add_patch(p)
        
for num,value in enumerate(h5objectives04["Grid_upgrade"]):
    if value==1:
        p = mpl.patches.Rectangle((1.5,num+11.5), 1, 1, hatch='/', fill=None,zorder=10, linestyle='solid',linewidth='0.6', color='black')
        ax.add_patch(p)
     
    else:
        p = mpl.patches.Rectangle((1.5,num+11.5), 1, 1, hatch='', fill=None,zorder=10)
        ax.add_patch(p)

for num,value in enumerate(h5objectives05["Grid_upgrade"]):
    if value==1:
        p = mpl.patches.Rectangle((0.5,num+12.5), 1, 1, hatch='/', fill=None,zorder=10, linestyle='solid',linewidth='0.6', color='black')
        ax.add_patch(p)
     
    else:
        p = mpl.patches.Rectangle((0.5,num+12.5), 1, 1, hatch='', fill=None,zorder=10)
        ax.add_patch(p)
        

        
##################################
########## ADD GREY AREA #########
##################################

##### 25 %

p = mpl.patches.Rectangle((0.5,0.5), 1, 1, hatch='', fill=True, color='0.93') 
ax.add_patch(p) 
p = mpl.patches.Rectangle((0.5,1.5), 1, 1, hatch='', fill=True, color='0.93') 
ax.add_patch(p) 
p = mpl.patches.Rectangle((0.5,2.5), 1, 1, hatch='', fill=True, color='0.93') 
ax.add_patch(p) 
p = mpl.patches.Rectangle((0.5,3.5), 1, 1, hatch='', fill=True, color='0.93') 
ax.add_patch(p) 
p = mpl.patches.Rectangle((0.5,4.5), 1, 1, hatch='', fill=True, color='0.93') 
ax.add_patch(p) 
p = mpl.patches.Rectangle((0.5,5.5), 1, 1, hatch='', fill=True, color='0.93') 
ax.add_patch(p) 
p = mpl.patches.Rectangle((0.5,6.5), 1, 1, hatch='', fill=True, color='0.93') 
ax.add_patch(p) 
p = mpl.patches.Rectangle((0.5,7.5), 1, 1, hatch='', fill=True, color='0.93') 
ax.add_patch(p) 
p = mpl.patches.Rectangle((0.5,8.5), 1, 1, hatch='', fill=True, color='0.93') 
ax.add_patch(p) 
p = mpl.patches.Rectangle((0.5,9.5), 1, 1, hatch='', fill=True, color='0.93') 
ax.add_patch(p) 
p = mpl.patches.Rectangle((0.5,10.5), 1, 1, hatch='', fill=True, color='0.93') 
ax.add_patch(p) 
p = mpl.patches.Rectangle((0.5,11.5), 1, 1, hatch='', fill=True, color='0.93') 
ax.add_patch(p) 

###3### 40 %

p = mpl.patches.Rectangle((1.5,0.5), 1, 1, hatch='', fill=True, color='0.93') 
ax.add_patch(p) 
p = mpl.patches.Rectangle((1.5,1.5), 1, 1, hatch='', fill=True, color='0.93') 
ax.add_patch(p) 
p = mpl.patches.Rectangle((1.5,2.5), 1, 1, hatch='', fill=True, color='0.93') 
ax.add_patch(p) 
p = mpl.patches.Rectangle((1.5,3.5), 1, 1, hatch='', fill=True, color='0.93') 
ax.add_patch(p) 
p = mpl.patches.Rectangle((1.5,4.5), 1, 1, hatch='', fill=True, color='0.93') 
ax.add_patch(p) 
p = mpl.patches.Rectangle((1.5,5.5), 1, 1, hatch='', fill=True, color='0.93') 
ax.add_patch(p) 
p = mpl.patches.Rectangle((1.5,6.5), 1, 1, hatch='', fill=True, color='0.93') 
ax.add_patch(p) 
p = mpl.patches.Rectangle((1.5,7.5), 1, 1, hatch='', fill=True, color='0.93') 
ax.add_patch(p) 
p = mpl.patches.Rectangle((1.5,8.5), 1, 1, hatch='', fill=True, color='0.93') 
ax.add_patch(p) 
p = mpl.patches.Rectangle((1.5,9.5), 1, 1, hatch='', fill=True, color='0.93') 
ax.add_patch(p) 
p = mpl.patches.Rectangle((1.5,10.5), 1, 1, hatch='', fill=True, color='0.93') 
ax.add_patch(p) 

###3### 50 %

p = mpl.patches.Rectangle((2.5,0.5), 1, 1, hatch='', fill=True, color='0.93') 
ax.add_patch(p) 
p = mpl.patches.Rectangle((2.5,1.5), 1, 1, hatch='', fill=True, color='0.93') 
ax.add_patch(p) 
p = mpl.patches.Rectangle((2.5,2.5), 1, 1, hatch='', fill=True, color='0.93') 
ax.add_patch(p) 
p = mpl.patches.Rectangle((2.5,3.5), 1, 1, hatch='', fill=True, color='0.93') 
ax.add_patch(p) 
p = mpl.patches.Rectangle((2.5,4.5), 1, 1, hatch='', fill=True, color='0.93') 
ax.add_patch(p) 
p = mpl.patches.Rectangle((2.5,5.5), 1, 1, hatch='', fill=True, color='0.93') 
ax.add_patch(p) 
p = mpl.patches.Rectangle((2.5,6.5), 1, 1, hatch='', fill=True, color='0.93') 
ax.add_patch(p) 
p = mpl.patches.Rectangle((2.5,7.5), 1, 1, hatch='', fill=True, color='0.93') 
ax.add_patch(p) 

###3### 70 %

p = mpl.patches.Rectangle((3.5,0.5), 1, 1, hatch='', fill=True, color='0.93') 
ax.add_patch(p) 
p = mpl.patches.Rectangle((3.5,1.5), 1, 1, hatch='', fill=True, color='0.93') 
ax.add_patch(p) 
p = mpl.patches.Rectangle((3.5,2.5), 1, 1, hatch='', fill=True, color='0.93') 
ax.add_patch(p) 
p = mpl.patches.Rectangle((3.5,3.5), 1, 1, hatch='', fill=True, color='0.93') 
ax.add_patch(p) 
p = mpl.patches.Rectangle((3.5,4.5), 1, 1, hatch='', fill=True, color='0.93') 
ax.add_patch(p) 



###3### 85 %

p = mpl.patches.Rectangle((4.5,0.5), 1, 1, hatch='', fill=True, color='0.93') 
ax.add_patch(p) 
p = mpl.patches.Rectangle((4.5,1.5), 1, 1, hatch='', fill=True, color='0.93') 
ax.add_patch(p) 




#fig.delaxes(fig.axes[4])
fig.delaxes(fig.axes[-2])
#fig.delaxes(fig.axes[-1]) #remove extra colorbars
fig.delaxes(fig.axes[2])
fig.delaxes(fig.axes[3])
fig.delaxes(fig.axes[1])
#fig.delaxes(fig.axes[0])



#fig.axes[3].spines['bottom'].set_color('black')
#fig.axes[3].spines['bottom'].set_linewidth(0.0)

ax.spines['top'].set_color('black')
ax.spines['top'].set_linewidth(0.4)

ax.spines['left'].set_color('black')
ax.spines['left'].set_linewidth(0.4)

ax.spines['right'].set_color('black')
ax.spines['right'].set_linewidth(0.4)

ax.grid(b=False) #remove grid
fig.set_figheight(5)
fig.set_figwidth(8)

        

#labels = ["25%", "55%", "85%", "100%"]

labelsx = [item for item in ax.get_xticks()]


for num,value in enumerate(labelsx):
    if value==1:
        labelsx[num]='25%'
    elif value==2:
        labelsx[num]='40%'
    elif value==3:
        labelsx[num]='55%'
    elif value==4:
        labelsx[num]='70%'
    elif value==5:
        labelsx[num]='85%'
    elif value==6:
        labelsx[num]='100%'
    else:
        labelsx[num]=''

            
        
ax.set_xticklabels(labelsx, **{'fontsize': 10})

labelsy = [item for item in ax.get_yticks()]


for num,value in enumerate(labelsy):
    if value==1:
        labelsy[num]='Carbon optimal'
    elif value==4:
        labelsy[num]='0 carbon'
    elif value==8:
        labelsy[num]='Cost optimal'
    else:
        labelsy[num]=''

ax.set_yticklabels(labelsy, **{'fontsize': 10})

ax.set_xlabel('Renewable share in the grid', **{'fontsize': 12})
ax.set_ylabel('')
plt.ylim([0.5,18.5])
plt.xlim([0.5,6.5])

cbar_ax = fig.axes[-1]
cbar_ax.set_ylabel('DH utilization', **{'fontsize': 12})
fig.delaxes(fig.axes[1])
#cbar_ax.outline.set_visible(False)
fig.set_figheight(4)
#fig.set_figwidth(8)
#plt.axis('tight')

##THE TOP GRAY AREA
p = mpl.patches.Rectangle((2.5,17.5), 1, 1, hatch='', fill=None, zorder=31) 
ax.add_patch(p)

p = mpl.patches.Rectangle((3.5,17.5), 1, 1, hatch='', fill=True, color='0.93', zorder=30) 
ax.add_patch(p)
p = mpl.patches.Rectangle((3.5,16.5), 1, 1, hatch='', fill=None, zorder=31) 
ax.add_patch(p) 

p = mpl.patches.Rectangle((4.5,17.5), 1, 1, hatch='', fill=True, color='0.93', linestyle='solid',zorder=30) 
ax.add_patch(p) 
p = mpl.patches.Rectangle((4.5,16.5), 1, 1, hatch='', fill=True, color='0.93', linestyle='solid',zorder=30) 
ax.add_patch(p)
p = mpl.patches.Rectangle((4.5,15.5), 1, 1, hatch='', fill=None, zorder=31) 
ax.add_patch(p) 


p = mpl.patches.Rectangle((5.5,17.5), 1, 1, hatch='', fill=True, color='0.93', linestyle='solid',zorder=30) 
ax.add_patch(p) 
p = mpl.patches.Rectangle((5.5,16.5), 1, 1, hatch='', fill=True, color='0.93', linestyle='solid',zorder=30) 
ax.add_patch(p) 
p = mpl.patches.Rectangle((5.5,15.5), 1, 1, hatch='', fill=None, zorder=31) 
ax.add_patch(p) 

plt.tick_params(axis='both', which='major', labelsize=10)
plt.tick_params(axis='both', which='minor', labelsize=10)
plt.tight_layout()

path='T:\IEEE_case_study\Normal\GRIDUPGRADE\DHpotentialPAPER.png'#path to lis
fig.savefig(path,bbox_inches='tight',dpi=500) #save the fig

# %% [markdown]
# # Pareto front

# %%
h5objectives05=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Objectives/NORM_RelaxedUniInt_CHPboiler_noPWL05')
del h5objectives05["Grid_upgrade"]
del h5objectives05["Qsum"]
del h5objectives05["DHconnections"]
h5objectives05['Case']='25%'
h5objectives05
# Out:
#                Inv_cost       Oper_cost      Total_cost       Emissions Case
# 4600000  1717489.476489   944450.047244  3125953.543280  4600000.000000  25%
# 4800000  2105701.466036   774253.950560  2879955.416596  4800000.000000  25%
# 5000000  1781691.689966   949367.904556  2731059.594522  5000000.000000  25%
# 5500000  1041461.136456  1275855.479777  2317316.616233  5500000.000000  25%
# 6000000   708204.404617  1469243.254411  2177447.659028  6000000.000000  25%
# 8000000   380953.915334  1699164.660492  2080118.575826  6830225.655325  25%

# %%
h5objectives04=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Objectives/NORM_RelaxedUniInt_CHPboiler_noPWL04')
del h5objectives04["Grid_upgrade"]
del h5objectives04["Qsum"]
del h5objectives04["DHconnections"]
h5objectives04['Case']='40%'
h5objectives04
# Out:
#                Inv_cost       Oper_cost      Total_cost       Emissions Case
# 4400000  2318115.300502   688091.527428  3006206.827930  4400000.000000  40%
# 4600000  1849838.510114   919658.595459  2769497.105573  4600000.000000  40%
# 4800000  1522189.617767  1079946.083731  2602135.701498  4800000.000000  40%
# 5000000  1174030.477056  1210948.780132  2384979.257189  5000000.000000  40%
# 5500000   794179.131065  1415476.591971  2209655.723036  5500000.000000  40%
# 6000000   556191.577789  1576798.239448  2132989.817237  6000000.000000  40%
# 8000000   366687.935456  1746727.375589  2113415.311046  6681476.519947  40%

# %%
Pareto=pd.concat([h5objectives05,h5objectives04], axis=0)

# %%
h5objectives03=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Objectives/NORM_RelaxedUniInt_CHPboiler_noPWL03')
del h5objectives03["Grid_upgrade"]
del h5objectives03["Qsum"]
del h5objectives03["DHconnections"]
h5objectives03['Case']='55%'
h5objectives03
# Out:
#                Inv_cost       Oper_cost      Total_cost      Emissions Case
# 3200000  2573529.224709   904839.413218  3121547.652340  3200000.00000  55%
# 3500000  1577442.273538  1453749.472933  3031191.746471  3500000.00000  55%
# 4000000  1166334.997373  1506052.823573  2672387.820945  4000000.00000  55%
# 4400000  1151285.287415  1328085.991543  2479371.278957  4400000.00000  55%
# 4600000  1105403.072101  1288874.664020  2394277.736121  4600000.00000  55%
# 4800000   998399.740301  1315226.148453  2313625.888754  4800000.00000  55%
# 5000000   883418.753440  1374003.896382  2257422.649822  5000000.00000  55%
# 5500000   613275.980729  1525983.048533  2139259.029263  5500000.00000  55%
# 6000000   464007.967224  1659560.525902  2123568.493126  6000000.00000  55%
# 8000000   368558.236333  1745116.699532  2101654.632340  6314787.84649  55%

# %%
Pareto=pd.concat([Pareto,h5objectives03], axis=0)

# %%
h5objectives02=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Objectives/NORM_RelaxedUniInt_CHPboiler_noPWL02')
del h5objectives02["Grid_upgrade"]
del h5objectives02["Qsum"]
del h5objectives02["DHconnections"]
h5objectives02['Case']='70%'
h5objectives02
# Out:
#                Inv_cost       Oper_cost      Total_cost       Emissions Case
# 2500000  1186057.112876  1708525.459591  2894582.572467  2500000.000000  70%
# 3000000   892235.906279  1762611.914179  2654847.820457  3000000.000000  70%
# 3100000   888472.770874  1739609.798592  2628082.569467  3100000.000000  70%
# 3200000   877622.379665  1721280.300364  2598902.680029  3200000.000000  70%
# 3500000   868853.396946  1656703.000555  2525556.397501  3500000.000000  70%
# 4000000   836120.634223  1562071.148248  2398191.782470  4000000.000000  70%
# 4400000   790043.059264  1507670.871356  2297713.930620  4400000.000000  70%
# 4600000   765678.605265  1485229.213037  2250907.818302  4600000.000000  70%
# 4800000   712840.786312  1499707.713016  2212548.499327  4800000.000000  70%
# 5000000   672517.486528  1501297.112891  2173814.599418  5000000.000000  70%
# 5500000   488336.078282  1613607.677095  2145876.156500  5500000.000000  70%
# ...

# %%
Pareto=pd.concat([Pareto,h5objectives02], axis=0)

# %%
h5objectives01=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Objectives/NORM_RelaxedUniInt_CHPboiler_noPWL01')
del h5objectives01["Grid_upgrade"]
del h5objectives01["Qsum"]
del h5objectives01["DHconnections"]
h5objectives01.drop("8000000", axis=0, inplace=True)
h5objectives01.drop("6000000", axis=0, inplace=True)
h5objectives01['Case']='85%'
h5objectives01
# Out:
#                Inv_cost       Oper_cost      Total_cost      Emissions Case
# 1300000  1020034.234964  1836257.760594  2856291.995558  1300000.00000  85%
# 1500000   741091.888368  1966208.520880  2707300.409248  1500000.00000  85%
# 2000000   736257.533338  1880943.181269  2617200.714607  2000000.00000  85%
# 2500000   720273.764054  1808364.330265  2528638.094320  2500000.00000  85%
# 3000000   709847.816057  1733633.380816  2443481.196873  3000000.00000  85%
# 3100000   706544.232807  1717387.436770  2423931.669577  3100000.00000  85%
# 3200000   650336.950731  1841314.969279  2397512.145800  3200000.00000  85%
# 3500000   696505.249320  1658276.283294  2354781.532613  3500000.00000  85%
# 4000000   670324.312722  1598742.186611  2269066.499334  4000000.00000  85%
# 4400000   668957.590217  1639930.619130  2241685.153500  4400000.00000  85%
# 4600000   619353.967062  1554296.199855  2173650.166917  4600000.00000  85%
# ...

# %%
Pareto=pd.concat([Pareto,h5objectives01], axis=0)

# %%
h5objectives0=pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Objectives/NORM_RelaxedUniInt_CHPboiler_noPWL0')
del h5objectives0["Grid_upgrade"]
del h5objectives0["Qsum"]
del h5objectives0["DHconnections"]
h5objectives0.drop("8000000", axis=0, inplace=True)
h5objectives0.drop("6000000", axis=0, inplace=True)
h5objectives0.drop("5000000", axis=0, inplace=True)
h5objectives0['Case']='100%'
h5objectives0
# Out:
#               Inv_cost       Oper_cost      Total_cost       Emissions  Case
# 0        741800.129582  2081295.141757  2823095.271339        0.000000  100%
# 1000000  647899.542080  1947756.868245  2595656.410325  1000000.000000  100%
# 1300000  632551.921611  1920261.096273  2552813.017884  1300000.000000  100%
# 1500000  639382.893550  1886673.726347  2526056.619897  1500000.000000  100%
# 2000000  601646.392512  1861912.162624  2463558.555136  2000000.000000  100%
# 2500000  621218.702245  1773104.214775  2394322.917020  2500000.000000  100%
# 3000000  610446.206531  1714909.975702  2325356.182232  3000000.000000  100%
# 3100000  611691.693174  1703960.345266  2315652.038440  3100000.000000  100%
# 3200000  614528.944684  1684592.815416  2299121.760100  3200000.000000  100%
# 3500000  608795.576849  1650836.420647  2259631.997496  3500000.000000  100%
# 4000000  588639.787149  1607017.193397  2195656.980545  4000000.000000  100%
# ...

# %%
Pareto=pd.concat([Pareto,h5objectives0], axis=0)

# %%
Pareto["Emissions"]=Pareto["Emissions"]/1000/20
Pareto["Total_cost"]=Pareto["Total_cost"]/1000/20

h5objectives05["Emissions"]=h5objectives05["Emissions"]/1000/20
h5objectives05["Total_cost"]=h5objectives05["Total_cost"]/1000/20

h5objectives04["Emissions"]=h5objectives04["Emissions"]/1000/20
h5objectives04["Total_cost"]=h5objectives04["Total_cost"]/1000/20

h5objectives03["Emissions"]=h5objectives03["Emissions"]/1000/20
h5objectives03["Total_cost"]=h5objectives03["Total_cost"]/1000/20

h5objectives02["Emissions"]=h5objectives02["Emissions"]/1000/20
h5objectives02["Total_cost"]=h5objectives02["Total_cost"]/1000/20

h5objectives01["Emissions"]=h5objectives01["Emissions"]/1000/20
h5objectives01["Total_cost"]=h5objectives01["Total_cost"]/1000/20

h5objectives0["Emissions"]=h5objectives0["Emissions"]/1000/20
h5objectives0["Total_cost"]=h5objectives0["Total_cost"]/1000/20

# %%
#fig, ax = plt.subplots()
#ax.set_axis_bgcolor('white')
color=sns.color_palette("muted")



lm=sns.lmplot('Emissions', 'Total_cost', data=Pareto, fit_reg=False,  hue="Case", markers=['o', 'v', 's', 'p', 'D', 'h'], scatter=True, palette= color, scatter_kws={"s": 40}, legend= False, size=5, aspect=1.5) #,  scatter_kws={"marker": "D", "s": 100}
ax=lm.axes

plt.legend(title='Scenarios',loc='upper right')

h5objectives05.plot(x="Emissions", y="Total_cost", ax=ax[0,0], color=color[0], legend= False)
h5objectives04.plot(x="Emissions", y="Total_cost", ax=ax[0,0], color=color[1], legend= False)
h5objectives03.plot(x="Emissions", y="Total_cost", ax=ax[0,0], color=color[2], legend= False)
h5objectives02.plot(x="Emissions", y="Total_cost", ax=ax[0,0], color=color[3], legend= False)
h5objectives01.plot(x="Emissions", y="Total_cost", ax=ax[0,0], color=color[4], legend= False)
h5objectives0.plot(x="Emissions", y="Total_cost", ax=ax[0,0], color=color[5], legend= False)
#Pareto.groupby("Case").plot(x="Emissions", y="Total_cost", ax=ax[0,0], colormap=color)

ax[0,0].set_axis_bgcolor('white')

ax[0,0].spines['bottom'].set_color('black')
ax[0,0].spines['bottom'].set_linewidth(0.4)


ax[0,0].spines['left'].set_color('black')
ax[0,0].spines['left'].set_linewidth(0.4)


#plt.title('Pareto front')
plt.xlabel(r'$Carbon\/\/ Emissions\/ (tCO_2 /y) $')
plt.ylabel(r'$Total\/\/ Cost\/ (10^3 $'+ u'\u20AC'+' /y )')

#ax.set_xlabel('Renewable share in the grid', **{'fontsize': 12})
#ax.set_ylabel('')
plt.ylim([100,190])
plt.xlim([-7,350])


#cbar_ax = fig.axes[-1]
#cbar_ax.set_ylabel('DH capacity', **{'fontsize': 12})
#fig.delaxes(fig.axes[1])
#cbar_ax.outline.set_visible(False)



#plt.axis('tight')

#plt.show()

path='T:\IEEE_case_study\Normal\GRIDUPGRADE\Pareto.png'#path to lis
plt.savefig(path,bbox_inches='tight',dpi=500) #save the fig

# %% [markdown]
# # CURRENT AND VOLTAGE

# %% [markdown]
# CF 0.5

# %%
##########################################
################ CURRENT #################
##########################################


A_8000_CF05 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL05/8000000/CurentA')

colA=A_8000_CF05.columns
CurrentCF05= np.array(A_8000_CF05['I12'])

for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
        
for cols in colA[1:]:
    CurrentCF05=np.append(CurrentCF05,np.array(A_8000_CF05[cols]))
    
    
B_8000_CF05 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL05/8000000/CurentB')

colA=B_8000_CF05.columns

for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    CurrentCF05=np.append(CurrentCF05,np.array(B_8000_CF05[cols]))
    
C_8000_CF05 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL05/8000000/CurentC')

colA=C_8000_CF05.columns
for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    CurrentCF05=np.append(CurrentCF05,np.array(C_8000_CF05[cols]))

    
    
    
A_6000_CF05 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL05/6000000/CurentA')

colA=A_6000_CF05.columns
for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    CurrentCF05=np.append(CurrentCF05,np.array(A_6000_CF05[cols]))
    
B_6000_CF05 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL05/6000000/CurentB')

colA=B_6000_CF05.columns
for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    CurrentCF05=np.append(CurrentCF05,np.array(B_6000_CF05[cols]))
    
C_6000_CF05 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL05/6000000/CurentC')

colA=C_6000_CF05.columns
for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    CurrentCF05=np.append(CurrentCF05,np.array(C_6000_CF05[cols]))
    
    
    

A_5500_CF05 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL05/5500000/CurentA')

colA=A_5500_CF05.columns
for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    CurrentCF05=np.append(CurrentCF05,np.array(A_5500_CF05[cols]))
    
B_5500_CF05 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL05/5500000/CurentB')

colA=B_5500_CF05.columns
for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    CurrentCF05=np.append(CurrentCF05,np.array(B_5500_CF05[cols]))
    
C_5500_CF05 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL05/5500000/CurentC')

colA=C_5500_CF05.columns
for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    CurrentCF05=np.append(CurrentCF05,np.array(C_5500_CF05[cols]))

    
    
A_5000_CF05 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL05/5000000/CurentA')

colA=A_5000_CF05.columns
for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    CurrentCF05=np.append(CurrentCF05,np.array(A_5000_CF05[cols]))
    
B_5000_CF05 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL05/5000000/CurentB')

colA=B_5000_CF05.columns
for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    CurrentCF05=np.append(CurrentCF05,np.array(B_5000_CF05[cols]))
    
C_5000_CF05 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL05/5000000/CurentC')

colA=C_5000_CF05.columns
for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    CurrentCF05=np.append(CurrentCF05,np.array(C_5000_CF05[cols]))
    
    
    

A_4800_CF05 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL05/4800000/CurentA')

colA=A_4800_CF05.columns
for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    CurrentCF05=np.append(CurrentCF05,np.array(A_4800_CF05[cols]))
    
B_4800_CF05 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL05/4800000/CurentB')

colA=B_4800_CF05.columns
for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    CurrentCF05=np.append(CurrentCF05,np.array(B_4800_CF05[cols]))
    
C_4800_CF05 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL05/4800000/CurentC')

colA=C_4800_CF05.columns
for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    CurrentCF05=np.append(CurrentCF05,np.array(C_4800_CF05[cols]))
    
    
    

A_4600_CF05 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL05/4600000/CurentA')

colA=A_4600_CF05.columns
for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    CurrentCF05=np.append(CurrentCF05,np.array(A_4600_CF05[cols]))
    
B_4600_CF05 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL05/4600000/CurentB')

colA=B_4600_CF05.columns
for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    CurrentCF05=np.append(CurrentCF05,np.array(B_4600_CF05[cols]))
    
C_4600_CF05 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL05/4600000/CurentC')

colA=C_4600_CF05.columns
for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    CurrentCF05=np.append(CurrentCF05,np.array(C_4600_CF05[cols]))

###########################
##### VOLTAGES ############
##########################


A_8000_CF05 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL05/8000000/VoltageA')

colA=A_8000_CF05.columns
VoltageCF05= np.array(A_8000_CF05['2'])
for cols in colA[1:]:
    VoltageCF05=np.append(VoltageCF05,np.array(A_8000_CF05[cols]))
    
    
B_8000_CF05 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL05/8000000/VoltageB')

colA=B_8000_CF05.columns
for cols in colA:
    VoltageCF05=np.append(VoltageCF05,np.array(B_8000_CF05[cols]))
    
C_8000_CF05 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL05/8000000/VoltageC')

colA=C_8000_CF05.columns
for cols in colA:
    VoltageCF05=np.append(VoltageCF05,np.array(C_8000_CF05[cols]))

    
    
    
A_6000_CF05 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL05/6000000/VoltageA')

colA=A_6000_CF05.columns
for cols in colA:
    VoltageCF05=np.append(VoltageCF05,np.array(A_6000_CF05[cols]))
    
B_6000_CF05 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL05/6000000/VoltageB')

colA=B_6000_CF05.columns
for cols in colA:
    VoltageCF05=np.append(VoltageCF05,np.array(B_6000_CF05[cols]))
    
C_6000_CF05 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL05/6000000/VoltageC')

colA=C_6000_CF05.columns
for cols in colA:
    VoltageCF05=np.append(VoltageCF05,np.array(C_6000_CF05[cols]))
    
    
    

A_5500_CF05 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL05/5500000/VoltageA')

colA=A_5500_CF05.columns
for cols in colA:
    VoltageCF05=np.append(VoltageCF05,np.array(A_5500_CF05[cols]))
    
B_5500_CF05 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL05/5500000/VoltageB')

colA=B_5500_CF05.columns
for cols in colA:
    VoltageCF05=np.append(VoltageCF05,np.array(B_5500_CF05[cols]))
    
C_5500_CF05 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL05/5500000/VoltageC')

colA=C_5500_CF05.columns
for cols in colA:
    VoltageCF05=np.append(VoltageCF05,np.array(C_5500_CF05[cols]))

    
    
A_5000_CF05 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL05/5000000/VoltageA')

colA=A_5000_CF05.columns
for cols in colA:
    VoltageCF05=np.append(VoltageCF05,np.array(A_5000_CF05[cols]))
    
B_5000_CF05 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL05/5000000/VoltageB')

colA=B_5000_CF05.columns
for cols in colA:
    VoltageCF05=np.append(VoltageCF05,np.array(B_5000_CF05[cols]))
    
C_5000_CF05 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL05/5000000/VoltageC')

colA=C_5000_CF05.columns
for cols in colA:
    VoltageCF05=np.append(VoltageCF05,np.array(C_5000_CF05[cols]))
    
    
    

A_4800_CF05 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL05/4800000/VoltageA')

colA=A_4800_CF05.columns
for cols in colA:
    VoltageCF05=np.append(VoltageCF05,np.array(A_4800_CF05[cols]))
    
B_4800_CF05 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL05/4800000/VoltageB')

colA=B_4800_CF05.columns
for cols in colA:
    VoltageCF05=np.append(VoltageCF05,np.array(B_4800_CF05[cols]))
    
C_4800_CF05 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL05/4800000/VoltageC')

colA=C_4800_CF05.columns
for cols in colA:
    VoltageCF05=np.append(VoltageCF05,np.array(C_4800_CF05[cols]))
    
    
    

A_4600_CF05 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL05/4600000/VoltageA')

colA=A_4600_CF05.columns
for cols in colA:
    VoltageCF05=np.append(VoltageCF05,np.array(A_4600_CF05[cols]))
    
B_4600_CF05 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL05/4600000/VoltageB')

colA=B_4600_CF05.columns
for cols in colA:
    VoltageCF05=np.append(VoltageCF05,np.array(B_4600_CF05[cols]))
    
C_4600_CF05 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL05/4600000/VoltageC')

colA=C_4600_CF05.columns
for cols in colA:
    VoltageCF05=np.append(VoltageCF05,np.array(C_4600_CF05[cols]))

# %%
Hexplot05=pd.concat([pd.DataFrame(CurrentCF05, columns=['Current']),pd.DataFrame(VoltageCF05, columns=['Voltage'])], axis=1)
Voltage05=pd.DataFrame(VoltageCF05, columns=['25%'])
Current05=pd.DataFrame(CurrentCF05, columns=['25%'])

# %%
##########################################
################ CURRENT #################
##########################################


A_8000_CF05 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL05/8000000/CurentA')

colA=A_8000_CF05.columns
Current100CF05= np.array(A_8000_CF05['I12'])

for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
        
for cols in colA[1:]:
    Current100CF05=np.append(Current100CF05,np.array(A_8000_CF05[cols]))
    
    
B_8000_CF05 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL05/8000000/CurentB')

colA=B_8000_CF05.columns

for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    Current100CF05=np.append(Current100CF05,np.array(B_8000_CF05[cols]))
    
C_8000_CF05 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL05/8000000/CurentC')

colA=C_8000_CF05.columns
for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    Current100CF05=np.append(Current100CF05,np.array(C_8000_CF05[cols]))

    
    
    


A_4600_CF05 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL05/4600000/CurentA')

colA=A_4600_CF05.columns
Current0CF05= np.array(A_4600_CF05['I12'])

for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
        
for cols in colA[1:]:
    Current0CF05=np.append(Current0CF05,np.array(A_4600_CF05[cols]))
    
B_4600_CF05 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL05/4600000/CurentB')

colA=B_4600_CF05.columns
for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    Current0CF05=np.append(Current0CF05,np.array(B_4600_CF05[cols]))
    
C_4600_CF05 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL05/4600000/CurentC')

colA=C_4600_CF05.columns
for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    Current0CF05=np.append(Current0CF05,np.array(C_4600_CF05[cols]))

###########################
##### VOLTAGES ############
##########################


A_8000_CF05 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL05/8000000/VoltageA')

colA=A_8000_CF05.columns
Voltage100CF05= np.array(A_8000_CF05['2'])
for cols in colA[1:]:
    Voltage100CF05=np.append(Voltage100CF05,np.array(A_8000_CF05[cols]))
    
    
B_8000_CF05 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL05/8000000/VoltageB')

colA=B_8000_CF05.columns
for cols in colA:
    Voltage100CF05=np.append(Voltage100CF05,np.array(B_8000_CF05[cols]))
    
C_8000_CF05 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL05/8000000/VoltageC')

colA=C_8000_CF05.columns
for cols in colA:
    Voltage100CF05=np.append(Voltage100CF05,np.array(C_8000_CF05[cols]))

    
    
    

A_4600_CF05 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL05/4600000/VoltageA')

colA=A_4600_CF05.columns
Voltage0CF05= np.array(A_4600_CF05['2'])
for cols in colA[1:]:
    Voltage0CF05=np.append(Voltage0CF05,np.array(A_4600_CF05[cols]))
    
    
B_4600_CF05 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL05/4600000/VoltageB')

colA=B_4600_CF05.columns
for cols in colA:
    Voltage0CF05=np.append(Voltage0CF05,np.array(B_4600_CF05[cols]))
    
C_4600_CF05 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL05/4600000/VoltageC')

colA=C_4600_CF05.columns
for cols in colA:
    Voltage0CF05=np.append(Voltage0CF05,np.array(C_4600_CF05[cols]))

# %%
Voltage05cost=pd.DataFrame(Voltage100CF05, columns=['25%'])
Current05cost=pd.DataFrame(Current100CF05, columns=['25%'])

Voltage05carb=pd.DataFrame(Voltage0CF05, columns=['25%'])
Current05carb=pd.DataFrame(Current0CF05, columns=['25%'])

# %% [markdown]
# CF 0.4

# %%
##########################################
################ CURRENT #################
##########################################


A_8000_CF04 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL04/8000000/CurentA')

colA=A_8000_CF04.columns
CurrentCF04= np.array(A_8000_CF04['I12'])

for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
        
for cols in colA[1:]:
    CurrentCF04=np.append(CurrentCF04,np.array(A_8000_CF04[cols]))
    
    
B_8000_CF04 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL04/8000000/CurentB')

colA=B_8000_CF04.columns

for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    CurrentCF04=np.append(CurrentCF04,np.array(B_8000_CF04[cols]))
    
C_8000_CF04 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL04/8000000/CurentC')

colA=C_8000_CF04.columns
for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    CurrentCF04=np.append(CurrentCF04,np.array(C_8000_CF04[cols]))

    
    
    
A_6000_CF04 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL04/6000000/CurentA')

colA=A_6000_CF04.columns
for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    CurrentCF04=np.append(CurrentCF04,np.array(A_6000_CF04[cols]))
    
B_6000_CF04 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL04/6000000/CurentB')

colA=B_6000_CF04.columns
for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    CurrentCF04=np.append(CurrentCF04,np.array(B_6000_CF04[cols]))
    
C_6000_CF04 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL04/6000000/CurentC')

colA=C_6000_CF04.columns
for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    CurrentCF04=np.append(CurrentCF04,np.array(C_6000_CF04[cols]))
    
    
    

A_5500_CF04 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL04/5500000/CurentA')

colA=A_5500_CF04.columns
for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    CurrentCF04=np.append(CurrentCF04,np.array(A_5500_CF04[cols]))
    
B_5500_CF04 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL04/5500000/CurentB')

colA=B_5500_CF04.columns
for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    CurrentCF04=np.append(CurrentCF04,np.array(B_5500_CF04[cols]))
    
C_5500_CF04 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL04/5500000/CurentC')

colA=C_5500_CF04.columns
for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    CurrentCF04=np.append(CurrentCF04,np.array(C_5500_CF04[cols]))

    
    
A_5000_CF04 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL04/5000000/CurentA')

colA=A_5000_CF04.columns
for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    CurrentCF04=np.append(CurrentCF04,np.array(A_5000_CF04[cols]))
    
B_5000_CF04 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL04/5000000/CurentB')

colA=B_5000_CF04.columns
for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    CurrentCF04=np.append(CurrentCF04,np.array(B_5000_CF04[cols]))
    
C_5000_CF04 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL04/5000000/CurentC')

colA=C_5000_CF04.columns
for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    CurrentCF04=np.append(CurrentCF04,np.array(C_5000_CF04[cols]))
    
    
    

A_4800_CF04 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL04/4800000/CurentA')

colA=A_4800_CF04.columns
for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    CurrentCF04=np.append(CurrentCF04,np.array(A_4800_CF04[cols]))
    
B_4800_CF04 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL04/4800000/CurentB')

colA=B_4800_CF04.columns
for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    CurrentCF04=np.append(CurrentCF04,np.array(B_4800_CF04[cols]))
    
C_4800_CF04 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL04/4800000/CurentC')

colA=C_4800_CF04.columns
for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    CurrentCF04=np.append(CurrentCF04,np.array(C_4800_CF04[cols]))
    
    
    

A_4600_CF04 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL04/4600000/CurentA')

colA=A_4600_CF04.columns
for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    CurrentCF04=np.append(CurrentCF04,np.array(A_4600_CF04[cols]))
    
B_4600_CF04 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL04/4600000/CurentB')

colA=B_4600_CF04.columns
for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    CurrentCF04=np.append(CurrentCF04,np.array(B_4600_CF04[cols]))
    
C_4600_CF04 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL04/4600000/CurentC')

colA=C_4600_CF04.columns
for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    CurrentCF04=np.append(CurrentCF04,np.array(C_4600_CF04[cols]))
    
    
    
    
    
    
A_4400_CF04 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL04/4400000/CurentA')

colA=A_4400_CF04.columns
for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    CurrentCF04=np.append(CurrentCF04,np.array(A_4400_CF04[cols]))
    
B_4400_CF04 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL04/4400000/CurentB')

colA=B_4400_CF04.columns
for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    CurrentCF04=np.append(CurrentCF04,np.array(B_4400_CF04[cols]))
    
C_4400_CF04 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL04/4400000/CurentC')

colA=C_4400_CF04.columns
for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    CurrentCF04=np.append(CurrentCF04,np.array(C_4400_CF04[cols]))

###########################
##### VOLTAGES ############
##########################


A_8000_CF04 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL04/8000000/VoltageA')

colA=A_8000_CF04.columns
VoltageCF04= np.array(A_8000_CF04['2'])
for cols in colA[1:]:
    VoltageCF04=np.append(VoltageCF04,np.array(A_8000_CF04[cols]))
    
    
B_8000_CF04 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL04/8000000/VoltageB')

colA=B_8000_CF04.columns
for cols in colA:
    VoltageCF04=np.append(VoltageCF04,np.array(B_8000_CF04[cols]))
    
C_8000_CF04 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL04/8000000/VoltageC')

colA=C_8000_CF04.columns
for cols in colA:
    VoltageCF04=np.append(VoltageCF04,np.array(C_8000_CF04[cols]))

    
    
    
A_6000_CF04 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL04/6000000/VoltageA')

colA=A_6000_CF04.columns
for cols in colA:
    VoltageCF04=np.append(VoltageCF04,np.array(A_6000_CF04[cols]))
    
B_6000_CF04 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL04/6000000/VoltageB')

colA=B_6000_CF04.columns
for cols in colA:
    VoltageCF04=np.append(VoltageCF04,np.array(B_6000_CF04[cols]))
    
C_6000_CF04 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL04/6000000/VoltageC')

colA=C_6000_CF04.columns
for cols in colA:
    VoltageCF04=np.append(VoltageCF04,np.array(C_6000_CF04[cols]))
    
    
    

A_5500_CF04 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL04/5500000/VoltageA')

colA=A_5500_CF04.columns
for cols in colA:
    VoltageCF04=np.append(VoltageCF04,np.array(A_5500_CF04[cols]))
    
B_5500_CF04 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL04/5500000/VoltageB')

colA=B_5500_CF04.columns
for cols in colA:
    VoltageCF04=np.append(VoltageCF04,np.array(B_5500_CF04[cols]))
    
C_5500_CF04 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL04/5500000/VoltageC')

colA=C_5500_CF04.columns
for cols in colA:
    VoltageCF04=np.append(VoltageCF04,np.array(C_5500_CF04[cols]))

    
    
A_5000_CF04 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL04/5000000/VoltageA')

colA=A_5000_CF04.columns
for cols in colA:
    VoltageCF04=np.append(VoltageCF04,np.array(A_5000_CF04[cols]))
    
B_5000_CF04 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL04/5000000/VoltageB')

colA=B_5000_CF04.columns
for cols in colA:
    VoltageCF04=np.append(VoltageCF04,np.array(B_5000_CF04[cols]))
    
C_5000_CF04 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL04/5000000/VoltageC')

colA=C_5000_CF04.columns
for cols in colA:
    VoltageCF04=np.append(VoltageCF04,np.array(C_5000_CF04[cols]))
    
    
    

A_4800_CF04 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL04/4800000/VoltageA')

colA=A_4800_CF04.columns
for cols in colA:
    VoltageCF04=np.append(VoltageCF04,np.array(A_4800_CF04[cols]))
    
B_4800_CF04 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL04/4800000/VoltageB')

colA=B_4800_CF04.columns
for cols in colA:
    VoltageCF04=np.append(VoltageCF04,np.array(B_4800_CF04[cols]))
    
C_4800_CF04 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL04/4800000/VoltageC')

colA=C_4800_CF04.columns
for cols in colA:
    VoltageCF04=np.append(VoltageCF04,np.array(C_4800_CF04[cols]))
    
    
    

A_4600_CF04 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL04/4600000/VoltageA')

colA=A_4600_CF04.columns
for cols in colA:
    VoltageCF04=np.append(VoltageCF04,np.array(A_4600_CF04[cols]))
    
B_4600_CF04 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL04/4600000/VoltageB')

colA=B_4600_CF04.columns
for cols in colA:
    VoltageCF04=np.append(VoltageCF04,np.array(B_4600_CF04[cols]))
    
C_4600_CF04 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL04/4600000/VoltageC')

colA=C_4600_CF04.columns
for cols in colA:
    VoltageCF04=np.append(VoltageCF04,np.array(C_4600_CF04[cols]))
    

    
    
    
A_4400_CF04 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL04/4400000/VoltageA')

colA=A_4400_CF04.columns
for cols in colA:
    VoltageCF04=np.append(VoltageCF04,np.array(A_4400_CF04[cols]))
    
B_4400_CF04 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL04/4400000/VoltageB')

colA=B_4400_CF04.columns
for cols in colA:
    VoltageCF04=np.append(VoltageCF04,np.array(B_4400_CF04[cols]))
    
C_4400_CF04 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL04/4400000/VoltageC')

colA=C_4400_CF04.columns
for cols in colA:
    VoltageCF04=np.append(VoltageCF04,np.array(C_4400_CF04[cols]))

# %%
Hexplot04=pd.concat([pd.DataFrame(CurrentCF04, columns=['Current']),pd.DataFrame(VoltageCF04, columns=['Voltage'])], axis=1)
Voltage04=pd.DataFrame(VoltageCF04, columns=['40%'])
Current04=pd.DataFrame(CurrentCF04, columns=['40%'])

# %%
##########################################
################ CURRENT #################
##########################################


A_8000_CF04 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL04/8000000/CurentA')

colA=A_8000_CF04.columns
Current100CF04= np.array(A_8000_CF04['I12'])

for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
        
for cols in colA[1:]:
    Current100CF04=np.append(Current100CF04,np.array(A_8000_CF04[cols]))
    
    
B_8000_CF04 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL04/8000000/CurentB')

colA=B_8000_CF04.columns

for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    Current100CF04=np.append(Current100CF04,np.array(B_8000_CF04[cols]))
    
C_8000_CF04 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL04/8000000/CurentC')

colA=C_8000_CF04.columns
for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    Current100CF04=np.append(Current100CF04,np.array(C_8000_CF04[cols]))

    
    
    

    
    
A_4400_CF04 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL04/4400000/CurentA')

colA=A_4400_CF04.columns
Current0CF04= np.array(A_4400_CF04['I12'])

for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
        
for cols in colA[1:]:
    Current0CF04=np.append(Current0CF04,np.array(A_4400_CF04[cols]))
    
B_4400_CF04 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL04/4400000/CurentB')

colA=B_4400_CF04.columns
for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    Current0CF04=np.append(Current0CF04,np.array(B_4400_CF04[cols]))
    
C_4400_CF04 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL04/4400000/CurentC')

colA=C_4400_CF04.columns
for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    Current0CF04=np.append(Current0CF04,np.array(C_4400_CF04[cols]))

###########################
##### VOLTAGES ############
##########################


A_8000_CF04 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL04/8000000/VoltageA')

colA=A_8000_CF04.columns
Voltage100CF04= np.array(A_8000_CF04['2'])
for cols in colA[1:]:
    Voltage100CF04=np.append(Voltage100CF04,np.array(A_8000_CF04[cols]))
    
    
B_8000_CF04 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL04/8000000/VoltageB')

colA=B_8000_CF04.columns
for cols in colA:
    Voltage100CF04=np.append(Voltage100CF04,np.array(B_8000_CF04[cols]))
    
C_8000_CF04 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL04/8000000/VoltageC')

colA=C_8000_CF04.columns
for cols in colA:
    Voltage100CF04=np.append(Voltage100CF04,np.array(C_8000_CF04[cols]))

    
    
    

    
    
    
A_4400_CF04 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL04/4400000/VoltageA')

colA=A_4400_CF04.columns
Voltage0CF04= np.array(A_4400_CF04['2'])
for cols in colA[1:]:
    Voltage0CF04=np.append(Voltage0CF04,np.array(A_4400_CF04[cols]))
    
B_4400_CF04 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL04/4400000/VoltageB')

colA=B_4400_CF04.columns
for cols in colA:
    Voltage0CF04=np.append(Voltage0CF04,np.array(B_4400_CF04[cols]))
    
C_4400_CF04 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL04/4400000/VoltageC')

colA=C_4400_CF04.columns
for cols in colA:
    Voltage0CF04=np.append(Voltage0CF04,np.array(C_4400_CF04[cols]))

# %%
Voltage04cost=pd.DataFrame(Voltage100CF04, columns=['40%'])
Current04cost=pd.DataFrame(Current100CF04, columns=['40%'])

Voltage04carb=pd.DataFrame(Voltage0CF04, columns=['40%'])
Current04carb=pd.DataFrame(Current0CF04, columns=['40%'])

# %% [markdown]
# CF 0.3

# %%
##########################################
################ CURRENT #################
##########################################


A_8000_CF03 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL03/8000000/CurentA')

colA=A_8000_CF03.columns
CurrentCF03= np.array(A_8000_CF03['I12'])

for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
        
for cols in colA[1:]:
    CurrentCF03=np.append(CurrentCF03,np.array(A_8000_CF03[cols]))
    
    
B_8000_CF03 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL03/8000000/CurentB')

colA=B_8000_CF03.columns

for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    CurrentCF03=np.append(CurrentCF03,np.array(B_8000_CF03[cols]))
    
C_8000_CF03 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL03/8000000/CurentC')

colA=C_8000_CF03.columns
for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    CurrentCF03=np.append(CurrentCF03,np.array(C_8000_CF03[cols]))

    
    
    
A_6000_CF03 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL03/6000000/CurentA')

colA=A_6000_CF03.columns
for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    CurrentCF03=np.append(CurrentCF03,np.array(A_6000_CF03[cols]))
    
B_6000_CF03 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL03/6000000/CurentB')

colA=B_6000_CF03.columns
for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    CurrentCF03=np.append(CurrentCF03,np.array(B_6000_CF03[cols]))
    
C_6000_CF03 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL03/6000000/CurentC')

colA=C_6000_CF03.columns
for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    CurrentCF03=np.append(CurrentCF03,np.array(C_6000_CF03[cols]))
    
    
    

A_5500_CF03 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL03/5500000/CurentA')

colA=A_5500_CF03.columns
for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    CurrentCF03=np.append(CurrentCF03,np.array(A_5500_CF03[cols]))
    
B_5500_CF03 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL03/5500000/CurentB')

colA=B_5500_CF03.columns
for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    CurrentCF03=np.append(CurrentCF03,np.array(B_5500_CF03[cols]))
    
C_5500_CF03 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL03/5500000/CurentC')

colA=C_5500_CF03.columns
for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    CurrentCF03=np.append(CurrentCF03,np.array(C_5500_CF03[cols]))

    
    
A_5000_CF03 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL03/5000000/CurentA')

colA=A_5000_CF03.columns
for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    CurrentCF03=np.append(CurrentCF03,np.array(A_5000_CF03[cols]))
    
B_5000_CF03 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL03/5000000/CurentB')

colA=B_5000_CF03.columns
for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    CurrentCF03=np.append(CurrentCF03,np.array(B_5000_CF03[cols]))
    
C_5000_CF03 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL03/5000000/CurentC')

colA=C_5000_CF03.columns
for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    CurrentCF03=np.append(CurrentCF03,np.array(C_5000_CF03[cols]))
    
    
    

A_4800_CF03 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL03/4800000/CurentA')

colA=A_4800_CF03.columns
for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    CurrentCF03=np.append(CurrentCF03,np.array(A_4800_CF03[cols]))
    
B_4800_CF03 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL03/4800000/CurentB')

colA=B_4800_CF03.columns
for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    CurrentCF03=np.append(CurrentCF03,np.array(B_4800_CF03[cols]))
    
C_4800_CF03 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL03/4800000/CurentC')

colA=C_4800_CF03.columns
for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    CurrentCF03=np.append(CurrentCF03,np.array(C_4800_CF03[cols]))
    
    
    

A_4600_CF03 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL03/4600000/CurentA')

colA=A_4600_CF03.columns
for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    CurrentCF03=np.append(CurrentCF03,np.array(A_4600_CF03[cols]))
    
B_4600_CF03 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL03/4600000/CurentB')

colA=B_4600_CF03.columns
for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    CurrentCF03=np.append(CurrentCF03,np.array(B_4600_CF03[cols]))
    
C_4600_CF03 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL03/4600000/CurentC')

colA=C_4600_CF03.columns
for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    CurrentCF03=np.append(CurrentCF03,np.array(C_4600_CF03[cols]))
    
    
    
    
    
    
A_4400_CF03 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL03/4400000/CurentA')

colA=A_4400_CF03.columns
for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    CurrentCF03=np.append(CurrentCF03,np.array(A_4400_CF03[cols]))
    
B_4400_CF03 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL03/4400000/CurentB')

colA=B_4400_CF03.columns
for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    CurrentCF03=np.append(CurrentCF03,np.array(B_4400_CF03[cols]))
    
C_4400_CF03 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL03/4400000/CurentC')

colA=C_4400_CF03.columns
for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    CurrentCF03=np.append(CurrentCF03,np.array(C_4400_CF03[cols]))
    
    
    
    
A_4000_CF03 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL03/4000000/CurentA')

colA=A_4000_CF03.columns
for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    CurrentCF03=np.append(CurrentCF03,np.array(A_4000_CF03[cols]))
    
B_4000_CF03 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL03/4000000/CurentB')

colA=B_4000_CF03.columns
for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    CurrentCF03=np.append(CurrentCF03,np.array(B_4000_CF03[cols]))
    
C_4000_CF03 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL03/4000000/CurentC')

colA=C_4000_CF03.columns
for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    CurrentCF03=np.append(CurrentCF03,np.array(C_4000_CF03[cols]))
    
    
    
    
    
A_3500_CF03 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL03/3500000/CurentA')

colA=A_3500_CF03.columns
for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    CurrentCF03=np.append(CurrentCF03,np.array(A_3500_CF03[cols]))
    
B_3500_CF03 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL03/3500000/CurentB')

colA=B_3500_CF03.columns
for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    CurrentCF03=np.append(CurrentCF03,np.array(B_3500_CF03[cols]))
    
C_3500_CF03 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL03/3500000/CurentC')

colA=C_3500_CF03.columns
for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    CurrentCF03=np.append(CurrentCF03,np.array(C_3500_CF03[cols]))
    
    
    
    
    
A_3200_CF03 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL03/3200000/CurentA')

colA=A_3200_CF03.columns
for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    CurrentCF03=np.append(CurrentCF03,np.array(A_3200_CF03[cols]))
    
B_3200_CF03 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL03/3200000/CurentB')

colA=B_3200_CF03.columns
for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    CurrentCF03=np.append(CurrentCF03,np.array(B_3200_CF03[cols]))
    
C_3200_CF03 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL03/3200000/CurentC')

colA=C_3200_CF03.columns
for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    CurrentCF03=np.append(CurrentCF03,np.array(C_3200_CF03[cols]))

###########################
##### VOLTAGES ############
##########################


A_8000_CF03 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL03/8000000/VoltageA')

colA=A_8000_CF03.columns
VoltageCF03= np.array(A_8000_CF03['2'])
for cols in colA[1:]:
    VoltageCF03=np.append(VoltageCF03,np.array(A_8000_CF03[cols]))
    
    
B_8000_CF03 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL03/8000000/VoltageB')

colA=B_8000_CF03.columns
for cols in colA:
    VoltageCF03=np.append(VoltageCF03,np.array(B_8000_CF03[cols]))
    
C_8000_CF03 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL03/8000000/VoltageC')

colA=C_8000_CF03.columns
for cols in colA:
    VoltageCF03=np.append(VoltageCF03,np.array(C_8000_CF03[cols]))

    
    
    
A_6000_CF03 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL03/6000000/VoltageA')

colA=A_6000_CF03.columns
for cols in colA:
    VoltageCF03=np.append(VoltageCF03,np.array(A_6000_CF03[cols]))
    
B_6000_CF03 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL03/6000000/VoltageB')

colA=B_6000_CF03.columns
for cols in colA:
    VoltageCF03=np.append(VoltageCF03,np.array(B_6000_CF03[cols]))
    
C_6000_CF03 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL03/6000000/VoltageC')

colA=C_6000_CF03.columns
for cols in colA:
    VoltageCF03=np.append(VoltageCF03,np.array(C_6000_CF03[cols]))
    
    
    

A_5500_CF03 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL03/5500000/VoltageA')

colA=A_5500_CF03.columns
for cols in colA:
    VoltageCF03=np.append(VoltageCF03,np.array(A_5500_CF03[cols]))
    
B_5500_CF03 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL03/5500000/VoltageB')

colA=B_5500_CF03.columns
for cols in colA:
    VoltageCF03=np.append(VoltageCF03,np.array(B_5500_CF03[cols]))
    
C_5500_CF03 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL03/5500000/VoltageC')

colA=C_5500_CF03.columns
for cols in colA:
    VoltageCF03=np.append(VoltageCF03,np.array(C_5500_CF03[cols]))

    
    
A_5000_CF03 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL03/5000000/VoltageA')

colA=A_5000_CF03.columns
for cols in colA:
    VoltageCF03=np.append(VoltageCF03,np.array(A_5000_CF03[cols]))
    
B_5000_CF03 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL03/5000000/VoltageB')

colA=B_5000_CF03.columns
for cols in colA:
    VoltageCF03=np.append(VoltageCF03,np.array(B_5000_CF03[cols]))
    
C_5000_CF03 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL03/5000000/VoltageC')

colA=C_5000_CF03.columns
for cols in colA:
    VoltageCF03=np.append(VoltageCF03,np.array(C_5000_CF03[cols]))
    
    
    

A_4800_CF03 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL03/4800000/VoltageA')

colA=A_4800_CF03.columns
for cols in colA:
    VoltageCF03=np.append(VoltageCF03,np.array(A_4800_CF03[cols]))
    
B_4800_CF03 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL03/4800000/VoltageB')

colA=B_4800_CF03.columns
for cols in colA:
    VoltageCF03=np.append(VoltageCF03,np.array(B_4800_CF03[cols]))
    
C_4800_CF03 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL03/4800000/VoltageC')

colA=C_4800_CF03.columns
for cols in colA:
    VoltageCF03=np.append(VoltageCF03,np.array(C_4800_CF03[cols]))
    
    
    

A_4600_CF03 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL03/4600000/VoltageA')

colA=A_4600_CF03.columns
for cols in colA:
    VoltageCF03=np.append(VoltageCF03,np.array(A_4600_CF03[cols]))
    
B_4600_CF03 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL03/4600000/VoltageB')

colA=B_4600_CF03.columns
for cols in colA:
    VoltageCF03=np.append(VoltageCF03,np.array(B_4600_CF03[cols]))
    
C_4600_CF03 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL03/4600000/VoltageC')

colA=C_4600_CF03.columns
for cols in colA:
    VoltageCF03=np.append(VoltageCF03,np.array(C_4600_CF03[cols]))
    

    
    
    
A_4400_CF03 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL03/4400000/VoltageA')

colA=A_4400_CF03.columns
for cols in colA:
    VoltageCF03=np.append(VoltageCF03,np.array(A_4400_CF03[cols]))
    
B_4400_CF03 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL03/4400000/VoltageB')

colA=B_4400_CF03.columns
for cols in colA:
    VoltageCF03=np.append(VoltageCF03,np.array(B_4400_CF03[cols]))
    
C_4400_CF03 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL03/4400000/VoltageC')

colA=C_4400_CF03.columns
for cols in colA:
    VoltageCF03=np.append(VoltageCF03,np.array(C_4400_CF03[cols]))

    
    
    
    
A_4000_CF03 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL03/4000000/VoltageA')

colA=A_4000_CF03.columns
for cols in colA:
    VoltageCF03=np.append(VoltageCF03,np.array(A_4000_CF03[cols]))
    
B_4000_CF03 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL03/4000000/VoltageB')

colA=B_4000_CF03.columns
for cols in colA:
    VoltageCF03=np.append(VoltageCF03,np.array(B_4000_CF03[cols]))
    
C_4000_CF03 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL03/4000000/VoltageC')

colA=C_4000_CF03.columns
for cols in colA:
    VoltageCF03=np.append(VoltageCF03,np.array(C_4000_CF03[cols]))
    

    
    
    
    
A_3500_CF03 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL03/3500000/VoltageA')

colA=A_3500_CF03.columns
for cols in colA:
    VoltageCF03=np.append(VoltageCF03,np.array(A_3500_CF03[cols]))
    
B_3500_CF03 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL03/3500000/VoltageB')

colA=B_3500_CF03.columns
for cols in colA:
    VoltageCF03=np.append(VoltageCF03,np.array(B_3500_CF03[cols]))
    
C_3500_CF03 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL03/3500000/VoltageC')

colA=C_3500_CF03.columns
for cols in colA:
    VoltageCF03=np.append(VoltageCF03,np.array(C_3500_CF03[cols]))
    

    
    
    
    
A_3200_CF03 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL03/3200000/VoltageA')

colA=A_3200_CF03.columns
for cols in colA:
    VoltageCF03=np.append(VoltageCF03,np.array(A_3200_CF03[cols]))
    
B_3200_CF03 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL03/3200000/VoltageB')

colA=B_3200_CF03.columns
for cols in colA:
    VoltageCF03=np.append(VoltageCF03,np.array(B_3200_CF03[cols]))
    
C_3200_CF03 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL03/3200000/VoltageC')

colA=C_3200_CF03.columns
for cols in colA:
    VoltageCF03=np.append(VoltageCF03,np.array(C_3200_CF03[cols]))

# %%
Hexplot03=pd.concat([pd.DataFrame(CurrentCF03, columns=['Current']),pd.DataFrame(VoltageCF03, columns=['Voltage'])], axis=1)
Voltage03=pd.DataFrame(VoltageCF03, columns=['55%'])
Current03=pd.DataFrame(CurrentCF03, columns=['55%'])

# %%
##########################################
################ CURRENT #################
##########################################


A_8000_CF03 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL03/8000000/CurentA')

colA=A_8000_CF03.columns
Current100CF03= np.array(A_8000_CF03['I12'])

for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
        
for cols in colA[1:]:
    Current100CF03=np.append(Current100CF03,np.array(A_8000_CF03[cols]))
    
    
B_8000_CF03 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL03/8000000/CurentB')

colA=B_8000_CF03.columns

for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    Current100CF03=np.append(Current100CF03,np.array(B_8000_CF03[cols]))
    
C_8000_CF03 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL03/8000000/CurentC')

colA=C_8000_CF03.columns
for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    Current100CF03=np.append(Current100CF03,np.array(C_8000_CF03[cols]))

    
    


    
    
A_3200_CF03 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL03/3200000/CurentA')

colA=A_8000_CF03.columns
Current0CF03= np.array(A_3200_CF03['I12'])

for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
        
for cols in colA[1:]:
    Current0CF03=np.append(Current0CF03,np.array(A_3200_CF03[cols]))
    
B_3200_CF03 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL03/3200000/CurentB')

colA=B_3200_CF03.columns
for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    Current0CF03=np.append(Current0CF03,np.array(B_3200_CF03[cols]))
    
C_3200_CF03 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL03/3200000/CurentC')

colA=C_3200_CF03.columns
for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    Current0CF03=np.append(Current0CF03,np.array(C_3200_CF03[cols]))

###########################
##### VOLTAGES ############
##########################


A_8000_CF03 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL03/8000000/VoltageA')

colA=A_8000_CF03.columns
Voltage100CF03= np.array(A_8000_CF03['2'])
for cols in colA[1:]:
    Voltage100CF03=np.append(Voltage100CF03,np.array(A_8000_CF03[cols]))
    
    
B_8000_CF03 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL03/8000000/VoltageB')

colA=B_8000_CF03.columns
for cols in colA:
    Voltage100CF03=np.append(Voltage100CF03,np.array(B_8000_CF03[cols]))
    
C_8000_CF03 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL03/8000000/VoltageC')

colA=C_8000_CF03.columns
for cols in colA:
    Voltage100CF03=np.append(Voltage100CF03,np.array(C_8000_CF03[cols]))

    
    
    

    
    
    
A_3200_CF03 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL03/3200000/VoltageA')

colA=A_3200_CF03.columns
Voltage0CF03= np.array(A_3200_CF03['2'])
for cols in colA[1:]:
    Voltage0CF03=np.append(Voltage0CF03,np.array(A_3200_CF03[cols]))
    
B_3200_CF03 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL03/3200000/VoltageB')

colA=B_3200_CF03.columns
for cols in colA:
    Voltage0CF03=np.append(Voltage0CF03,np.array(B_3200_CF03[cols]))
    
C_3200_CF03 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL03/3200000/VoltageC')

colA=C_3200_CF03.columns
for cols in colA:
    Voltage0CF03=np.append(Voltage0CF03,np.array(C_3200_CF03[cols]))

# %%
Voltage03cost=pd.DataFrame(Voltage100CF03, columns=['55%'])
Current03cost=pd.DataFrame(Current100CF03, columns=['55%'])

Voltage03carb=pd.DataFrame(Voltage0CF03, columns=['55%'])
Current03carb=pd.DataFrame(Current0CF03, columns=['55%'])

# %% [markdown]
# CF 0.2

# %%
##########################################
################ CURRENT #################
##########################################


A_8000_CF02 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL02/8000000/CurentA')

colA=A_8000_CF02.columns
CurrentCF02= np.array(A_8000_CF02['I12'])

for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
        
for cols in colA[1:]:
    CurrentCF02=np.append(CurrentCF02,np.array(A_8000_CF02[cols]))
    
    
B_8000_CF02 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL02/8000000/CurentB')

colA=B_8000_CF02.columns

for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    CurrentCF02=np.append(CurrentCF02,np.array(B_8000_CF02[cols]))
    
C_8000_CF02 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL02/8000000/CurentC')

colA=C_8000_CF02.columns
for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    CurrentCF02=np.append(CurrentCF02,np.array(C_8000_CF02[cols]))

    
    
    
A_6000_CF02 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL02/6000000/CurentA')

colA=A_6000_CF02.columns
for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    CurrentCF02=np.append(CurrentCF02,np.array(A_6000_CF02[cols]))
    
B_6000_CF02 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL02/6000000/CurentB')

colA=B_6000_CF02.columns
for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    CurrentCF02=np.append(CurrentCF02,np.array(B_6000_CF02[cols]))
    
C_6000_CF02 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL02/6000000/CurentC')

colA=C_6000_CF02.columns
for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    CurrentCF02=np.append(CurrentCF02,np.array(C_6000_CF02[cols]))
    
    
    

A_5500_CF02 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL02/5500000/CurentA')

colA=A_5500_CF02.columns
for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    CurrentCF02=np.append(CurrentCF02,np.array(A_5500_CF02[cols]))
    
B_5500_CF02 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL02/5500000/CurentB')

colA=B_5500_CF02.columns
for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    CurrentCF02=np.append(CurrentCF02,np.array(B_5500_CF02[cols]))
    
C_5500_CF02 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL02/5500000/CurentC')

colA=C_5500_CF02.columns
for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    CurrentCF02=np.append(CurrentCF02,np.array(C_5500_CF02[cols]))

    
    
A_5000_CF02 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL02/5000000/CurentA')

colA=A_5000_CF02.columns
for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    CurrentCF02=np.append(CurrentCF02,np.array(A_5000_CF02[cols]))
    
B_5000_CF02 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL02/5000000/CurentB')

colA=B_5000_CF02.columns
for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    CurrentCF02=np.append(CurrentCF02,np.array(B_5000_CF02[cols]))
    
C_5000_CF02 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL02/5000000/CurentC')

colA=C_5000_CF02.columns
for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    CurrentCF02=np.append(CurrentCF02,np.array(C_5000_CF02[cols]))
    
    
    

A_4800_CF02 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL02/4800000/CurentA')

colA=A_4800_CF02.columns
for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    CurrentCF02=np.append(CurrentCF02,np.array(A_4800_CF02[cols]))
    
B_4800_CF02 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL02/4800000/CurentB')

colA=B_4800_CF02.columns
for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    CurrentCF02=np.append(CurrentCF02,np.array(B_4800_CF02[cols]))
    
C_4800_CF02 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL02/4800000/CurentC')

colA=C_4800_CF02.columns
for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    CurrentCF02=np.append(CurrentCF02,np.array(C_4800_CF02[cols]))
    
    
    

A_4600_CF02 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL02/4600000/CurentA')

colA=A_4600_CF02.columns
for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    CurrentCF02=np.append(CurrentCF02,np.array(A_4600_CF02[cols]))
    
B_4600_CF02 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL02/4600000/CurentB')

colA=B_4600_CF02.columns
for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    CurrentCF02=np.append(CurrentCF02,np.array(B_4600_CF02[cols]))
    
C_4600_CF02 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL02/4600000/CurentC')

colA=C_4600_CF02.columns
for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    CurrentCF02=np.append(CurrentCF02,np.array(C_4600_CF02[cols]))
    
    
    
    
    
    
A_4400_CF02 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL02/4400000/CurentA')

colA=A_4400_CF02.columns
for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    CurrentCF02=np.append(CurrentCF02,np.array(A_4400_CF02[cols]))
    
B_4400_CF02 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL02/4400000/CurentB')

colA=B_4400_CF02.columns
for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    CurrentCF02=np.append(CurrentCF02,np.array(B_4400_CF02[cols]))
    
C_4400_CF02 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL02/4400000/CurentC')

colA=C_4400_CF02.columns
for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    CurrentCF02=np.append(CurrentCF02,np.array(C_4400_CF02[cols]))
    
    
    
    
A_4000_CF02 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL02/4000000/CurentA')

colA=A_4000_CF02.columns
for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    CurrentCF02=np.append(CurrentCF02,np.array(A_4000_CF02[cols]))
    
B_4000_CF02 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL02/4000000/CurentB')

colA=B_4000_CF02.columns
for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    CurrentCF02=np.append(CurrentCF02,np.array(B_4000_CF02[cols]))
    
C_4000_CF02 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL02/4000000/CurentC')

colA=C_4000_CF02.columns
for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    CurrentCF02=np.append(CurrentCF02,np.array(C_4000_CF02[cols]))
    
    
    
    
    
A_3500_CF02 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL02/3500000/CurentA')

colA=A_3500_CF02.columns
for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    CurrentCF02=np.append(CurrentCF02,np.array(A_3500_CF02[cols]))
    
B_3500_CF02 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL02/3500000/CurentB')

colA=B_3500_CF02.columns
for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    CurrentCF02=np.append(CurrentCF02,np.array(B_3500_CF02[cols]))
    
C_3500_CF02 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL02/3500000/CurentC')

colA=C_3500_CF02.columns
for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    CurrentCF02=np.append(CurrentCF02,np.array(C_3500_CF02[cols]))
    
    
    
    
    
A_3200_CF02 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL02/3200000/CurentA')

colA=A_3200_CF02.columns
for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    CurrentCF02=np.append(CurrentCF02,np.array(A_3200_CF02[cols]))
    
B_3200_CF02 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL02/3200000/CurentB')

colA=B_3200_CF02.columns
for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    CurrentCF02=np.append(CurrentCF02,np.array(B_3200_CF02[cols]))
    
C_3200_CF02 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL02/3200000/CurentC')

colA=C_3200_CF02.columns
for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    CurrentCF02=np.append(CurrentCF02,np.array(C_3200_CF02[cols]))
    
    
    

    
A_3100_CF02 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL02/3100000/CurentA')

colA=A_3100_CF02.columns
for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    CurrentCF02=np.append(CurrentCF02,np.array(A_3100_CF02[cols]))
    
B_3100_CF02 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL02/3100000/CurentB')

colA=B_3100_CF02.columns
for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    CurrentCF02=np.append(CurrentCF02,np.array(B_3100_CF02[cols]))
    
C_3100_CF02 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL02/3100000/CurentC')

colA=C_3100_CF02.columns
for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    CurrentCF02=np.append(CurrentCF02,np.array(C_3100_CF02[cols]))
    
    
    
    
    

    
A_3000_CF02 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL02/3000000/CurentA')

colA=A_3000_CF02.columns
for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    CurrentCF02=np.append(CurrentCF02,np.array(A_3000_CF02[cols]))
    
B_3000_CF02 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL02/3000000/CurentB')

colA=B_3000_CF02.columns
for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    CurrentCF02=np.append(CurrentCF02,np.array(B_3000_CF02[cols]))
    
C_3000_CF02 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL02/3000000/CurentC')

colA=C_3000_CF02.columns
for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    CurrentCF02=np.append(CurrentCF02,np.array(C_3000_CF02[cols]))
    
    
    
    
    
    

    
A_2500_CF02 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL02/2500000/CurentA')

colA=A_2500_CF02.columns
for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    CurrentCF02=np.append(CurrentCF02,np.array(A_2500_CF02[cols]))
    
B_2500_CF02 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL02/2500000/CurentB')

colA=B_2500_CF02.columns
for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    CurrentCF02=np.append(CurrentCF02,np.array(B_2500_CF02[cols]))
    
C_2500_CF02 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL02/2500000/CurentC')

colA=C_2500_CF02.columns
for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    CurrentCF02=np.append(CurrentCF02,np.array(C_2500_CF02[cols]))

###########################
##### VOLTAGES ############
##########################


A_8000_CF02 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL02/8000000/VoltageA')

colA=A_8000_CF02.columns
VoltageCF02= np.array(A_8000_CF02['2'])
for cols in colA[1:]:
    VoltageCF02=np.append(VoltageCF02,np.array(A_8000_CF02[cols]))
    
    
B_8000_CF02 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL02/8000000/VoltageB')

colA=B_8000_CF02.columns
for cols in colA:
    VoltageCF02=np.append(VoltageCF02,np.array(B_8000_CF02[cols]))
    
C_8000_CF02 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL02/8000000/VoltageC')

colA=C_8000_CF02.columns
for cols in colA:
    VoltageCF02=np.append(VoltageCF02,np.array(C_8000_CF02[cols]))

    
    
    
A_6000_CF02 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL02/6000000/VoltageA')

colA=A_6000_CF02.columns
for cols in colA:
    VoltageCF02=np.append(VoltageCF02,np.array(A_6000_CF02[cols]))
    
B_6000_CF02 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL02/6000000/VoltageB')

colA=B_6000_CF02.columns
for cols in colA:
    VoltageCF02=np.append(VoltageCF02,np.array(B_6000_CF02[cols]))
    
C_6000_CF02 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL02/6000000/VoltageC')

colA=C_6000_CF02.columns
for cols in colA:
    VoltageCF02=np.append(VoltageCF02,np.array(C_6000_CF02[cols]))
    
    
    

A_5500_CF02 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL02/5500000/VoltageA')

colA=A_5500_CF02.columns
for cols in colA:
    VoltageCF02=np.append(VoltageCF02,np.array(A_5500_CF02[cols]))
    
B_5500_CF02 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL02/5500000/VoltageB')

colA=B_5500_CF02.columns
for cols in colA:
    VoltageCF02=np.append(VoltageCF02,np.array(B_5500_CF02[cols]))
    
C_5500_CF02 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL02/5500000/VoltageC')

colA=C_5500_CF02.columns
for cols in colA:
    VoltageCF02=np.append(VoltageCF02,np.array(C_5500_CF02[cols]))

    
    
A_5000_CF02 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL02/5000000/VoltageA')

colA=A_5000_CF02.columns
for cols in colA:
    VoltageCF02=np.append(VoltageCF02,np.array(A_5000_CF02[cols]))
    
B_5000_CF02 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL02/5000000/VoltageB')

colA=B_5000_CF02.columns
for cols in colA:
    VoltageCF02=np.append(VoltageCF02,np.array(B_5000_CF02[cols]))
    
C_5000_CF02 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL02/5000000/VoltageC')

colA=C_5000_CF02.columns
for cols in colA:
    VoltageCF02=np.append(VoltageCF02,np.array(C_5000_CF02[cols]))
    
    
    

A_4800_CF02 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL02/4800000/VoltageA')

colA=A_4800_CF02.columns
for cols in colA:
    VoltageCF02=np.append(VoltageCF02,np.array(A_4800_CF02[cols]))
    
B_4800_CF02 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL02/4800000/VoltageB')

colA=B_4800_CF02.columns
for cols in colA:
    VoltageCF02=np.append(VoltageCF02,np.array(B_4800_CF02[cols]))
    
C_4800_CF02 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL02/4800000/VoltageC')

colA=C_4800_CF02.columns
for cols in colA:
    VoltageCF02=np.append(VoltageCF02,np.array(C_4800_CF02[cols]))
    
    
    

A_4600_CF02 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL02/4600000/VoltageA')

colA=A_4600_CF02.columns
for cols in colA:
    VoltageCF02=np.append(VoltageCF02,np.array(A_4600_CF02[cols]))
    
B_4600_CF02 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL02/4600000/VoltageB')

colA=B_4600_CF02.columns
for cols in colA:
    VoltageCF02=np.append(VoltageCF02,np.array(B_4600_CF02[cols]))
    
C_4600_CF02 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL02/4600000/VoltageC')

colA=C_4600_CF02.columns
for cols in colA:
    VoltageCF02=np.append(VoltageCF02,np.array(C_4600_CF02[cols]))
    

    
    
    
A_4400_CF02 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL02/4400000/VoltageA')

colA=A_4400_CF02.columns
for cols in colA:
    VoltageCF02=np.append(VoltageCF02,np.array(A_4400_CF02[cols]))
    
B_4400_CF02 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL02/4400000/VoltageB')

colA=B_4400_CF02.columns
for cols in colA:
    VoltageCF02=np.append(VoltageCF02,np.array(B_4400_CF02[cols]))
    
C_4400_CF02 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL02/4400000/VoltageC')

colA=C_4400_CF02.columns
for cols in colA:
    VoltageCF02=np.append(VoltageCF02,np.array(C_4400_CF02[cols]))

    
    
    
    
A_4000_CF02 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL02/4000000/VoltageA')

colA=A_4000_CF02.columns
for cols in colA:
    VoltageCF02=np.append(VoltageCF02,np.array(A_4000_CF02[cols]))
    
B_4000_CF02 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL02/4000000/VoltageB')

colA=B_4000_CF02.columns
for cols in colA:
    VoltageCF02=np.append(VoltageCF02,np.array(B_4000_CF02[cols]))
    
C_4000_CF02 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL02/4000000/VoltageC')

colA=C_4000_CF02.columns
for cols in colA:
    VoltageCF02=np.append(VoltageCF02,np.array(C_4000_CF02[cols]))
    

    
    
    
    
A_3500_CF02 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL02/3500000/VoltageA')

colA=A_3500_CF02.columns
for cols in colA:
    VoltageCF02=np.append(VoltageCF02,np.array(A_3500_CF02[cols]))
    
B_3500_CF02 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL02/3500000/VoltageB')

colA=B_3500_CF02.columns
for cols in colA:
    VoltageCF02=np.append(VoltageCF02,np.array(B_3500_CF02[cols]))
    
C_3500_CF02 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL02/3500000/VoltageC')

colA=C_3500_CF02.columns
for cols in colA:
    VoltageCF02=np.append(VoltageCF02,np.array(C_3500_CF02[cols]))
    

    
    
    
    
A_3200_CF02 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL02/3200000/VoltageA')

colA=A_3200_CF02.columns
for cols in colA:
    VoltageCF02=np.append(VoltageCF02,np.array(A_3200_CF02[cols]))
    
B_3200_CF02 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL02/3200000/VoltageB')

colA=B_3200_CF02.columns
for cols in colA:
    VoltageCF02=np.append(VoltageCF02,np.array(B_3200_CF02[cols]))
    
C_3200_CF02 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL02/3200000/VoltageC')

colA=C_3200_CF02.columns
for cols in colA:
    VoltageCF02=np.append(VoltageCF02,np.array(C_3200_CF02[cols]))

    

    
    
    
    
A_3100_CF02 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL02/3100000/VoltageA')

colA=A_3100_CF02.columns
for cols in colA:
    VoltageCF02=np.append(VoltageCF02,np.array(A_3100_CF02[cols]))
    
B_3100_CF02 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL02/3100000/VoltageB')

colA=B_3100_CF02.columns
for cols in colA:
    VoltageCF02=np.append(VoltageCF02,np.array(B_3100_CF02[cols]))
    
C_3100_CF02 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL02/3100000/VoltageC')

colA=C_3100_CF02.columns
for cols in colA:
    VoltageCF02=np.append(VoltageCF02,np.array(C_3100_CF02[cols]))
    
    

    
    
    
    
A_3000_CF02 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL02/3000000/VoltageA')

colA=A_3000_CF02.columns
for cols in colA:
    VoltageCF02=np.append(VoltageCF02,np.array(A_3000_CF02[cols]))
    
B_3000_CF02 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL02/3000000/VoltageB')

colA=B_3000_CF02.columns
for cols in colA:
    VoltageCF02=np.append(VoltageCF02,np.array(B_3000_CF02[cols]))
    
C_3000_CF02 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL02/3000000/VoltageC')

colA=C_3000_CF02.columns
for cols in colA:
    VoltageCF02=np.append(VoltageCF02,np.array(C_3000_CF02[cols]))
    
    
    

    
    
    
    
A_2500_CF02 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL02/2500000/VoltageA')

colA=A_2500_CF02.columns
for cols in colA:
    VoltageCF02=np.append(VoltageCF02,np.array(A_2500_CF02[cols]))
    
B_2500_CF02 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL02/2500000/VoltageB')

colA=B_2500_CF02.columns
for cols in colA:
    VoltageCF02=np.append(VoltageCF02,np.array(B_2500_CF02[cols]))
    
C_2500_CF02 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL02/2500000/VoltageC')

colA=C_2500_CF02.columns
for cols in colA:
    VoltageCF02=np.append(VoltageCF02,np.array(C_2500_CF02[cols]))

# %%
Hexplot02=pd.concat([pd.DataFrame(CurrentCF02, columns=['Current']),pd.DataFrame(VoltageCF02, columns=['Voltage'])], axis=1)
Voltage02=pd.DataFrame(VoltageCF02, columns=['70%'])
Current02=pd.DataFrame(CurrentCF02, columns=['70%'])

# %%
##########################################
################ CURRENT #################
##########################################


A_8000_CF02 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL02/8000000/CurentA')

colA=A_8000_CF02.columns
Current100CF02= np.array(A_8000_CF02['I12'])

for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
        
for cols in colA[1:]:
    Current100CF02=np.append(Current100CF02,np.array(A_8000_CF02[cols]))
    
    
B_8000_CF02 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL02/8000000/CurentB')

colA=B_8000_CF02.columns

for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    Current100CF02=np.append(Current100CF02,np.array(B_8000_CF02[cols]))
    
C_8000_CF02 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL02/8000000/CurentC')

colA=C_8000_CF02.columns
for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    Current100CF02=np.append(Current100CF02,np.array(C_8000_CF02[cols]))

    
    
    

    
    
    
    

    
A_2500_CF02 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL02/2500000/CurentA')

colA=A_2500_CF02.columns
Current0CF02= np.array(A_2500_CF02['I12'])

for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
        
for cols in colA[1:]:
    Current0CF02=np.append(Current0CF02,np.array(A_2500_CF02[cols]))
    
B_2500_CF02 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL02/2500000/CurentB')

colA=B_2500_CF02.columns
for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    Current0CF02=np.append(Current0CF02,np.array(B_2500_CF02[cols]))
    
C_2500_CF02 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL02/2500000/CurentC')

colA=C_2500_CF02.columns
for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    Current0CF02=np.append(Current0CF02,np.array(C_2500_CF02[cols]))

###########################
##### VOLTAGES ############
##########################


A_8000_CF02 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL02/8000000/VoltageA')

colA=A_8000_CF02.columns
Voltage100CF02= np.array(A_8000_CF02['2'])
for cols in colA[1:]:
    Voltage100CF02=np.append(Voltage100CF02,np.array(A_8000_CF02[cols]))
    
    
B_8000_CF02 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL02/8000000/VoltageB')

colA=B_8000_CF02.columns
for cols in colA:
    Voltage100CF02=np.append(Voltage100CF02,np.array(B_8000_CF02[cols]))
    
C_8000_CF02 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL02/8000000/VoltageC')

colA=C_8000_CF02.columns
for cols in colA:
    Voltage100CF02=np.append(Voltage100CF02,np.array(C_8000_CF02[cols]))

    
    
    

    
    
    
A_2500_CF02 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL02/2500000/VoltageA')

colA=A_2500_CF02.columns
Voltage100CF02= np.array(A_2500_CF02['2'])
for cols in colA[1:]:
    Voltage0CF02=np.append(Voltage0CF02,np.array(A_2500_CF02[cols]))
    
B_2500_CF02 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL02/2500000/VoltageB')

colA=B_2500_CF02.columns
for cols in colA:
    Voltage0CF02=np.append(Voltage0CF02,np.array(B_2500_CF02[cols]))
    
C_2500_CF02 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL02/2500000/VoltageC')

colA=C_2500_CF02.columns
for cols in colA:
    Voltage0CF02=np.append(Voltage0CF02,np.array(C_2500_CF02[cols]))

# %%
Voltage02cost=pd.DataFrame(Voltage100CF02, columns=['70%'])
Current02cost=pd.DataFrame(Current100CF02, columns=['70%'])

Voltage02carb=pd.DataFrame(Voltage0CF02, columns=['70%'])
Current02carb=pd.DataFrame(Current0CF02, columns=['70%'])

# %% [markdown]
# CF 0.1

# %%
##########################################
################ CURRENT #################
##########################################


A_8000_CF01 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL01/8000000/CurentA')

colA=A_8000_CF01.columns
CurrentCF01= np.array(A_8000_CF01['I12'])

for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
        
for cols in colA[1:]:
    CurrentCF01=np.append(CurrentCF01,np.array(A_8000_CF01[cols]))
    
    
B_8000_CF01 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL01/8000000/CurentB')

colA=B_8000_CF01.columns

for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    CurrentCF01=np.append(CurrentCF01,np.array(B_8000_CF01[cols]))
    
C_8000_CF01 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL01/8000000/CurentC')

colA=C_8000_CF01.columns
for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    CurrentCF01=np.append(CurrentCF01,np.array(C_8000_CF01[cols]))

    
    
    
A_6000_CF01 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL01/6000000/CurentA')

colA=A_6000_CF01.columns
for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    CurrentCF01=np.append(CurrentCF01,np.array(A_6000_CF01[cols]))
    
B_6000_CF01 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL01/6000000/CurentB')

colA=B_6000_CF01.columns
for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    CurrentCF01=np.append(CurrentCF01,np.array(B_6000_CF01[cols]))
    
C_6000_CF01 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL01/6000000/CurentC')

colA=C_6000_CF01.columns
for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    CurrentCF01=np.append(CurrentCF01,np.array(C_6000_CF01[cols]))
    
    
    

A_5500_CF01 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL01/5500000/CurentA')

colA=A_5500_CF01.columns
for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    CurrentCF01=np.append(CurrentCF01,np.array(A_5500_CF01[cols]))
    
B_5500_CF01 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL01/5500000/CurentB')

colA=B_5500_CF01.columns
for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    CurrentCF01=np.append(CurrentCF01,np.array(B_5500_CF01[cols]))
    
C_5500_CF01 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL01/5500000/CurentC')

colA=C_5500_CF01.columns
for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    CurrentCF01=np.append(CurrentCF01,np.array(C_5500_CF01[cols]))

    
    
A_5000_CF01 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL01/5000000/CurentA')

colA=A_5000_CF01.columns
for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    CurrentCF01=np.append(CurrentCF01,np.array(A_5000_CF01[cols]))
    
B_5000_CF01 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL01/5000000/CurentB')

colA=B_5000_CF01.columns
for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    CurrentCF01=np.append(CurrentCF01,np.array(B_5000_CF01[cols]))
    
C_5000_CF01 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL01/5000000/CurentC')

colA=C_5000_CF01.columns
for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    CurrentCF01=np.append(CurrentCF01,np.array(C_5000_CF01[cols]))
    
    
    

A_4800_CF01 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL01/4800000/CurentA')

colA=A_4800_CF01.columns
for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    CurrentCF01=np.append(CurrentCF01,np.array(A_4800_CF01[cols]))
    
B_4800_CF01 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL01/4800000/CurentB')

colA=B_4800_CF01.columns
for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    CurrentCF01=np.append(CurrentCF01,np.array(B_4800_CF01[cols]))
    
C_4800_CF01 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL01/4800000/CurentC')

colA=C_4800_CF01.columns
for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    CurrentCF01=np.append(CurrentCF01,np.array(C_4800_CF01[cols]))
    
    
    

A_4600_CF01 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL01/4600000/CurentA')

colA=A_4600_CF01.columns
for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    CurrentCF01=np.append(CurrentCF01,np.array(A_4600_CF01[cols]))
    
B_4600_CF01 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL01/4600000/CurentB')

colA=B_4600_CF01.columns
for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    CurrentCF01=np.append(CurrentCF01,np.array(B_4600_CF01[cols]))
    
C_4600_CF01 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL01/4600000/CurentC')

colA=C_4600_CF01.columns
for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    CurrentCF01=np.append(CurrentCF01,np.array(C_4600_CF01[cols]))
    
    
    
    
    
    
A_4400_CF01 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL01/4400000/CurentA')

colA=A_4400_CF01.columns
for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    CurrentCF01=np.append(CurrentCF01,np.array(A_4400_CF01[cols]))
    
B_4400_CF01 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL01/4400000/CurentB')

colA=B_4400_CF01.columns
for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    CurrentCF01=np.append(CurrentCF01,np.array(B_4400_CF01[cols]))
    
C_4400_CF01 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL01/4400000/CurentC')

colA=C_4400_CF01.columns
for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    CurrentCF01=np.append(CurrentCF01,np.array(C_4400_CF01[cols]))
    
    
    
    
A_4000_CF01 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL01/4000000/CurentA')

colA=A_4000_CF01.columns
for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    CurrentCF01=np.append(CurrentCF01,np.array(A_4000_CF01[cols]))
    
B_4000_CF01 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL01/4000000/CurentB')

colA=B_4000_CF01.columns
for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    CurrentCF01=np.append(CurrentCF01,np.array(B_4000_CF01[cols]))
    
C_4000_CF01 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL01/4000000/CurentC')

colA=C_4000_CF01.columns
for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    CurrentCF01=np.append(CurrentCF01,np.array(C_4000_CF01[cols]))
    
    
    
    
    
A_3500_CF01 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL01/3500000/CurentA')

colA=A_3500_CF01.columns
for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    CurrentCF01=np.append(CurrentCF01,np.array(A_3500_CF01[cols]))
    
B_3500_CF01 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL01/3500000/CurentB')

colA=B_3500_CF01.columns
for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    CurrentCF01=np.append(CurrentCF01,np.array(B_3500_CF01[cols]))
    
C_3500_CF01 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL01/3500000/CurentC')

colA=C_3500_CF01.columns
for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    CurrentCF01=np.append(CurrentCF01,np.array(C_3500_CF01[cols]))
    
    
    
    
    
A_3200_CF01 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL01/3200000/CurentA')

colA=A_3200_CF01.columns
for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    CurrentCF01=np.append(CurrentCF01,np.array(A_3200_CF01[cols]))
    
B_3200_CF01 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL01/3200000/CurentB')

colA=B_3200_CF01.columns
for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    CurrentCF01=np.append(CurrentCF01,np.array(B_3200_CF01[cols]))
    
C_3200_CF01 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL01/3200000/CurentC')

colA=C_3200_CF01.columns
for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    CurrentCF01=np.append(CurrentCF01,np.array(C_3200_CF01[cols]))
    
    
    

    
A_3100_CF01 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL01/3100000/CurentA')

colA=A_3100_CF01.columns
for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    CurrentCF01=np.append(CurrentCF01,np.array(A_3100_CF01[cols]))
    
B_3100_CF01 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL01/3100000/CurentB')

colA=B_3100_CF01.columns
for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    CurrentCF01=np.append(CurrentCF01,np.array(B_3100_CF01[cols]))
    
C_3100_CF01 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL01/3100000/CurentC')

colA=C_3100_CF01.columns
for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    CurrentCF01=np.append(CurrentCF01,np.array(C_3100_CF01[cols]))
    
    
    
    
    

    
A_3000_CF01 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL01/3000000/CurentA')

colA=A_3000_CF01.columns
for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    CurrentCF01=np.append(CurrentCF01,np.array(A_3000_CF01[cols]))
    
B_3000_CF01 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL01/3000000/CurentB')

colA=B_3000_CF01.columns
for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    CurrentCF01=np.append(CurrentCF01,np.array(B_3000_CF01[cols]))
    
C_3000_CF01 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL01/3000000/CurentC')

colA=C_3000_CF01.columns
for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    CurrentCF01=np.append(CurrentCF01,np.array(C_3000_CF01[cols]))
    
    
    
    
    
    

    
A_2500_CF01 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL01/2500000/CurentA')

colA=A_2500_CF01.columns
for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    CurrentCF01=np.append(CurrentCF01,np.array(A_2500_CF01[cols]))
    
B_2500_CF01 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL01/2500000/CurentB')

colA=B_2500_CF01.columns
for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    CurrentCF01=np.append(CurrentCF01,np.array(B_2500_CF01[cols]))
    
C_2500_CF01 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL01/2500000/CurentC')

colA=C_2500_CF01.columns
for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    CurrentCF01=np.append(CurrentCF01,np.array(C_2500_CF01[cols]))

    
    
    
    
    
    

    
A_2000_CF01 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL01/2000000/CurentA')

colA=A_2000_CF01.columns
for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    CurrentCF01=np.append(CurrentCF01,np.array(A_2000_CF01[cols]))
    
B_2000_CF01 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL01/2000000/CurentB')

colA=B_2000_CF01.columns
for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    CurrentCF01=np.append(CurrentCF01,np.array(B_2000_CF01[cols]))
    
C_2000_CF01 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL01/2000000/CurentC')

colA=C_2000_CF01.columns
for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    CurrentCF01=np.append(CurrentCF01,np.array(C_2000_CF01[cols]))
    
    
    
    
    
    
    
    

    
A_1500_CF01 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL01/1500000/CurentA')

colA=A_1500_CF01.columns
for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    CurrentCF01=np.append(CurrentCF01,np.array(A_1500_CF01[cols]))
    
B_1500_CF01 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL01/1500000/CurentB')

colA=B_1500_CF01.columns
for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    CurrentCF01=np.append(CurrentCF01,np.array(B_1500_CF01[cols]))
    
C_1500_CF01 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL01/1500000/CurentC')

colA=C_1500_CF01.columns
for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    CurrentCF01=np.append(CurrentCF01,np.array(C_1500_CF01[cols]))
    
    
    
    
    
    
    
    

    
A_1300_CF01 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL01/1300000/CurentA')

colA=A_1300_CF01.columns
for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    CurrentCF01=np.append(CurrentCF01,np.array(A_1300_CF01[cols]))
    
B_1300_CF01 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL01/1300000/CurentB')

colA=B_1300_CF01.columns
for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    CurrentCF01=np.append(CurrentCF01,np.array(B_1300_CF01[cols]))
    
C_1300_CF01 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL01/1300000/CurentC')

colA=C_1300_CF01.columns
for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    CurrentCF01=np.append(CurrentCF01,np.array(C_1300_CF01[cols]))
###########################
##### VOLTAGES ############
##########################


A_8000_CF01 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL01/8000000/VoltageA')

colA=A_8000_CF01.columns
VoltageCF01= np.array(A_8000_CF01['2'])
for cols in colA[1:]:
    VoltageCF01=np.append(VoltageCF01,np.array(A_8000_CF01[cols]))
    
    
B_8000_CF01 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL01/8000000/VoltageB')

colA=B_8000_CF01.columns
for cols in colA:
    VoltageCF01=np.append(VoltageCF01,np.array(B_8000_CF01[cols]))
    
C_8000_CF01 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL01/8000000/VoltageC')

colA=C_8000_CF01.columns
for cols in colA:
    VoltageCF01=np.append(VoltageCF01,np.array(C_8000_CF01[cols]))

    
    
    
A_6000_CF01 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL01/6000000/VoltageA')

colA=A_6000_CF01.columns
for cols in colA:
    VoltageCF01=np.append(VoltageCF01,np.array(A_6000_CF01[cols]))
    
B_6000_CF01 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL01/6000000/VoltageB')

colA=B_6000_CF01.columns
for cols in colA:
    VoltageCF01=np.append(VoltageCF01,np.array(B_6000_CF01[cols]))
    
C_6000_CF01 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL01/6000000/VoltageC')

colA=C_6000_CF01.columns
for cols in colA:
    VoltageCF01=np.append(VoltageCF01,np.array(C_6000_CF01[cols]))
    
    
    

A_5500_CF01 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL01/5500000/VoltageA')

colA=A_5500_CF01.columns
for cols in colA:
    VoltageCF01=np.append(VoltageCF01,np.array(A_5500_CF01[cols]))
    
B_5500_CF01 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL01/5500000/VoltageB')

colA=B_5500_CF01.columns
for cols in colA:
    VoltageCF01=np.append(VoltageCF01,np.array(B_5500_CF01[cols]))
    
C_5500_CF01 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL01/5500000/VoltageC')

colA=C_5500_CF01.columns
for cols in colA:
    VoltageCF01=np.append(VoltageCF01,np.array(C_5500_CF01[cols]))

    
    
A_5000_CF01 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL01/5000000/VoltageA')

colA=A_5000_CF01.columns
for cols in colA:
    VoltageCF01=np.append(VoltageCF01,np.array(A_5000_CF01[cols]))
    
B_5000_CF01 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL01/5000000/VoltageB')

colA=B_5000_CF01.columns
for cols in colA:
    VoltageCF01=np.append(VoltageCF01,np.array(B_5000_CF01[cols]))
    
C_5000_CF01 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL01/5000000/VoltageC')

colA=C_5000_CF01.columns
for cols in colA:
    VoltageCF01=np.append(VoltageCF01,np.array(C_5000_CF01[cols]))
    
    
    

A_4800_CF01 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL01/4800000/VoltageA')

colA=A_4800_CF01.columns
for cols in colA:
    VoltageCF01=np.append(VoltageCF01,np.array(A_4800_CF01[cols]))
    
B_4800_CF01 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL01/4800000/VoltageB')

colA=B_4800_CF01.columns
for cols in colA:
    VoltageCF01=np.append(VoltageCF01,np.array(B_4800_CF01[cols]))
    
C_4800_CF01 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL01/4800000/VoltageC')

colA=C_4800_CF01.columns
for cols in colA:
    VoltageCF01=np.append(VoltageCF01,np.array(C_4800_CF01[cols]))
    
    
    

A_4600_CF01 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL01/4600000/VoltageA')

colA=A_4600_CF01.columns
for cols in colA:
    VoltageCF01=np.append(VoltageCF01,np.array(A_4600_CF01[cols]))
    
B_4600_CF01 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL01/4600000/VoltageB')

colA=B_4600_CF01.columns
for cols in colA:
    VoltageCF01=np.append(VoltageCF01,np.array(B_4600_CF01[cols]))
    
C_4600_CF01 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL01/4600000/VoltageC')

colA=C_4600_CF01.columns
for cols in colA:
    VoltageCF01=np.append(VoltageCF01,np.array(C_4600_CF01[cols]))
    

    
    
    
A_4400_CF01 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL01/4400000/VoltageA')

colA=A_4400_CF01.columns
for cols in colA:
    VoltageCF01=np.append(VoltageCF01,np.array(A_4400_CF01[cols]))
    
B_4400_CF01 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL01/4400000/VoltageB')

colA=B_4400_CF01.columns
for cols in colA:
    VoltageCF01=np.append(VoltageCF01,np.array(B_4400_CF01[cols]))
    
C_4400_CF01 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL01/4400000/VoltageC')

colA=C_4400_CF01.columns
for cols in colA:
    VoltageCF01=np.append(VoltageCF01,np.array(C_4400_CF01[cols]))

    
    
    
    
A_4000_CF01 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL01/4000000/VoltageA')

colA=A_4000_CF01.columns
for cols in colA:
    VoltageCF01=np.append(VoltageCF01,np.array(A_4000_CF01[cols]))
    
B_4000_CF01 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL01/4000000/VoltageB')

colA=B_4000_CF01.columns
for cols in colA:
    VoltageCF01=np.append(VoltageCF01,np.array(B_4000_CF01[cols]))
    
C_4000_CF01 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL01/4000000/VoltageC')

colA=C_4000_CF01.columns
for cols in colA:
    VoltageCF01=np.append(VoltageCF01,np.array(C_4000_CF01[cols]))
    

    
    
    
    
A_3500_CF01 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL01/3500000/VoltageA')

colA=A_3500_CF01.columns
for cols in colA:
    VoltageCF01=np.append(VoltageCF01,np.array(A_3500_CF01[cols]))
    
B_3500_CF01 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL01/3500000/VoltageB')

colA=B_3500_CF01.columns
for cols in colA:
    VoltageCF01=np.append(VoltageCF01,np.array(B_3500_CF01[cols]))
    
C_3500_CF01 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL01/3500000/VoltageC')

colA=C_3500_CF01.columns
for cols in colA:
    VoltageCF01=np.append(VoltageCF01,np.array(C_3500_CF01[cols]))
    

    
    
    
    
A_3200_CF01 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL01/3200000/VoltageA')

colA=A_3200_CF01.columns
for cols in colA:
    VoltageCF01=np.append(VoltageCF01,np.array(A_3200_CF01[cols]))
    
B_3200_CF01 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL01/3200000/VoltageB')

colA=B_3200_CF01.columns
for cols in colA:
    VoltageCF01=np.append(VoltageCF01,np.array(B_3200_CF01[cols]))
    
C_3200_CF01 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL01/3200000/VoltageC')

colA=C_3200_CF01.columns
for cols in colA:
    VoltageCF01=np.append(VoltageCF01,np.array(C_3200_CF01[cols]))

    

    
    
    
    
A_3100_CF01 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL01/3100000/VoltageA')

colA=A_3100_CF01.columns
for cols in colA:
    VoltageCF01=np.append(VoltageCF01,np.array(A_3100_CF01[cols]))
    
B_3100_CF01 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL01/3100000/VoltageB')

colA=B_3100_CF01.columns
for cols in colA:
    VoltageCF01=np.append(VoltageCF01,np.array(B_3100_CF01[cols]))
    
C_3100_CF01 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL01/3100000/VoltageC')

colA=C_3100_CF01.columns
for cols in colA:
    VoltageCF01=np.append(VoltageCF01,np.array(C_3100_CF01[cols]))
    
    

    
    
    
    
A_3000_CF01 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL01/3000000/VoltageA')

colA=A_3000_CF01.columns
for cols in colA:
    VoltageCF01=np.append(VoltageCF01,np.array(A_3000_CF01[cols]))
    
B_3000_CF01 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL01/3000000/VoltageB')

colA=B_3000_CF01.columns
for cols in colA:
    VoltageCF01=np.append(VoltageCF01,np.array(B_3000_CF01[cols]))
    
C_3000_CF01 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL01/3000000/VoltageC')

colA=C_3000_CF01.columns
for cols in colA:
    VoltageCF01=np.append(VoltageCF01,np.array(C_3000_CF01[cols]))
    
    
    

    
    
    
    
A_2500_CF01 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL01/2500000/VoltageA')

colA=A_2500_CF01.columns
for cols in colA:
    VoltageCF01=np.append(VoltageCF01,np.array(A_2500_CF01[cols]))
    
B_2500_CF01 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL01/2500000/VoltageB')

colA=B_2500_CF01.columns
for cols in colA:
    VoltageCF01=np.append(VoltageCF01,np.array(B_2500_CF01[cols]))
    
C_2500_CF01 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL01/2500000/VoltageC')

colA=C_2500_CF01.columns
for cols in colA:
    VoltageCF01=np.append(VoltageCF01,np.array(C_2500_CF01[cols]))
    
    
    
    

    
    
    
    
A_2000_CF01 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL01/2000000/VoltageA')

colA=A_2000_CF01.columns
for cols in colA:
    VoltageCF01=np.append(VoltageCF01,np.array(A_2000_CF01[cols]))
    
B_2000_CF01 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL01/2000000/VoltageB')

colA=B_2000_CF01.columns
for cols in colA:
    VoltageCF01=np.append(VoltageCF01,np.array(B_2000_CF01[cols]))
    
C_2000_CF01 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL01/2000000/VoltageC')

colA=C_2000_CF01.columns
for cols in colA:
    VoltageCF01=np.append(VoltageCF01,np.array(C_2000_CF01[cols]))
    
    
    
    

    
    
    
    
A_1500_CF01 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL01/1500000/VoltageA')

colA=A_1500_CF01.columns
for cols in colA:
    VoltageCF01=np.append(VoltageCF01,np.array(A_1500_CF01[cols]))
    
B_1500_CF01 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL01/1500000/VoltageB')

colA=B_1500_CF01.columns
for cols in colA:
    VoltageCF01=np.append(VoltageCF01,np.array(B_1500_CF01[cols]))
    
C_1500_CF01 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL01/1500000/VoltageC')

colA=C_1500_CF01.columns
for cols in colA:
    VoltageCF01=np.append(VoltageCF01,np.array(C_1500_CF01[cols]))
    
    
    
    

    
    
    
    
A_1300_CF01 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL01/1300000/VoltageA')

colA=A_1300_CF01.columns
for cols in colA:
    VoltageCF01=np.append(VoltageCF01,np.array(A_1300_CF01[cols]))
    
B_1300_CF01 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL01/1300000/VoltageB')

colA=B_1300_CF01.columns
for cols in colA:
    VoltageCF01=np.append(VoltageCF01,np.array(B_1300_CF01[cols]))
    
C_1300_CF01 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL01/1300000/VoltageC')

colA=C_1300_CF01.columns
for cols in colA:
    VoltageCF01=np.append(VoltageCF01,np.array(C_1300_CF01[cols]))

# %%
Hexplot01=pd.concat([pd.DataFrame(CurrentCF01, columns=['Current']),pd.DataFrame(VoltageCF01, columns=['Voltage'])], axis=1)
Voltage01=pd.DataFrame(VoltageCF01, columns=['85%'])
Current01=pd.DataFrame(CurrentCF01, columns=['85%'])

# %%
##########################################
################ CURRENT #################
##########################################


A_8000_CF01 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL01/8000000/CurentA')

colA=A_8000_CF01.columns
Current100CF01= np.array(A_8000_CF01['I12'])

for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
        
for cols in colA[1:]:
    Current100CF01=np.append(Current100CF01,np.array(A_8000_CF01[cols]))
    
    
B_8000_CF01 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL01/8000000/CurentB')

colA=B_8000_CF01.columns

for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    Current100CF01=np.append(Current100CF01,np.array(B_8000_CF01[cols]))
    
C_8000_CF01 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL01/8000000/CurentC')

colA=C_8000_CF01.columns
for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    Current100CF01=np.append(Current100CF01,np.array(C_8000_CF01[cols]))

    
    
    

    

    
A_1300_CF01 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL01/1300000/CurentA')

colA=A_1300_CF01.columns
Current0CF01= np.array(A_1300_CF01['I12'])

for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
        
for cols in colA[1:]:
    Current0CF01=np.append(Current0CF01,np.array(A_1300_CF01[cols]))
    
B_1300_CF01 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL01/1300000/CurentB')

colA=B_1300_CF01.columns
for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    Current0CF01=np.append(Current0CF01,np.array(B_1300_CF01[cols]))
    
C_1300_CF01 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL01/1300000/CurentC')

colA=C_1300_CF01.columns
for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    Current0CF01=np.append(Current0CF01,np.array(C_1300_CF01[cols]))
    
    
###########################
##### VOLTAGES ############
##########################


A_8000_CF01 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL01/8000000/VoltageA')

colA=A_8000_CF01.columns
Voltage100CF01= np.array(A_8000_CF01['2'])
for cols in colA[1:]:
    Voltage100CF01=np.append(Voltage100CF01,np.array(A_8000_CF01[cols]))
    
    
B_8000_CF01 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL01/8000000/VoltageB')

colA=B_8000_CF01.columns
for cols in colA:
    Voltage100CF01=np.append(Voltage100CF01,np.array(B_8000_CF01[cols]))
    
C_8000_CF01 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL01/8000000/VoltageC')

colA=C_8000_CF01.columns
for cols in colA:
    Voltage100CF01=np.append(Voltage100CF01,np.array(C_8000_CF01[cols]))

    
    
    


    
    
    
    
A_1300_CF01 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL01/1300000/VoltageA')

colA=A_1300_CF01.columns
Voltage0CF01= np.array(A_1300_CF01['2'])
for cols in colA[1:]:
    Voltage0CF01=np.append(Voltage0CF01,np.array(A_1300_CF01[cols]))
    
B_1300_CF01 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL01/1300000/VoltageB')

colA=B_1300_CF01.columns
for cols in colA:
    Voltage0CF01=np.append(Voltage0CF01,np.array(B_1300_CF01[cols]))
    
C_1300_CF01 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL01/1300000/VoltageC')

colA=C_1300_CF01.columns
for cols in colA:
    Voltage0CF01=np.append(Voltage0CF01,np.array(C_1300_CF01[cols]))

# %%
Voltage01cost=pd.DataFrame(Voltage100CF01, columns=['85%'])
Current01cost=pd.DataFrame(Current100CF01, columns=['85%'])

Voltage01carb=pd.DataFrame(Voltage0CF01, columns=['85%'])
Current01carb=pd.DataFrame(Current0CF01, columns=['85%'])

# %% [markdown]
# CF 0

# %%
##########################################
################ CURRENT #################
##########################################


A_8000_CF0 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL0/8000000/CurentA')

colA=A_8000_CF0.columns
CurrentCF0= np.array(A_8000_CF0['I12'])

for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
        
for cols in colA[1:]:
    CurrentCF0=np.append(CurrentCF0,np.array(A_8000_CF0[cols]))
    
    
B_8000_CF0 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL0/8000000/CurentB')

colA=B_8000_CF0.columns

for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    CurrentCF0=np.append(CurrentCF0,np.array(B_8000_CF0[cols]))
    
C_8000_CF0 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL0/8000000/CurentC')

colA=C_8000_CF0.columns
for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    CurrentCF0=np.append(CurrentCF0,np.array(C_8000_CF0[cols]))

    
    
    
A_6000_CF0 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL0/6000000/CurentA')

colA=A_6000_CF0.columns
for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    CurrentCF0=np.append(CurrentCF0,np.array(A_6000_CF0[cols]))
    
B_6000_CF0 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL0/6000000/CurentB')

colA=B_6000_CF0.columns
for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    CurrentCF0=np.append(CurrentCF0,np.array(B_6000_CF0[cols]))
    
C_6000_CF0 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL0/6000000/CurentC')

colA=C_6000_CF0.columns
for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    CurrentCF0=np.append(CurrentCF0,np.array(C_6000_CF0[cols]))
    
    
    

A_5500_CF0 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL0/5500000/CurentA')

colA=A_5500_CF0.columns
for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    CurrentCF0=np.append(CurrentCF0,np.array(A_5500_CF0[cols]))
    
B_5500_CF0 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL0/5500000/CurentB')

colA=B_5500_CF0.columns
for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    CurrentCF0=np.append(CurrentCF0,np.array(B_5500_CF0[cols]))
    
C_5500_CF0 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL0/5500000/CurentC')

colA=C_5500_CF0.columns
for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    CurrentCF0=np.append(CurrentCF0,np.array(C_5500_CF0[cols]))

    
    
A_5000_CF0 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL0/5000000/CurentA')

colA=A_5000_CF0.columns
for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    CurrentCF0=np.append(CurrentCF0,np.array(A_5000_CF0[cols]))
    
B_5000_CF0 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL0/5000000/CurentB')

colA=B_5000_CF0.columns
for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    CurrentCF0=np.append(CurrentCF0,np.array(B_5000_CF0[cols]))
    
C_5000_CF0 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL0/5000000/CurentC')

colA=C_5000_CF0.columns
for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    CurrentCF0=np.append(CurrentCF0,np.array(C_5000_CF0[cols]))
    
    
    

A_4800_CF0 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL0/4800000/CurentA')

colA=A_4800_CF0.columns
for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    CurrentCF0=np.append(CurrentCF0,np.array(A_4800_CF0[cols]))
    
B_4800_CF0 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL0/4800000/CurentB')

colA=B_4800_CF0.columns
for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    CurrentCF0=np.append(CurrentCF0,np.array(B_4800_CF0[cols]))
    
C_4800_CF0 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL0/4800000/CurentC')

colA=C_4800_CF0.columns
for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    CurrentCF0=np.append(CurrentCF0,np.array(C_4800_CF0[cols]))
    
    
    

A_4600_CF0 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL0/4600000/CurentA')

colA=A_4600_CF0.columns
for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    CurrentCF0=np.append(CurrentCF0,np.array(A_4600_CF0[cols]))
    
B_4600_CF0 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL0/4600000/CurentB')

colA=B_4600_CF0.columns
for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    CurrentCF0=np.append(CurrentCF0,np.array(B_4600_CF0[cols]))
    
C_4600_CF0 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL0/4600000/CurentC')

colA=C_4600_CF0.columns
for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    CurrentCF0=np.append(CurrentCF0,np.array(C_4600_CF0[cols]))
    
    
    
    
    
    
A_4400_CF0 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL0/4400000/CurentA')

colA=A_4400_CF0.columns
for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    CurrentCF0=np.append(CurrentCF0,np.array(A_4400_CF0[cols]))
    
B_4400_CF0 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL0/4400000/CurentB')

colA=B_4400_CF0.columns
for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    CurrentCF0=np.append(CurrentCF0,np.array(B_4400_CF0[cols]))
    
C_4400_CF0 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL0/4400000/CurentC')

colA=C_4400_CF0.columns
for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    CurrentCF0=np.append(CurrentCF0,np.array(C_4400_CF0[cols]))
    
    
    
    
A_4000_CF0 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL0/4000000/CurentA')

colA=A_4000_CF0.columns
for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    CurrentCF0=np.append(CurrentCF0,np.array(A_4000_CF0[cols]))
    
B_4000_CF0 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL0/4000000/CurentB')

colA=B_4000_CF0.columns
for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    CurrentCF0=np.append(CurrentCF0,np.array(B_4000_CF0[cols]))
    
C_4000_CF0 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL0/4000000/CurentC')

colA=C_4000_CF0.columns
for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    CurrentCF0=np.append(CurrentCF0,np.array(C_4000_CF0[cols]))
    
    
    
    
    
A_3500_CF0 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL0/3500000/CurentA')

colA=A_3500_CF0.columns
for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    CurrentCF0=np.append(CurrentCF0,np.array(A_3500_CF0[cols]))
    
B_3500_CF0 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL0/3500000/CurentB')

colA=B_3500_CF0.columns
for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    CurrentCF0=np.append(CurrentCF0,np.array(B_3500_CF0[cols]))
    
C_3500_CF0 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL0/3500000/CurentC')

colA=C_3500_CF0.columns
for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    CurrentCF0=np.append(CurrentCF0,np.array(C_3500_CF0[cols]))
    
    
    
    
    
A_3200_CF0 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL0/3200000/CurentA')

colA=A_3200_CF0.columns
for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    CurrentCF0=np.append(CurrentCF0,np.array(A_3200_CF0[cols]))
    
B_3200_CF0 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL0/3200000/CurentB')

colA=B_3200_CF0.columns
for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    CurrentCF0=np.append(CurrentCF0,np.array(B_3200_CF0[cols]))
    
C_3200_CF0 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL0/3200000/CurentC')

colA=C_3200_CF0.columns
for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    CurrentCF0=np.append(CurrentCF0,np.array(C_3200_CF0[cols]))
    
    
    

    
A_3100_CF0 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL0/3100000/CurentA')

colA=A_3100_CF0.columns
for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    CurrentCF0=np.append(CurrentCF0,np.array(A_3100_CF0[cols]))
    
B_3100_CF0 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL0/3100000/CurentB')

colA=B_3100_CF0.columns
for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    CurrentCF0=np.append(CurrentCF0,np.array(B_3100_CF0[cols]))
    
C_3100_CF0 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL0/3100000/CurentC')

colA=C_3100_CF0.columns
for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    CurrentCF0=np.append(CurrentCF0,np.array(C_3100_CF0[cols]))
    
    
    
    
    

    
A_3000_CF0 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL0/3000000/CurentA')

colA=A_3000_CF0.columns
for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    CurrentCF0=np.append(CurrentCF0,np.array(A_3000_CF0[cols]))
    
B_3000_CF0 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL0/3000000/CurentB')

colA=B_3000_CF0.columns
for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    CurrentCF0=np.append(CurrentCF0,np.array(B_3000_CF0[cols]))
    
C_3000_CF0 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL0/3000000/CurentC')

colA=C_3000_CF0.columns
for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    CurrentCF0=np.append(CurrentCF0,np.array(C_3000_CF0[cols]))
    
    
    
    
    
    

    
A_2500_CF0 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL0/2500000/CurentA')

colA=A_2500_CF0.columns
for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    CurrentCF0=np.append(CurrentCF0,np.array(A_2500_CF0[cols]))
    
B_2500_CF0 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL0/2500000/CurentB')

colA=B_2500_CF0.columns
for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    CurrentCF0=np.append(CurrentCF0,np.array(B_2500_CF0[cols]))
    
C_2500_CF0 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL0/2500000/CurentC')

colA=C_2500_CF0.columns
for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    CurrentCF0=np.append(CurrentCF0,np.array(C_2500_CF0[cols]))

    
    
    
    
    
    

    
A_2000_CF0 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL0/2000000/CurentA')

colA=A_2000_CF0.columns
for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    CurrentCF0=np.append(CurrentCF0,np.array(A_2000_CF0[cols]))
    
B_2000_CF0 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL0/2000000/CurentB')

colA=B_2000_CF0.columns
for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    CurrentCF0=np.append(CurrentCF0,np.array(B_2000_CF0[cols]))
    
C_2000_CF0 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL0/2000000/CurentC')

colA=C_2000_CF0.columns
for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    CurrentCF0=np.append(CurrentCF0,np.array(C_2000_CF0[cols]))
    
    
    
    
    
    
    
    

    
A_1500_CF0 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL0/1500000/CurentA')

colA=A_1500_CF0.columns
for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    CurrentCF0=np.append(CurrentCF0,np.array(A_1500_CF0[cols]))
    
B_1500_CF0 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL0/1500000/CurentB')

colA=B_1500_CF0.columns
for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    CurrentCF0=np.append(CurrentCF0,np.array(B_1500_CF0[cols]))
    
C_1500_CF0 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL0/1500000/CurentC')

colA=C_1500_CF0.columns
for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    CurrentCF0=np.append(CurrentCF0,np.array(C_1500_CF0[cols]))
    
    
    
    
    
    
    
    

    
A_1300_CF0 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL0/1300000/CurentA')

colA=A_1300_CF0.columns
for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    CurrentCF0=np.append(CurrentCF0,np.array(A_1300_CF0[cols]))
    
B_1300_CF0 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL0/1300000/CurentB')

colA=B_1300_CF0.columns
for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    CurrentCF0=np.append(CurrentCF0,np.array(B_1300_CF0[cols]))
    
C_1300_CF0 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL0/1300000/CurentC')

colA=C_1300_CF0.columns
for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    CurrentCF0=np.append(CurrentCF0,np.array(C_1300_CF0[cols]))
    
   
    
    
    
    
    
    

    
A_1000_CF0 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL0/1000000/CurentA')

colA=A_1000_CF0.columns
for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    CurrentCF0=np.append(CurrentCF0,np.array(A_1000_CF0[cols]))
    
B_1000_CF0 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL0/1000000/CurentB')

colA=B_1000_CF0.columns
for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    CurrentCF0=np.append(CurrentCF0,np.array(B_1000_CF0[cols]))
    
C_1000_CF0 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL0/1000000/CurentC')

colA=C_1000_CF0.columns
for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    CurrentCF0=np.append(CurrentCF0,np.array(C_1000_CF0[cols]))
    
   
    
    
    
    
    
    

    
A_0_CF0 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL0/0/CurentA')

colA=A_0_CF0.columns
for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    CurrentCF0=np.append(CurrentCF0,np.array(A_0_CF0[cols]))
    
B_0_CF0 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL0/0/CurentB')

colA=B_0_CF0.columns
for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    CurrentCF0=np.append(CurrentCF0,np.array(B_0_CF0[cols]))
    
C_0_CF0 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL0/0/CurentC')

colA=C_0_CF0.columns
for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    CurrentCF0=np.append(CurrentCF0,np.array(C_0_CF0[cols]))
###########################
##### VOLTAGES ############
##########################


A_8000_CF0 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL0/8000000/VoltageA')

colA=A_8000_CF0.columns
VoltageCF0= np.array(A_8000_CF0['2'])
for cols in colA[1:]:
    VoltageCF0=np.append(VoltageCF0,np.array(A_8000_CF0[cols]))
    
    
B_8000_CF0 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL0/8000000/VoltageB')

colA=B_8000_CF0.columns
for cols in colA:
    VoltageCF0=np.append(VoltageCF0,np.array(B_8000_CF0[cols]))
    
C_8000_CF0 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL0/8000000/VoltageC')

colA=C_8000_CF0.columns
for cols in colA:
    VoltageCF0=np.append(VoltageCF0,np.array(C_8000_CF0[cols]))

    
    
    
A_6000_CF0 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL0/6000000/VoltageA')

colA=A_6000_CF0.columns
for cols in colA:
    VoltageCF0=np.append(VoltageCF0,np.array(A_6000_CF0[cols]))
    
B_6000_CF0 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL0/6000000/VoltageB')

colA=B_6000_CF0.columns
for cols in colA:
    VoltageCF0=np.append(VoltageCF0,np.array(B_6000_CF0[cols]))
    
C_6000_CF0 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL0/6000000/VoltageC')

colA=C_6000_CF0.columns
for cols in colA:
    VoltageCF0=np.append(VoltageCF0,np.array(C_6000_CF0[cols]))
    
    
    

A_5500_CF0 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL0/5500000/VoltageA')

colA=A_5500_CF0.columns
for cols in colA:
    VoltageCF0=np.append(VoltageCF0,np.array(A_5500_CF0[cols]))
    
B_5500_CF0 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL0/5500000/VoltageB')

colA=B_5500_CF0.columns
for cols in colA:
    VoltageCF0=np.append(VoltageCF0,np.array(B_5500_CF0[cols]))
    
C_5500_CF0 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL0/5500000/VoltageC')

colA=C_5500_CF0.columns
for cols in colA:
    VoltageCF0=np.append(VoltageCF0,np.array(C_5500_CF0[cols]))

    
    
A_5000_CF0 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL0/5000000/VoltageA')

colA=A_5000_CF0.columns
for cols in colA:
    VoltageCF0=np.append(VoltageCF0,np.array(A_5000_CF0[cols]))
    
B_5000_CF0 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL0/5000000/VoltageB')

colA=B_5000_CF0.columns
for cols in colA:
    VoltageCF0=np.append(VoltageCF0,np.array(B_5000_CF0[cols]))
    
C_5000_CF0 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL0/5000000/VoltageC')

colA=C_5000_CF0.columns
for cols in colA:
    VoltageCF0=np.append(VoltageCF0,np.array(C_5000_CF0[cols]))
    
    
    

A_4800_CF0 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL0/4800000/VoltageA')

colA=A_4800_CF0.columns
for cols in colA:
    VoltageCF0=np.append(VoltageCF0,np.array(A_4800_CF0[cols]))
    
B_4800_CF0 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL0/4800000/VoltageB')

colA=B_4800_CF0.columns
for cols in colA:
    VoltageCF0=np.append(VoltageCF0,np.array(B_4800_CF0[cols]))
    
C_4800_CF0 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL0/4800000/VoltageC')

colA=C_4800_CF0.columns
for cols in colA:
    VoltageCF0=np.append(VoltageCF0,np.array(C_4800_CF0[cols]))
    
    
    

A_4600_CF0 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL0/4600000/VoltageA')

colA=A_4600_CF0.columns
for cols in colA:
    VoltageCF0=np.append(VoltageCF0,np.array(A_4600_CF0[cols]))
    
B_4600_CF0 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL0/4600000/VoltageB')

colA=B_4600_CF0.columns
for cols in colA:
    VoltageCF0=np.append(VoltageCF0,np.array(B_4600_CF0[cols]))
    
C_4600_CF0 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL0/4600000/VoltageC')

colA=C_4600_CF0.columns
for cols in colA:
    VoltageCF0=np.append(VoltageCF0,np.array(C_4600_CF0[cols]))
    

    
    
    
A_4400_CF0 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL0/4400000/VoltageA')

colA=A_4400_CF0.columns
for cols in colA:
    VoltageCF0=np.append(VoltageCF0,np.array(A_4400_CF0[cols]))
    
B_4400_CF0 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL0/4400000/VoltageB')

colA=B_4400_CF0.columns
for cols in colA:
    VoltageCF0=np.append(VoltageCF0,np.array(B_4400_CF0[cols]))
    
C_4400_CF0 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL0/4400000/VoltageC')

colA=C_4400_CF0.columns
for cols in colA:
    VoltageCF0=np.append(VoltageCF0,np.array(C_4400_CF0[cols]))

    
    
    
    
A_4000_CF0 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL0/4000000/VoltageA')

colA=A_4000_CF0.columns
for cols in colA:
    VoltageCF0=np.append(VoltageCF0,np.array(A_4000_CF0[cols]))
    
B_4000_CF0 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL0/4000000/VoltageB')

colA=B_4000_CF0.columns
for cols in colA:
    VoltageCF0=np.append(VoltageCF0,np.array(B_4000_CF0[cols]))
    
C_4000_CF0 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL0/4000000/VoltageC')

colA=C_4000_CF0.columns
for cols in colA:
    VoltageCF0=np.append(VoltageCF0,np.array(C_4000_CF0[cols]))
    

    
    
    
    
A_3500_CF0 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL0/3500000/VoltageA')

colA=A_3500_CF0.columns
for cols in colA:
    VoltageCF0=np.append(VoltageCF0,np.array(A_3500_CF0[cols]))
    
B_3500_CF0 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL0/3500000/VoltageB')

colA=B_3500_CF0.columns
for cols in colA:
    VoltageCF0=np.append(VoltageCF0,np.array(B_3500_CF0[cols]))
    
C_3500_CF0 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL0/3500000/VoltageC')

colA=C_3500_CF0.columns
for cols in colA:
    VoltageCF0=np.append(VoltageCF0,np.array(C_3500_CF0[cols]))
    

    
    
    
    
A_3200_CF0 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL0/3200000/VoltageA')

colA=A_3200_CF0.columns
for cols in colA:
    VoltageCF0=np.append(VoltageCF0,np.array(A_3200_CF0[cols]))
    
B_3200_CF0 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL0/3200000/VoltageB')

colA=B_3200_CF0.columns
for cols in colA:
    VoltageCF0=np.append(VoltageCF0,np.array(B_3200_CF0[cols]))
    
C_3200_CF0 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL0/3200000/VoltageC')

colA=C_3200_CF0.columns
for cols in colA:
    VoltageCF0=np.append(VoltageCF0,np.array(C_3200_CF0[cols]))

    

    
    
    
    
A_3100_CF0 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL0/3100000/VoltageA')

colA=A_3100_CF0.columns
for cols in colA:
    VoltageCF0=np.append(VoltageCF0,np.array(A_3100_CF0[cols]))
    
B_3100_CF0 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL0/3100000/VoltageB')

colA=B_3100_CF0.columns
for cols in colA:
    VoltageCF0=np.append(VoltageCF0,np.array(B_3100_CF0[cols]))
    
C_3100_CF0 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL0/3100000/VoltageC')

colA=C_3100_CF0.columns
for cols in colA:
    VoltageCF0=np.append(VoltageCF0,np.array(C_3100_CF0[cols]))
    
    

    
    
    
    
A_3000_CF0 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL0/3000000/VoltageA')

colA=A_3000_CF0.columns
for cols in colA:
    VoltageCF0=np.append(VoltageCF0,np.array(A_3000_CF0[cols]))
    
B_3000_CF0 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL0/3000000/VoltageB')

colA=B_3000_CF0.columns
for cols in colA:
    VoltageCF0=np.append(VoltageCF0,np.array(B_3000_CF0[cols]))
    
C_3000_CF0 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL0/3000000/VoltageC')

colA=C_3000_CF0.columns
for cols in colA:
    VoltageCF0=np.append(VoltageCF0,np.array(C_3000_CF0[cols]))
    
    
    

    
    
    
    
A_2500_CF0 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL0/2500000/VoltageA')

colA=A_2500_CF0.columns
for cols in colA:
    VoltageCF0=np.append(VoltageCF0,np.array(A_2500_CF0[cols]))
    
B_2500_CF0 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL0/2500000/VoltageB')

colA=B_2500_CF0.columns
for cols in colA:
    VoltageCF0=np.append(VoltageCF0,np.array(B_2500_CF0[cols]))
    
C_2500_CF0 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL0/2500000/VoltageC')

colA=C_2500_CF0.columns
for cols in colA:
    VoltageCF0=np.append(VoltageCF0,np.array(C_2500_CF0[cols]))
    
    
    
    

    
    
    
    
A_2000_CF0 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL0/2000000/VoltageA')

colA=A_2000_CF0.columns
for cols in colA:
    VoltageCF0=np.append(VoltageCF0,np.array(A_2000_CF0[cols]))
    
B_2000_CF0 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL0/2000000/VoltageB')

colA=B_2000_CF0.columns
for cols in colA:
    VoltageCF0=np.append(VoltageCF0,np.array(B_2000_CF0[cols]))
    
C_2000_CF0 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL0/2000000/VoltageC')

colA=C_2000_CF0.columns
for cols in colA:
    VoltageCF0=np.append(VoltageCF0,np.array(C_2000_CF0[cols]))
    
    
    
    

    
    
    
    
A_1500_CF0 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL0/1500000/VoltageA')

colA=A_1500_CF0.columns
for cols in colA:
    VoltageCF0=np.append(VoltageCF0,np.array(A_1500_CF0[cols]))
    
B_1500_CF0 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL0/1500000/VoltageB')

colA=B_1500_CF0.columns
for cols in colA:
    VoltageCF0=np.append(VoltageCF0,np.array(B_1500_CF0[cols]))
    
C_1500_CF0 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL0/1500000/VoltageC')

colA=C_1500_CF0.columns
for cols in colA:
    VoltageCF0=np.append(VoltageCF0,np.array(C_1500_CF0[cols]))
    
    
    
    

    
    
    
    
A_1300_CF0 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL0/1300000/VoltageA')

colA=A_1300_CF0.columns
for cols in colA:
    VoltageCF0=np.append(VoltageCF0,np.array(A_1300_CF0[cols]))
    
B_1300_CF0 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL0/1300000/VoltageB')

colA=B_1300_CF0.columns
for cols in colA:
    VoltageCF0=np.append(VoltageCF0,np.array(B_1300_CF0[cols]))
    
C_1300_CF0 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL0/1300000/VoltageC')

colA=C_1300_CF0.columns
for cols in colA:
    VoltageCF0=np.append(VoltageCF0,np.array(C_1300_CF0[cols]))
    
    
    
    

    
    
    
    
A_1000_CF0 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL0/1000000/VoltageA')

colA=A_1000_CF0.columns
for cols in colA:
    VoltageCF0=np.append(VoltageCF0,np.array(A_1000_CF0[cols]))
    
B_1000_CF0 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL0/1000000/VoltageB')

colA=B_1000_CF0.columns
for cols in colA:
    VoltageCF0=np.append(VoltageCF0,np.array(B_1000_CF0[cols]))
    
C_1000_CF0 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL0/1000000/VoltageC')

colA=C_1000_CF0.columns
for cols in colA:
    VoltageCF0=np.append(VoltageCF0,np.array(C_1000_CF0[cols]))
    
    
    
    

    
    
    
    
A_0_CF0 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL0/0/VoltageA')

colA=A_0_CF0.columns
for cols in colA:
    VoltageCF0=np.append(VoltageCF0,np.array(A_0_CF0[cols]))
    
B_0_CF0 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL0/0/VoltageB')

colA=B_0_CF0.columns
for cols in colA:
    VoltageCF0=np.append(VoltageCF0,np.array(B_0_CF0[cols]))
    
C_0_CF0 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL0/0/VoltageC')

colA=C_0_CF0.columns
for cols in colA:
    VoltageCF0=np.append(VoltageCF0,np.array(C_0_CF0[cols]))

# %%
Hexplot0=pd.concat([pd.DataFrame(CurrentCF0, columns=['Current']),pd.DataFrame(VoltageCF0, columns=['Voltage'])], axis=1)
Voltage0=pd.DataFrame(VoltageCF0, columns=['100%'])
Current0=pd.DataFrame(CurrentCF0, columns=['100%'])

# %%
##########################################
################ CURRENT #################
##########################################


A_8000_CF0 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL0/8000000/CurentA')

colA=A_8000_CF0.columns
Current100CF0= np.array(A_8000_CF0['I12'])

for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
        
for cols in colA[1:]:
    Current100CF0=np.append(Current100CF0,np.array(A_8000_CF0[cols]))
    
    
B_8000_CF0 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL0/8000000/CurentB')

colA=B_8000_CF0.columns

for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    Current100CF0=np.append(Current100CF0,np.array(B_8000_CF0[cols]))
    
C_8000_CF0 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL0/8000000/CurentC')

colA=C_8000_CF0.columns
for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    Current100CF0=np.append(Current100CF0,np.array(C_8000_CF0[cols]))

    
    
    


    
A_0_CF0 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL0/0/CurentA')

colA=A_0_CF0.columns
Current0CF0= np.array(A_0_CF0['I12'])

for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
        
for cols in colA[1:]:
    Current0CF0=np.append(Current0CF0,np.array(A_0_CF0[cols]))
    
    
B_0_CF0 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL0/0/CurentB')

colA=B_0_CF0.columns
for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    Current0CF0=np.append(Current0CF0,np.array(B_0_CF0[cols]))
    
C_0_CF0 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Currents/NORM_RelaxedUniInt_CHPboiler_noPWL0/0/CurentC')

colA=C_0_CF0.columns
for n, i in enumerate(colA):
    if n ==0:
        colsnum=int(i[1:])
        
    else:
        colsnum = np.append(colsnum, int(i[1:]))
        
colsnum=np.sort(colsnum)

for n,val in enumerate (colsnum):
    if n== 0:
        colA='I'+str(val)
        
    else:
        colA= np.append(colA, 'I'+str(val))
for cols in colA:
    Current0CF0=np.append(Current0CF0,np.array(C_0_CF0[cols]))
###########################
##### VOLTAGES ############
##########################


A_8000_CF0 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL0/8000000/VoltageA')

colA=A_8000_CF0.columns
Voltage100CF0= np.array(A_8000_CF0['2'])
for cols in colA[1:]:
    Voltage100CF0=np.append(Voltage100CF0,np.array(A_8000_CF0[cols]))
    
    
B_8000_CF0 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL0/8000000/VoltageB')

colA=B_8000_CF0.columns
for cols in colA:
    Voltage100CF0=np.append(Voltage100CF0,np.array(B_8000_CF0[cols]))
    
C_8000_CF0 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL0/8000000/VoltageC')

colA=C_8000_CF0.columns
for cols in colA:
    Voltage100CF0=np.append(Voltage100CF0,np.array(C_8000_CF0[cols]))

    
    
    


    
    
    
    
A_0_CF0 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL0/0/VoltageA')

colA=A_0_CF0.columns
Voltage0CF0= np.array(A_0_CF0['2'])
for cols in colA[1:]:
    Voltage0CF0=np.append(Voltage0CF0,np.array(A_0_CF0[cols]))
    
    
B_0_CF0 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL0/0/VoltageB')

colA=B_0_CF0.columns
for cols in colA:
    Voltage0CF0=np.append(Voltage0CF0,np.array(B_0_CF0[cols]))
    
C_0_CF0 = pd.read_hdf(r'T:\IEEE_case_study\data_working.h5','/Voltages/NORM_RelaxedUniInt_CHPboiler_noPWL0/0/VoltageC')

colA=C_0_CF0.columns
for cols in colA:
    Voltage0CF0=np.append(Voltage0CF0,np.array(C_0_CF0[cols]))

# %%
Voltage0cost=pd.DataFrame(Voltage100CF0, columns=['100%'])
Current0cost=pd.DataFrame(Current100CF0, columns=['100%'])

Voltage0carb=pd.DataFrame(Voltage0CF0, columns=['100%'])
Current0carb=pd.DataFrame(Current0CF0, columns=['100%'])

# %%
Voltage0.min(axis=0)
# Out:
# 100%    0.938173
# dtype: float64

# %%
Voltage01.min(axis=0)
# Out:
# 85%    0.924637
# dtype: float64

# %%
VoltageALL=pd.concat([Voltage05,Voltage04,Voltage03,Voltage02,Voltage01,Voltage0], axis=1)

fig = plt.figure(figsize=(6,4))
ax = fig.add_subplot(111)
sns.boxplot(data=VoltageALL, ax=ax)
ax.set_axis_bgcolor('white')
ax.grid(b=True, which='minor')

plt.xlabel('Renewable share in the grid')
plt.ylabel('Voltage (p.u.)')
plt.ylim([0.9, 1.1])
ax.set_yticks([0.9, 0.95, 1.05,1.1], minor=True)
ax.grid(b=True, which='minor', color='black', linewidth=0.5)

sns.despine(right=True, top=True, left=True)

fig.savefig(r'T:\IEEE_case_study\Normal\GRIDUPGRADE\VoltagePaper.png',bbox_inches='tight',dpi=500) #save the fig

# %%
VoltageALLcost=pd.concat([Voltage05cost,Voltage04cost,Voltage03cost,Voltage02cost,Voltage01cost,Voltage0cost], axis=1)

fig = plt.figure(figsize=(6,4))
ax = fig.add_subplot(111)
sns.boxplot(data=VoltageALLcost, ax=ax)
ax.set_axis_bgcolor('white')
ax.grid(b=True, which='minor')

plt.xlabel('Renewable share in the grid')
plt.ylabel('Voltage (p.u.)')
plt.ylim([0.9, 1.1])
ax.set_yticks([0.9, 0.95, 1.05,1.1], minor=True)
ax.grid(b=True, which='minor', color='black', linewidth=0.5)

sns.despine(right=True, top=True, left=True)

fig.savefig(r'T:\IEEE_case_study\Normal\GRIDUPGRADE\VoltageCost.png',bbox_inches='tight',dpi=500) #save the fig

VoltageALLcarb=pd.concat([Voltage05carb,Voltage04carb,Voltage03carb,Voltage02carb,Voltage01carb,Voltage0carb], axis=1)

fig = plt.figure(figsize=(6,4))
ax = fig.add_subplot(111)
sns.boxplot(data=VoltageALLcarb, ax=ax)
ax.set_axis_bgcolor('white')
ax.grid(b=True, which='minor')

plt.xlabel('Renewable share in the grid')
plt.ylabel('Voltage (p.u.)')
plt.ylim([0.9, 1.1])
ax.set_yticks([0.9, 0.95, 1.05,1.1], minor=True)
ax.grid(b=True, which='minor', color='black', linewidth=0.5)

sns.despine(right=True, top=True, left=True)

fig.savefig(r'T:\IEEE_case_study\Normal\GRIDUPGRADE\VoltageCarb.png',bbox_inches='tight',dpi=500) #save the fig

# %%
CurrentALL=pd.concat([Current05,Current04,Current03,Current02,Current01,Current0], axis=1)

fig = plt.figure(figsize=(6,4))
ax = fig.add_subplot(111)
sns.boxplot(data=CurrentALL, ax=ax)
ax.set_axis_bgcolor('white')
ax.grid(b=True, which='minor')

plt.xlabel('Renewable share in the grid')
plt.ylabel('Current (A)')
#plt.ylim([0, 100])
#ax.set_yticks([0.9, 0.95, 1.05,1.1], minor=True)
ax.grid(b=True, which='minor', color='black', linewidth=0.5)

sns.despine(right=True, top=True, left=True)

fig.savefig(r'T:\IEEE_case_study\Normal\GRIDUPGRADE\CurrentPaper.png',bbox_inches='tight',dpi=500) #save the fig

# %%
g = sns.jointplot("Voltage", "Current", data=Hexplot05, kind="hex", stat_func = None, joint_kws={'gridsize':30})
path='T:\IEEE_case_study\Normal\GRIDUPGRADE\Grid.png'#path to lis
plt.savefig(path,bbox_inches='tight',dpi=500) #save the fig

# %%
g = sns.jointplot("Voltage", "Current", data=Hexplot05,  stat_func = None)
path='T:\IEEE_case_study\Normal\GRIDUPGRADE\Grid2.png'#path to lis
plt.savefig(path,bbox_inches='tight',dpi=500) #save the fig

# %%
#sns.violinplot(y=Hexplot05["Current"])
sns.violinplot(y=Hexplot05["Voltage"])

# %%
CurrentALL=pd.concat([Current05,Current04,Current03,Current02,Current01,Current0], axis=1)

fig = plt.figure(figsize=(6,4))
ax = fig.add_subplot(111)
sns.violinplot(CurrentALL, ax=ax)
ax.set_axis_bgcolor('white')
ax.grid(b=True, which='minor')

plt.xlabel('Renewable share in the grid')
plt.ylabel('Current (A)')
plt.ylim([-10, 500])
ax.set_yticks([100, 200, 300,400, 500], minor=True)
ax.grid(b=True, which='minor', color='black', linewidth=0.4, alpha=0.6)

sns.despine(right=True, top=True, left=True)

fig.savefig(r'T:\IEEE_case_study\Normal\GRIDUPGRADE\CurrentViolinPaper.png',bbox_inches='tight',dpi=500) #save the fig
